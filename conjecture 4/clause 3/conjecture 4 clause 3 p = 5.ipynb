# %%
P = Primes()
ZR.<x> = PolynomialRing(ZZ)
D.<x> = PolynomialRing(QQ)
R.<x> = PolynomialRing(QQ)
C.<x> = PolynomialRing(CC)
S = PowerSeriesRing(QQ,'x', default_prec=300)
#S.<x,y>=PowerSeriesRing(QQ,default_prec=300)
# Using "R = PolynomialRing(QQ,'x')" produces an error.
# Yet using S as defined here is fine (see definition of Fraleigh4 below)
# But S = PowerSeriesRing(QQ,'x','y') also produces an error.
def pochhammer(x,n):
    return product ([x+k for k in [0..n-1]])
def cRaleigh2(alpha,beta,nu):
    pchhmrA = pochhammer(alpha,nu)
    pchhmrB = pochhammer(beta,nu)
    fnu=factorial(nu)
    answer = D(pchhmrA*pchhmrB/fnu^2)
    return answer
def term(alpha,beta,p):
    return D(1/(alpha + p) + 1/(beta + p) - 2/(1 + p))
def eRaleigh(alpha, beta, nu):
    return D(sum([term(alpha, beta, p) for p in [0..nu - 1]]))
def FstarRaleigh2(alpha,beta,u,terms):
    fsr = sum([cRaleigh2(alpha, beta, nu)*eRaleigh(alpha,beta,nu)*u^nu for nu in [1..terms]])
    return D(fsr)
def Fraleigh2(alpha,beta,u,terms): 
    return D(sum([cRaleigh2(alpha,beta,nu)*u^nu for nu in [0..terms]]))
def FstarRaleigh3(n,m,x):
    alpha = (1/2-1/m)/2
    beta = (1/2+1/m)/2
    fsr2 = FstarRaleigh2(alpha,beta,x,n)
    return D(fsr2)
def Fraleigh4(n,m,x):
    alpha = (1/2-1/m)/2
    beta = (1/2+1/m)/2
    fr2 = Fraleigh2(alpha,beta,x,n)
    return D(fr2)
def exNo3c(n,m):
    a1 = S(x)*exp(S(FstarRaleigh3(n,m,x)/Fraleigh4(n,m,x))).O(2*n)
    # S(x) instead of x in df of a1 to avoid an error message
    # after use of the stripQuotationMarks command below.
    a2 = S(a1).O(n+1)
    return a2 # applying S to argument of exp is key.
def J(n,m):
    exn = exNo3c(n+2,m)
    jnm = 1/exn.reverse()
    return jnm.O(n+1) # Jtest is faster than J, and they agree.
def normalJ(n,m):
    f = J(n,m)
    return f.truncate(n+1)
def Jcoefficient(n,m,x):
    f = J(n+2,m,x)
    f1 = f.truncate(n+1)
    f1=f1.list()
    f1=Set(f1)
    g1 = f.truncate(n)
    g1 = g1.list()
    g1 = set(g1)
    h = f1.difference(g1)
    h = h.list()
    return h[0]
def xjNewStep(n,m,x): 
    f=J(n,m,x)
    fl=f.list()
    return (sum(c*x**i*(m**3*2**6)**i for i,c in enumerate(fl)))
def xjNew(n,m,x):
    return xjNewStep(n-1,m,x)
def xjNewCoefficient(n,m,x):
    if n>0:return (xjNew(n,m,x)-xjNew(n-1,m,x))/x^n
    if n==0:return 1
def xjNewTest(n,m,x):
    return D(xjNewStep(n-1,m,x))
def polynomialCoefficient(n,poly):
    return poly.list()[n]
def factorpairToFactor(factorpair):
    (monomial,exponent)=factorpair
    return monomial^exponent
def numericalfactor(polynomial):
    fp=polynomial.factor()
    lst=[factorpairToFactor(factorpair) for factorpair in fp]
    return polynomial/product(lst)
def lastfactor(polynomial):
    fp=polynomial.factor()
    fp=FiniteEnumeratedSet(fp)
    return factorpairToFactor(fp.last())
def reduced(polynomial):
    return numericalfactor(polynomial)*lastfactor(polynomial)
def stripQuotationMarks(string):
    var('x')
    return sage_eval(string,locals={'x':x})

def prime_n(a):return P.unrank(a-1)

def primeFactors(n):
    answer=[]
    lf=list(n.factor())
    length=len(lf)
    for k in [0..length-1]:
        pair=lf[k]
        (base,exponent)=pair
        answer=answer+[[base]]
    return(flatten(answer))

def primeFactorsInList(lst):
    ld=len(lst)
    primelist=[]
    for k in [0..ld-1]:
        a=ZZ(lst[k])
        primelist=primelist+[primeFactors(a)]
    primelist=flatten(primelist)
    primelist=list(set(primelist))
    return primelist

def den(a):
    if a in QQ:
        if a in ZZ:return 1
        return a.denominator()
def listdens(lst):
    return list(den(a) for a in lst)
def polynomialdenominator(poly):return lcm(listdens(poly))
def polynomialnumerator(poly):
    return expand(poly*polynomialdenominator(poly))
def num(a):return a.numerator()
def prime(n):
    P=Primes()
    return P.unrank(n-1)
def inclusiveListPrimesTo(n):
    if is_prime(n):
        return list(primes(n+1))
    else:
        return list(primes(n))
def chunk(k,list):
    chnk=[]
    for n in [k..len(list)-1]:
        chnk=chnk+[list[n]]
    return chnk
def drop(m,lst): return list(Set(lst).difference({m}))
def sort(list):
    answr=[]
    chnk=list
    for n in [0..len(list)-1]:
        m = min(chnk)
        answr=answr+[m]
        chnk=drop(m,chnk)
    return answr
def ord(p,n):return QQ.valuation(p)(n)
def base_conversion(number, base_from, base_to):  # by Vishnu Namboothiri
# https://ask.sagemath.org/question/9657/how-to-output-decimal-numbers-in-different-radix/
    if(base_from==10):
        return stripQuotationMarks((number.str(base=base_to)))
    else:
        decimal = Integer(str(number), base=base_from)
        return (stripQuotationMarks(decimal.str(base=base_to)))
def lastFactorWithIntegralFactors(polynomial):
    return polynomialnumerator(lastfactor(polynomial))
def numericalFactorWithIntegralFactors(polynomial):
    nf=numericalfactor(polynomial);
    pd=polynomialdenominator(lastfactor(polynomial))
    return nf/pd


def primeDivisors(n):
    pd=[]
    n=n
    fn=factor(n)
    ln=len(fn)
    for k in [0..ln-1]:
        part = fn[k]
        (prime,exponent) = part
        pd = pd + [prime]
    return pd 
def fOverField(f,prime,power):
    answer=[]
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    ppoly = U(f)
    expr=str(ppoly)
    var('x')
    fp=ppoly.factor()
    return ppoly

###################### following two routines disagree ####################
def factorOverField(f,prime,power):
    answer=[]
    T = GF(prime^power,'t')
    G.<t>= GF(prime^power)
    U.<x> = T[]
    ppoly = U(f)
    expr=str(ppoly)
    var('x')
    fp=ppoly.factor()
    return fp

def factorOverField2(poly,prime,power,j):
    sd = leastSplittingDegree(poly,prime,bound)
    T=GF(prime^j)
    G.<t>= GF(prime^sd)
    U.<x> = T[]
    ppoly=U(poly)
    fpp=ppoly.factor()
    return fpp

############################

#######################################################
# splitting tests below fail at  e.g. f = x + 1 
############################################################

def splitsTF(f,prime,power):
    T = GF(prime^power)
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx > 1:return(False)
    return(True)

def leastSplittingDegree(f,prime,bound):
    for power in [1..bound]:
        tf=splitsTF(f,prime,power)
        if tf == True:return power
    return -1

#########################################################

def firstNprimes(n):
    P=Primes()
    first=[]
    for k in [0..n-1]:
        first=first+[P.unrank(k)]
    return first

def slopeExistsTF(pairlist):
    lenth=len(pairlist)
    if lenth<3:return False
    slopes=[]
    for k in [1..lenth-1]:
        pair1=pairlist[k-1]
        abscissa1=pair1[0]
        ordinate1=pair1[1]
        pair2=pairlist[k]
        abscissa2=pair2[0]
        ordinate2=pair2[1]
        dx=abscissa2-abscissa1
        if dx == 0:return False
        dy=ordinate2-ordinate1
        slope=dy/dx
        slopes=slopes+[slope]
    slopes=Set(slopes)
    if len(slopes) == 1:
        return [True,slopes[0]]
    if len(slopes) > 1:
        return False 
    
def zeroOfLinearMonomial(monomial,x):return x-monomial

def totalDegreeOverField(f,prime,power):
    T = GF(prime^power,'t')
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    td=0
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        td=td+exponent
    return td

def logsAndMultiplicitiesOverField(f,prime,power):
    T = GF(prime^power,'t')
    b=T.multiplicative_generator()
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    data=[]
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx == 1:
            xm=x-monomial
            if xm==0:data=data+[[-1,exponent]]
            if xm != 0:
                for i in [1..prime^power-1]:
                    if b^i==xm:data=data+[[i,exponent]]
    return data

def generatingZeroLogsOverField(f,prime,power):
    T = GF(prime^power,'t')
    b=T.multiplicative_generator()
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    data=[]
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx == 1:
            xm=x-monomial
            if xm==0:data=data+[[-1,exponent]]
            if xm != 0:
                for i in [1..prime^power-1]:
                    if b^i==xm:
                        if mod(i,prime)>0:
                            data=data+[i]
    data=data.sort()
    return data



def generatingZeroLogsAndMultiplicitiesOverField(f,prime,power):
    T = GF(prime^power,'t')
    b=T.multiplicative_generator()
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    data=[]
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx == 1:
            xm=x-monomial
            if xm==0:data=data+[[-1,exponent]]
            if xm != 0:
                for i in [1..prime^power-1]:
                    if b^i==xm:
                        if mod(i,prime)>0:
                            data=data+[[i,exponent]]
    return data




def logsAndMultiplicitiesOverFieldTest(f,prime,power):
    T = GF(prime^power,'t')
    b=T.multiplicative_generator()
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    print gf
    lnf = len(gf)-1
    data=[]
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx == 1:
            xm=x-monomial
            if xm==0:data=data+[[-1,exponent]]
            if xm != 0:
                for i in [1..prime^power-1]:
                    if b^i==xm:data=data+[[i,exponent]]
    return data

def logsAndMultiplicitiesOverFieldTest(f,prime,power):
    T = GF(prime^power,'t')
    b=T.multiplicative_generator()
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    print gf
    lnf = len(gf)-1
    data=[]
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx == 1:
            xm=x-monomial
            if xm==0:data=data+[[-1,exponent]]
            if xm != 0:
                for i in [1..prime^power-1]:
                    if b^i==xm:data=data+[[i,exponent]]
    return data



def dropzeros(list):
    data=[]
    el=len(list)
    for j  in [0..el-1]:
        lj=list[j]
        if lj != 0:data=data+[lj]
    return data

def padListOnRightToLengthK(listo,k):
    length=len(listo)
    padded=listo
   
    if length<k:
        for j in [length..k-1]:
            padded=padded+[0]
           
        return padded
    return listo

def testCandidateZeroLogOverField(f,prime,power,candidate):
    tf=False
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    poly = U(f)
    expr=str(poly)
    var('x')
    a=t^candidate
    expr3=sage_eval(expr,locals={'x':a})
    if expr3 == 0:tf=True
    return tf

def digitsToInteger(digitlist,prime):
    lenth=len(digitlist)
    sum=0
    for k in [0..lenth-1]:
        sum=sum+prime^k*digitlist[k]
    return sum

def minimumIntegerRepresentedInList(lstlst,prime):
    answer=Infinity
    ln=len(lstlst)
    for k in [0..ln-1]:
        lst=lstlst[k]
        n=digitsToInteger(lst,prime)
        if n < answer:answer=n
    return answer

def lastElement(lst):
    ln=len(lst)
    return lst[ln-1]

def push(lst):
    if len(lst)<2:return lst
    answer=[lastElement(lst)]
    for k in [0..len(lst)-2]:
        answer=flatten([answer]+[lst[k]])
    return answer

def cyclicPermutationEquivalenceClass(lst):
    if lst==[]:return lst
    answer=[lst]
    lnth=len(lst)
    for k in [0..lnth-2]:
        ple=push(lastElement(answer))
        answer=answer+[ple]
    return answer

def bestRepresentativeOfCyclicEquivalenceClass(lst,prime):
    cpec=cyclicPermutationEquivalenceClass(lst)
    minm=minimumIntegerRepresentedInList(cpec,prime)
    lcpec=len(lst) # ... = len(cpec)
    for k in [0..lcpec-1]:
        ck=cpec[k]
        dti=digitsToInteger(ck,prime)
        if minm==dti:return ck
    return "error"

def directZeroLogOverField(f,prime,power):
    tf=False
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    poly = U(f)
    expr=str(poly)
    var('x')
    answer=[]
    expr3=sage_eval(expr,locals={'x':0})
    if expr3 == 0:
        answer=[0]
    for i in [1..prime^power-1]:
        a=t^i
        expr3=sage_eval(expr,locals={'x':a})
        if expr3 == 0:
            answer=answer+[i]
    return answer

def reduce(f,prime):
    poly=polynomialnumerator(D(f))
    
    ls=list(poly)
    
    def modulo(n):
        return ZZ(mod(n,prime))
    def listmod(list):
        return map(modulo,list)
    lmls = listmod(ls)
    sm=0
    for j in [0..len(lmls)-1]:
        sm=sm+lmls[j]*x^j
    return sm


mt=[ #McKay-Thompson series w. a(0) = 24.
[-1, 1],
[0, 24],
[1, 276],
[2, 2048],
[3, 11202],
[4, 49152],
[5, 184024],
[6, 614400],
[7, 1881471],
[8, 5373952],
[9, 14478180],
[10, 37122048],
[11, 91231550],
[12, 216072192],
[13, 495248952],
[14, 1102430208],
[15, 2390434947],
[16, 5061476352],
[17, 10487167336],
[18, 21301241856],
[19, 42481784514],
[20, 83300614144],
[21, 160791890304],
[22, 305854488576],
[23, 573872089212],
[24, 1063005978624],
[25,1945403602764],
[26, 3519965179904],
[27, 6300794030460],
[28, 11164248047616],
[29, 19591528119288],
[30, 34065932304384],
[31, 58718797964805],
[32, 100372723007488],
[33, 170215559855424],
[34, 286470013685760],
[35, 478625723149576],
[36, 794110053826560],
[37, 1308745319975256],
[38, 2143055278039040],
[39, 3487563372381816],
[40, 5641848336678912],
[41, 9074553043554568],
[42, 14515166263443456],
[43, 23093778743102262],
[44, 36552977852071936],
[45, 57567784186189368],
[46, 90226777113575424],
[47, 140752796480416011],
[48, 218578429975461888],
[49, 337945040343588276],
[50, 520271697765971968],
[51, 797652526220573580],
[52, 1218002527825723392],
[53, 1852604006634050072],
[54, 2807138079496716288],
[55, 4237760460302936433],
[56, 6374456847628238848],
[57, 9554873766107770560],
[58, 14273181657059143680],
[59, 21250450411204068910],
[60, 31535729115847852032],
[61, 46650835290143061624],
[62, 68797209365301886976],
[63, 101150679669913197462],
[64, 148280443106626633728],
[65, 216743142763626253712],
[66, 315923191441199824896],
[67, 459218611940943755226],
[68, 665710603285072019456],
[69, 962508846974918603904],
[70, 1388038765923851599872],
[71, 1996639069403279491427],
[72, 2864978197116521938944],
[73, 4100990608911708903432],
[74, 5856297079648098807808],
[75, 8343432715970391209502],
[76, 11859696700297921757184],
[77, 16820105145987654631552],
[78, 23802835313046730063872],
[79, 33611779636250175278886],
[80, 47362494062244172660736],
[81, 66600077798590855556532],
[82, 93460562353103053049856],
[83, 130891485964083426534122],
[84, 182952844329494181838848],
[85, 255227018229957765044016],
[86, 355376219286719031156736],
[87, 493899311443420857952845],
[88, 685157678128482627354624],
[89, 948763597225844233250504],
[90, 1311456320500974276980736],
[91, 1809633323386495729057992],
[92, 2492760414984152205361152],
[93, 3427959082742197097793024],
[94, 4706168520874397834575872],
[95, 6450411048962389429976770],
[96, 8826863296640622526464000],
[97, 12059665023346371597383976],
[98, 16450700321708764061517824],
[99, 22405985191605778318221966],
[100, 30470821082605141257437184]]

def sumOfRoots(f,prime,power):
    answer=0
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    #U.<x> = T[] -- this line gave an error
    poly = U(f)
    expr=str(poly)
    var('x')
    for i in [1..prime^power-1]:
        a=t^i
        expr3=sage_eval(expr,locals={'x':a})
        if expr3 == 0:
            answer=answer+a
    return answer

def productOfNonzeroRoots(f,prime,power):
    answer=1
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    #U.<x> = T[] -- this line gave an error
    poly = U(f)
    expr=str(poly)
    var('x')
    for i in [1..prime^power-1]:
        a=t^i
        expr3=sage_eval(expr,locals={'x':a})
        if expr3 == 0:
            answer=answer*a
    return answer

def roots(f,prime,power):
    answer=[]
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    #U.<x> = T[] -- this line gave an error
    poly = U(f)
    expr=str(poly)
    var('x')
    expr3=sage_eval(expr,locals={'x':0})
    if expr3==0:answer=answer+[0]
    for i in [1..prime^power-1]:
        a=t^i
        expr3=sage_eval(expr,locals={'x':a})
        if expr3 == 0:
            answer=answer+[a]
    return answer

def numericalTermOverFieldNoPrint(f,prime,power):
    T = GF(prime^power,'t')
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    xproduct=1
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        xproduct=xproduct*monomial^exponent
    return g/xproduct

def polynomialDegree(poly):
    return len(poly.list())-1

def leadingCoefficient(poly):
    dp=D(poly)
    deg=polynomialDegree(dp)
    return dp.list()[deg]

def testRootLogTimesPrimeCn(f,prime,power):
    tf=True
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    poly = U(f)
    expr=str(poly)
    var('x')
    fp=poly.factor()
    lnf = len(fp) - 1
    flag = 1
    for i in [1..prime^power-1]:
        a=t^i
        expr3=sage_eval(expr,locals={'x':a})
        if expr3 == 0:
            j=i*prime
            b=t^j
            expr4=sage_eval(expr,locals={'x':b})
            if expr4!=0:
                tf=False
                print (i,j)
                
    return tf

def basicRoots(f,prime,power):
    answer=[]
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    poly = U(f)
    expr=str(poly)
    var('x')
    fp=poly.factor()
    lnf = len(fp) - 1
    flag = 1
    for i in [1..prime^power-1]:
        if mod(i,prime)!=0:
            a=t^i
            expr3=sage_eval(expr,locals={'x':a})
            if expr3 == 0:answer=answer+[i]
    return answer

def basicRootsDigits(f,prime,power):
    answer=[]
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    poly = U(f)
    expr=str(poly)
    var('x')
    fp=poly.factor()
    lnf = len(fp) - 1
    flag = 1
    for i in [1..prime^power-1]:
        if mod(i,prime)!=0:
            a=t^i
            expr3=sage_eval(expr,locals={'x':a})
            if expr3 == 0:answer=answer+[padListOnRightToLengthK(i.digits(prime),power)]
    return answer

def basicLogsAndMultiplicitiesOverField(f,prime,power):
    T = GF(prime^power,'t')
    b=T.multiplicative_generator()
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    data=[]
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx == 1:
            xm=x-monomial
            if xm==0:data=data+[[-1,exponent]]
            if xm != 0:
                for i in [1..prime^power-1]:
                    if mod(i,prime)!=0:
                        if b^i==xm:data=data+[[i,exponent]]
    return data.sort()

def totalMultiplicityOverField(f,prime,power):
    tm=0
    T = GF(prime^power,'t')
    b=T.multiplicative_generator()
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    data=[]
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx == 1:tm=tm+exponent
    return tm

def testRootLogTimesPrimeCn(f,prime,power):
    tf=True
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    poly = U(f)
    expr=str(poly)
    var('x')
    fp=poly.factor()
    lnf = len(fp) - 1
    flag = 1
    for i in [1..prime^power-1]:
        a=t^i
        expr3=sage_eval(expr,locals={'x':a})
        if expr3 == 0:
            j=i*prime
            b=t^j
            expr4=sage_eval(expr,locals={'x':b})
            if expr4!=0:
                tf=False
                print (i,j)
                
    return tf

# %%
## printed output has been snipped

import pickle
wfile=open('/Users/barrybrent/run1jun21no1.txt','a')
data=[]
for m in [3..500]:
    print m
    data=data+[[m,normalJ(200,m)]]
s=pickle.dumps(str(data))
wfile.write(s)
wfile.close()
#########################
import pickle
rfile = open('/Users/barrybrent/run1jun21no1.txt','r')
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)

polydata=[]

wfile = ## printed output has been snipped

import pickle
wfile=open('/Users/barrybrent/run1jun21no1.txt','a')
data=[]
for m in [3..500]:
    print m
    data=data+[[m,normalJ(200,m)]]
s=pickle.dumps(str(data))
wfile.write(s)
wfile.close()
#########################
import pickle
rfile = open('/Users/barrybrent/run1jun21no1.txt','r')
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)

polydata=[]

wfile = open('/Users/barrybrent/run14jun21no14.txt','a') # xJ polynomials
for n in [0..200]:
    data=[]
    for k in [0..2*n+1]:
        print (n,k)
        m = s[k][0]
        poly=x*s[k][1] 
        cf=polynomialCoefficient(n,poly)
        data=data+[[m,cf*m^(2*n)]]
    rl=R.lagrange_polynomial(data)
    polydata=polydata+[[n-1,rl]] 

    
t = pickle.dumps(str(polydata))
wfile.write(t)
wfile.close() # print-output snippeds
for n in [0..200]:
    data=[]
    for k in [0..2*n+1]:
        print (n,k)
        m = s[k][0]
        poly=x*s[k][1] 
        cf=polynomialCoefficient(n,poly)
        data=data+[[m,cf*m^(2*n)]]
    rl=R.lagrange_polynomial(data)
    polydata=polydata+[[n-1,rl]] 

    
t = pickle.dumps(str(polydata))
wfile.write(t)
wfile.close() # print-output snipped

# %% [markdown]
# sum

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') #Jfn
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
len(s)
# Out:
# 201

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=5
pairs=[]
for k in [1..200]:
    n=s[k][0]
    if (1==1)&(n>prime):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
        pair=(mod(n,prime),sd)
        pairs=pairs+[pair]
print sort(union(pairs))
# Out:
# [(0, 1), (1, 4), (2, 4), (3, 6), (4, 1)]

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=5
residue=0
sdvalue=1
badn=[]
count=0
flag=1
template=[]
for k in [1..200]:
    n=s[k][0]
    if (n>prime-1)&(mod(n,prime)==residue):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
    
        if (sd==sdvalue)&(flag==1):
            template=basicRoots(polynum,prime,sd)
            flag=0
    
        if (sd==sdvalue):
            count=1+count
            br=basicRoots(polynum,prime,sd)
            if br!=template:badn=badn+[n]
            lm=logsAndMultiplicitiesOverField(polynum,prime,sd)
            tm=totalMultiplicityOverField(polynum,prime,sd)
            print "------------------------------------------------------------------------"
            print "n: ",n," n.digits(prime): ",n.digits(prime)," sd: ",sd," prime: ",prime," n mod prime: ",mod(n,prime)
            print "basic roots:";print br
            print "root-logs and multiplicities:";print sorted(lm)
            print "total multiplicity of roots: ",tm
print "&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&"
if count==0:print "null"
print " bad n: ",badn;print "template: ",template
# Out:
# ------------------------------------------------------------------------
# n:  5  n.digits(prime):  [0, 1]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 2], [2, 4], [3, 2], [4, 4]]
# total multiplicity of roots:  12
# ------------------------------------------------------------------------
# n:  10  n.digits(prime):  [0, 2]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 4], [2, 6], [3, 4], [4, 6]]
# total multiplicity of roots:  20
# ------------------------------------------------------------------------
# n:  15  n.digits(prime):  [0, 3]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 6], [2, 8], [3, 6], [4, 8]]
# total multiplicity of roots:  28
# ------------------------------------------------------------------------
# n:  20  n.digits(prime):  [0, 4]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 8], [2, 10], [3, 8], [4, 10]]
# total multiplicity of roots:  36
# ------------------------------------------------------------------------
# n:  25  n.digits(prime):  [0, 0, 1]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 10], [2, 12], [3, 10], [4, 12]]
# total multiplicity of roots:  44
# ------------------------------------------------------------------------
# n:  30  n.digits(prime):  [0, 1, 1]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 12], [2, 14], [3, 12], [4, 14]]
# total multiplicity of roots:  52
# ------------------------------------------------------------------------
# n:  35  n.digits(prime):  [0, 2, 1]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 14], [2, 16], [3, 14], [4, 16]]
# total multiplicity of roots:  60
# ------------------------------------------------------------------------
# n:  40  n.digits(prime):  [0, 3, 1]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 16], [2, 18], [3, 16], [4, 18]]
# total multiplicity of roots:  68
# ------------------------------------------------------------------------
# n:  45  n.digits(prime):  [0, 4, 1]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 18], [2, 20], [3, 18], [4, 20]]
# total multiplicity of roots:  76
# ------------------------------------------------------------------------
# n:  50  n.digits(prime):  [0, 0, 2]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 20], [2, 22], [3, 20], [4, 22]]
# total multiplicity of roots:  84
# ------------------------------------------------------------------------
# n:  55  n.digits(prime):  [0, 1, 2]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 22], [2, 24], [3, 22], [4, 24]]
# total multiplicity of roots:  92
# ------------------------------------------------------------------------
# n:  60  n.digits(prime):  [0, 2, 2]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 24], [2, 26], [3, 24], [4, 26]]
# total multiplicity of roots:  100
# ------------------------------------------------------------------------
# n:  65  n.digits(prime):  [0, 3, 2]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 26], [2, 28], [3, 26], [4, 28]]
# total multiplicity of roots:  108
# ------------------------------------------------------------------------
# n:  70  n.digits(prime):  [0, 4, 2]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 28], [2, 30], [3, 28], [4, 30]]
# total multiplicity of roots:  116
# ------------------------------------------------------------------------
# n:  75  n.digits(prime):  [0, 0, 3]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 30], [2, 32], [3, 30], [4, 32]]
# total multiplicity of roots:  124
# ------------------------------------------------------------------------
# n:  80  n.digits(prime):  [0, 1, 3]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 32], [2, 34], [3, 32], [4, 34]]
# total multiplicity of roots:  132
# ------------------------------------------------------------------------
# n:  85  n.digits(prime):  [0, 2, 3]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 34], [2, 36], [3, 34], [4, 36]]
# total multiplicity of roots:  140
# ------------------------------------------------------------------------
# n:  90  n.digits(prime):  [0, 3, 3]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 36], [2, 38], [3, 36], [4, 38]]
# total multiplicity of roots:  148
# ------------------------------------------------------------------------
# n:  95  n.digits(prime):  [0, 4, 3]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 38], [2, 40], [3, 38], [4, 40]]
# total multiplicity of roots:  156
# ------------------------------------------------------------------------
# n:  100  n.digits(prime):  [0, 0, 4]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 40], [2, 42], [3, 40], [4, 42]]
# total multiplicity of roots:  164
# ------------------------------------------------------------------------
# n:  105  n.digits(prime):  [0, 1, 4]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 42], [2, 44], [3, 42], [4, 44]]
# total multiplicity of roots:  172
# ------------------------------------------------------------------------
# n:  110  n.digits(prime):  [0, 2, 4]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 44], [2, 46], [3, 44], [4, 46]]
# total multiplicity of roots:  180
# ------------------------------------------------------------------------
# n:  115  n.digits(prime):  [0, 3, 4]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 46], [2, 48], [3, 46], [4, 48]]
# total multiplicity of roots:  188
# ------------------------------------------------------------------------
# n:  120  n.digits(prime):  [0, 4, 4]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 48], [2, 50], [3, 48], [4, 50]]
# total multiplicity of roots:  196
# ------------------------------------------------------------------------
# n:  125  n.digits(prime):  [0, 0, 0, 1]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 50], [2, 52], [3, 50], [4, 52]]
# total multiplicity of roots:  204
# ------------------------------------------------------------------------
# n:  130  n.digits(prime):  [0, 1, 0, 1]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 52], [2, 54], [3, 52], [4, 54]]
# total multiplicity of roots:  212
# ------------------------------------------------------------------------
# n:  135  n.digits(prime):  [0, 2, 0, 1]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 54], [2, 56], [3, 54], [4, 56]]
# total multiplicity of roots:  220
# ------------------------------------------------------------------------
# n:  140  n.digits(prime):  [0, 3, 0, 1]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 56], [2, 58], [3, 56], [4, 58]]
# total multiplicity of roots:  228
# ------------------------------------------------------------------------
# n:  145  n.digits(prime):  [0, 4, 0, 1]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 58], [2, 60], [3, 58], [4, 60]]
# total multiplicity of roots:  236
# ------------------------------------------------------------------------
# n:  150  n.digits(prime):  [0, 0, 1, 1]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 60], [2, 62], [3, 60], [4, 62]]
# total multiplicity of roots:  244
# ------------------------------------------------------------------------
# n:  155  n.digits(prime):  [0, 1, 1, 1]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 62], [2, 64], [3, 62], [4, 64]]
# total multiplicity of roots:  252
# ------------------------------------------------------------------------
# n:  160  n.digits(prime):  [0, 2, 1, 1]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 64], [2, 66], [3, 64], [4, 66]]
# total multiplicity of roots:  260
# ------------------------------------------------------------------------
# n:  165  n.digits(prime):  [0, 3, 1, 1]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 66], [2, 68], [3, 66], [4, 68]]
# total multiplicity of roots:  268
# ------------------------------------------------------------------------
# n:  170  n.digits(prime):  [0, 4, 1, 1]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 68], [2, 70], [3, 68], [4, 70]]
# total multiplicity of roots:  276
# ------------------------------------------------------------------------
# n:  175  n.digits(prime):  [0, 0, 2, 1]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 70], [2, 72], [3, 70], [4, 72]]
# total multiplicity of roots:  284
# ------------------------------------------------------------------------
# n:  180  n.digits(prime):  [0, 1, 2, 1]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 72], [2, 74], [3, 72], [4, 74]]
# total multiplicity of roots:  292
# ------------------------------------------------------------------------
# n:  185  n.digits(prime):  [0, 2, 2, 1]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 74], [2, 76], [3, 74], [4, 76]]
# total multiplicity of roots:  300
# ------------------------------------------------------------------------
# n:  190  n.digits(prime):  [0, 3, 2, 1]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 76], [2, 78], [3, 76], [4, 78]]
# total multiplicity of roots:  308
# ------------------------------------------------------------------------
# n:  195  n.digits(prime):  [0, 4, 2, 1]  sd:  1  prime:  5  n mod prime:  0
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 78], [2, 80], [3, 78], [4, 80]]
# total multiplicity of roots:  316
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
#  bad n:  []
# template:  [1, 2, 3, 4]

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=5
residue=1
sdvalue=4
badn=[]
count=0
flag=1
template=[]
for k in [1..200]:
    n=s[k][0]
    if (n>prime-1)&(mod(n,prime)==residue):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
    
        if (sd==sdvalue)&(flag==1):
            template=basicRoots(polynum,prime,sd)
            flag=0
    
        if (sd==sdvalue):
            count=1+count
            br=basicRoots(polynum,prime,sd)
            if br!=template:badn=badn+[n]
            lm=logsAndMultiplicitiesOverField(polynum,prime,sd)
            tm=totalMultiplicityOverField(polynum,prime,sd)
            print "------------------------------------------------------------------------"
            print "n: ",n," n.digits(prime): ",n.digits(prime)," sd: ",sd," prime: ",prime," n mod prime: ",mod(n,prime)
            print "basic roots:";print br
            print "root-logs and multiplicities:";print sorted(lm)
            print "total multiplicity of roots: ",tm
print "&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&"
if count==0:print "null"
print " bad n: ",badn;print "template: ",template
# Out:
# ------------------------------------------------------------------------
# n:  6  n.digits(prime):  [1, 1]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 2], [312, 2], [403, 1], [455, 1], [468, 2], [624, 2]]
# total multiplicity of roots:  12
# ------------------------------------------------------------------------
# n:  11  n.digits(prime):  [1, 2]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 4], [312, 4], [403, 1], [455, 1], [468, 4], [624, 4]]
# total multiplicity of roots:  20
# ------------------------------------------------------------------------
# n:  16  n.digits(prime):  [1, 3]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 6], [312, 6], [403, 1], [455, 1], [468, 6], [624, 6]]
# total multiplicity of roots:  28
# ------------------------------------------------------------------------
# n:  21  n.digits(prime):  [1, 4]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 8], [312, 8], [403, 1], [455, 1], [468, 8], [624, 8]]
# total multiplicity of roots:  36
# ------------------------------------------------------------------------
# n:  26  n.digits(prime):  [1, 0, 1]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 10], [312, 10], [403, 1], [455, 1], [468, 10], [624, 10]]
# total multiplicity of roots:  44
# ------------------------------------------------------------------------
# n:  31  n.digits(prime):  [1, 1, 1]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 12], [312, 12], [403, 1], [455, 1], [468, 12], [624, 12]]
# total multiplicity of roots:  52
# ------------------------------------------------------------------------
# n:  36  n.digits(prime):  [1, 2, 1]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 14], [312, 14], [403, 1], [455, 1], [468, 14], [624, 14]]
# total multiplicity of roots:  60
# ------------------------------------------------------------------------
# n:  41  n.digits(prime):  [1, 3, 1]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 16], [312, 16], [403, 1], [455, 1], [468, 16], [624, 16]]
# total multiplicity of roots:  68
# ------------------------------------------------------------------------
# n:  46  n.digits(prime):  [1, 4, 1]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 18], [312, 18], [403, 1], [455, 1], [468, 18], [624, 18]]
# total multiplicity of roots:  76
# ------------------------------------------------------------------------
# n:  51  n.digits(prime):  [1, 0, 2]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 20], [312, 20], [403, 1], [455, 1], [468, 20], [624, 20]]
# total multiplicity of roots:  84
# ------------------------------------------------------------------------
# n:  56  n.digits(prime):  [1, 1, 2]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 22], [312, 22], [403, 1], [455, 1], [468, 22], [624, 22]]
# total multiplicity of roots:  92
# ------------------------------------------------------------------------
# n:  61  n.digits(prime):  [1, 2, 2]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 24], [312, 24], [403, 1], [455, 1], [468, 24], [624, 24]]
# total multiplicity of roots:  100
# ------------------------------------------------------------------------
# n:  66  n.digits(prime):  [1, 3, 2]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 26], [312, 26], [403, 1], [455, 1], [468, 26], [624, 26]]
# total multiplicity of roots:  108
# ------------------------------------------------------------------------
# n:  71  n.digits(prime):  [1, 4, 2]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 28], [312, 28], [403, 1], [455, 1], [468, 28], [624, 28]]
# total multiplicity of roots:  116
# ------------------------------------------------------------------------
# n:  76  n.digits(prime):  [1, 0, 3]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 30], [312, 30], [403, 1], [455, 1], [468, 30], [624, 30]]
# total multiplicity of roots:  124
# ------------------------------------------------------------------------
# n:  81  n.digits(prime):  [1, 1, 3]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 32], [312, 32], [403, 1], [455, 1], [468, 32], [624, 32]]
# total multiplicity of roots:  132
# ------------------------------------------------------------------------
# n:  86  n.digits(prime):  [1, 2, 3]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 34], [312, 34], [403, 1], [455, 1], [468, 34], [624, 34]]
# total multiplicity of roots:  140
# ------------------------------------------------------------------------
# n:  91  n.digits(prime):  [1, 3, 3]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 36], [312, 36], [403, 1], [455, 1], [468, 36], [624, 36]]
# total multiplicity of roots:  148
# ------------------------------------------------------------------------
# n:  96  n.digits(prime):  [1, 4, 3]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 38], [312, 38], [403, 1], [455, 1], [468, 38], [624, 38]]
# total multiplicity of roots:  156
# ------------------------------------------------------------------------
# n:  101  n.digits(prime):  [1, 0, 4]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 40], [312, 40], [403, 1], [455, 1], [468, 40], [624, 40]]
# total multiplicity of roots:  164
# ------------------------------------------------------------------------
# n:  106  n.digits(prime):  [1, 1, 4]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 42], [312, 42], [403, 1], [455, 1], [468, 42], [624, 42]]
# total multiplicity of roots:  172
# ------------------------------------------------------------------------
# n:  111  n.digits(prime):  [1, 2, 4]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 44], [312, 44], [403, 1], [455, 1], [468, 44], [624, 44]]
# total multiplicity of roots:  180
# ------------------------------------------------------------------------
# n:  116  n.digits(prime):  [1, 3, 4]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 46], [312, 46], [403, 1], [455, 1], [468, 46], [624, 46]]
# total multiplicity of roots:  188
# ------------------------------------------------------------------------
# n:  121  n.digits(prime):  [1, 4, 4]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 48], [312, 48], [403, 1], [455, 1], [468, 48], [624, 48]]
# total multiplicity of roots:  196
# ------------------------------------------------------------------------
# n:  126  n.digits(prime):  [1, 0, 0, 1]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 50], [312, 50], [403, 1], [455, 1], [468, 50], [624, 50]]
# total multiplicity of roots:  204
# ------------------------------------------------------------------------
# n:  131  n.digits(prime):  [1, 1, 0, 1]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 52], [312, 52], [403, 1], [455, 1], [468, 52], [624, 52]]
# total multiplicity of roots:  212
# ------------------------------------------------------------------------
# n:  136  n.digits(prime):  [1, 2, 0, 1]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 54], [312, 54], [403, 1], [455, 1], [468, 54], [624, 54]]
# total multiplicity of roots:  220
# ------------------------------------------------------------------------
# n:  141  n.digits(prime):  [1, 3, 0, 1]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 56], [312, 56], [403, 1], [455, 1], [468, 56], [624, 56]]
# total multiplicity of roots:  228
# ------------------------------------------------------------------------
# n:  146  n.digits(prime):  [1, 4, 0, 1]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 58], [312, 58], [403, 1], [455, 1], [468, 58], [624, 58]]
# total multiplicity of roots:  236
# ------------------------------------------------------------------------
# n:  151  n.digits(prime):  [1, 0, 1, 1]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 60], [312, 60], [403, 1], [455, 1], [468, 60], [624, 60]]
# total multiplicity of roots:  244
# ------------------------------------------------------------------------
# n:  156  n.digits(prime):  [1, 1, 1, 1]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 62], [312, 62], [403, 1], [455, 1], [468, 62], [624, 62]]
# total multiplicity of roots:  252
# ------------------------------------------------------------------------
# n:  161  n.digits(prime):  [1, 2, 1, 1]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 64], [312, 64], [403, 1], [455, 1], [468, 64], [624, 64]]
# total multiplicity of roots:  260
# ------------------------------------------------------------------------
# n:  166  n.digits(prime):  [1, 3, 1, 1]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 66], [312, 66], [403, 1], [455, 1], [468, 66], [624, 66]]
# total multiplicity of roots:  268
# ------------------------------------------------------------------------
# n:  171  n.digits(prime):  [1, 4, 1, 1]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 68], [312, 68], [403, 1], [455, 1], [468, 68], [624, 68]]
# total multiplicity of roots:  276
# ------------------------------------------------------------------------
# n:  176  n.digits(prime):  [1, 0, 2, 1]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 70], [312, 70], [403, 1], [455, 1], [468, 70], [624, 70]]
# total multiplicity of roots:  284
# ------------------------------------------------------------------------
# n:  181  n.digits(prime):  [1, 1, 2, 1]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 72], [312, 72], [403, 1], [455, 1], [468, 72], [624, 72]]
# total multiplicity of roots:  292
# ------------------------------------------------------------------------
# n:  186  n.digits(prime):  [1, 2, 2, 1]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 74], [312, 74], [403, 1], [455, 1], [468, 74], [624, 74]]
# total multiplicity of roots:  300
# ------------------------------------------------------------------------
# n:  191  n.digits(prime):  [1, 3, 2, 1]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 76], [312, 76], [403, 1], [455, 1], [468, 76], [624, 76]]
# total multiplicity of roots:  308
# ------------------------------------------------------------------------
# n:  196  n.digits(prime):  [1, 4, 2, 1]  sd:  4  prime:  5  n mod prime:  1
# basic roots:
# [91, 143, 156, 312, 403, 468, 624]
# root-logs and multiplicities:
# [[91, 1], [143, 1], [156, 78], [312, 78], [403, 1], [455, 1], [468, 78], [624, 78]]
# total multiplicity of roots:  316
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
#  bad n:  []
# template:  [91, 143, 156, 312, 403, 468, 624]

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=5
residue=2
sdvalue=4
badn=[]
count=0
flag=1
template=[]
for k in [1..200]:
    n=s[k][0]
    if (n>prime-1)&(mod(n,prime)==residue):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
    
        if (sd==sdvalue)&(flag==1):
            template=basicRoots(polynum,prime,sd)
            flag=0
    
        if (sd==sdvalue):
            count=1+count
            br=basicRoots(polynum,prime,sd)
            if br!=template:badn=badn+[n]
            lm=logsAndMultiplicitiesOverField(polynum,prime,sd)
            tm=totalMultiplicityOverField(polynum,prime,sd)
            print "------------------------------------------------------------------------"
            print "n: ",n," n.digits(prime): ",n.digits(prime)," sd: ",sd," prime: ",prime," n mod prime: ",mod(n,prime)
            print "basic roots:";print br
            print "root-logs and multiplicities:";print sorted(lm)
            print "total multiplicity of roots: ",tm
print "&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&"
if count==0:print "null"
print " bad n: ",badn;print "template: ",template
# Out:
# ------------------------------------------------------------------------
# n:  7  n.digits(prime):  [2, 1]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 3], [169, 1], [221, 1], [312, 2], [468, 3], [481, 1], [533, 1], [624, 2]]
# total multiplicity of roots:  14
# ------------------------------------------------------------------------
# n:  12  n.digits(prime):  [2, 2]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 5], [169, 1], [221, 1], [312, 4], [468, 5], [481, 1], [533, 1], [624, 4]]
# total multiplicity of roots:  22
# ------------------------------------------------------------------------
# n:  17  n.digits(prime):  [2, 3]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 7], [169, 1], [221, 1], [312, 6], [468, 7], [481, 1], [533, 1], [624, 6]]
# total multiplicity of roots:  30
# ------------------------------------------------------------------------
# n:  22  n.digits(prime):  [2, 4]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 9], [169, 1], [221, 1], [312, 8], [468, 9], [481, 1], [533, 1], [624, 8]]
# total multiplicity of roots:  38
# ------------------------------------------------------------------------
# n:  27  n.digits(prime):  [2, 0, 1]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 11], [169, 1], [221, 1], [312, 10], [468, 11], [481, 1], [533, 1], [624, 10]]
# total multiplicity of roots:  46
# ------------------------------------------------------------------------
# n:  32  n.digits(prime):  [2, 1, 1]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 13], [169, 1], [221, 1], [312, 12], [468, 13], [481, 1], [533, 1], [624, 12]]
# total multiplicity of roots:  54
# ------------------------------------------------------------------------
# n:  37  n.digits(prime):  [2, 2, 1]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 15], [169, 1], [221, 1], [312, 14], [468, 15], [481, 1], [533, 1], [624, 14]]
# total multiplicity of roots:  62
# ------------------------------------------------------------------------
# n:  42  n.digits(prime):  [2, 3, 1]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 17], [169, 1], [221, 1], [312, 16], [468, 17], [481, 1], [533, 1], [624, 16]]
# total multiplicity of roots:  70
# ------------------------------------------------------------------------
# n:  47  n.digits(prime):  [2, 4, 1]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 19], [169, 1], [221, 1], [312, 18], [468, 19], [481, 1], [533, 1], [624, 18]]
# total multiplicity of roots:  78
# ------------------------------------------------------------------------
# n:  52  n.digits(prime):  [2, 0, 2]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 21], [169, 1], [221, 1], [312, 20], [468, 21], [481, 1], [533, 1], [624, 20]]
# total multiplicity of roots:  86
# ------------------------------------------------------------------------
# n:  57  n.digits(prime):  [2, 1, 2]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 23], [169, 1], [221, 1], [312, 22], [468, 23], [481, 1], [533, 1], [624, 22]]
# total multiplicity of roots:  94
# ------------------------------------------------------------------------
# n:  62  n.digits(prime):  [2, 2, 2]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 25], [169, 1], [221, 1], [312, 24], [468, 25], [481, 1], [533, 1], [624, 24]]
# total multiplicity of roots:  102
# ------------------------------------------------------------------------
# n:  67  n.digits(prime):  [2, 3, 2]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 27], [169, 1], [221, 1], [312, 26], [468, 27], [481, 1], [533, 1], [624, 26]]
# total multiplicity of roots:  110
# ------------------------------------------------------------------------
# n:  72  n.digits(prime):  [2, 4, 2]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 29], [169, 1], [221, 1], [312, 28], [468, 29], [481, 1], [533, 1], [624, 28]]
# total multiplicity of roots:  118
# ------------------------------------------------------------------------
# n:  77  n.digits(prime):  [2, 0, 3]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 31], [169, 1], [221, 1], [312, 30], [468, 31], [481, 1], [533, 1], [624, 30]]
# total multiplicity of roots:  126
# ------------------------------------------------------------------------
# n:  82  n.digits(prime):  [2, 1, 3]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 33], [169, 1], [221, 1], [312, 32], [468, 33], [481, 1], [533, 1], [624, 32]]
# total multiplicity of roots:  134
# ------------------------------------------------------------------------
# n:  87  n.digits(prime):  [2, 2, 3]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 35], [169, 1], [221, 1], [312, 34], [468, 35], [481, 1], [533, 1], [624, 34]]
# total multiplicity of roots:  142
# ------------------------------------------------------------------------
# n:  92  n.digits(prime):  [2, 3, 3]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 37], [169, 1], [221, 1], [312, 36], [468, 37], [481, 1], [533, 1], [624, 36]]
# total multiplicity of roots:  150
# ------------------------------------------------------------------------
# n:  97  n.digits(prime):  [2, 4, 3]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 39], [169, 1], [221, 1], [312, 38], [468, 39], [481, 1], [533, 1], [624, 38]]
# total multiplicity of roots:  158
# ------------------------------------------------------------------------
# n:  102  n.digits(prime):  [2, 0, 4]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 41], [169, 1], [221, 1], [312, 40], [468, 41], [481, 1], [533, 1], [624, 40]]
# total multiplicity of roots:  166
# ------------------------------------------------------------------------
# n:  107  n.digits(prime):  [2, 1, 4]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 43], [169, 1], [221, 1], [312, 42], [468, 43], [481, 1], [533, 1], [624, 42]]
# total multiplicity of roots:  174
# ------------------------------------------------------------------------
# n:  112  n.digits(prime):  [2, 2, 4]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 45], [169, 1], [221, 1], [312, 44], [468, 45], [481, 1], [533, 1], [624, 44]]
# total multiplicity of roots:  182
# ------------------------------------------------------------------------
# n:  117  n.digits(prime):  [2, 3, 4]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 47], [169, 1], [221, 1], [312, 46], [468, 47], [481, 1], [533, 1], [624, 46]]
# total multiplicity of roots:  190
# ------------------------------------------------------------------------
# n:  122  n.digits(prime):  [2, 4, 4]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 49], [169, 1], [221, 1], [312, 48], [468, 49], [481, 1], [533, 1], [624, 48]]
# total multiplicity of roots:  198
# ------------------------------------------------------------------------
# n:  127  n.digits(prime):  [2, 0, 0, 1]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 51], [169, 1], [221, 1], [312, 50], [468, 51], [481, 1], [533, 1], [624, 50]]
# total multiplicity of roots:  206
# ------------------------------------------------------------------------
# n:  132  n.digits(prime):  [2, 1, 0, 1]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 53], [169, 1], [221, 1], [312, 52], [468, 53], [481, 1], [533, 1], [624, 52]]
# total multiplicity of roots:  214
# ------------------------------------------------------------------------
# n:  137  n.digits(prime):  [2, 2, 0, 1]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 55], [169, 1], [221, 1], [312, 54], [468, 55], [481, 1], [533, 1], [624, 54]]
# total multiplicity of roots:  222
# ------------------------------------------------------------------------
# n:  142  n.digits(prime):  [2, 3, 0, 1]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 57], [169, 1], [221, 1], [312, 56], [468, 57], [481, 1], [533, 1], [624, 56]]
# total multiplicity of roots:  230
# ------------------------------------------------------------------------
# n:  147  n.digits(prime):  [2, 4, 0, 1]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 59], [169, 1], [221, 1], [312, 58], [468, 59], [481, 1], [533, 1], [624, 58]]
# total multiplicity of roots:  238
# ------------------------------------------------------------------------
# n:  152  n.digits(prime):  [2, 0, 1, 1]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 61], [169, 1], [221, 1], [312, 60], [468, 61], [481, 1], [533, 1], [624, 60]]
# total multiplicity of roots:  246
# ------------------------------------------------------------------------
# n:  157  n.digits(prime):  [2, 1, 1, 1]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 63], [169, 1], [221, 1], [312, 62], [468, 63], [481, 1], [533, 1], [624, 62]]
# total multiplicity of roots:  254
# ------------------------------------------------------------------------
# n:  162  n.digits(prime):  [2, 2, 1, 1]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 65], [169, 1], [221, 1], [312, 64], [468, 65], [481, 1], [533, 1], [624, 64]]
# total multiplicity of roots:  262
# ------------------------------------------------------------------------
# n:  167  n.digits(prime):  [2, 3, 1, 1]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 67], [169, 1], [221, 1], [312, 66], [468, 67], [481, 1], [533, 1], [624, 66]]
# total multiplicity of roots:  270
# ------------------------------------------------------------------------
# n:  172  n.digits(prime):  [2, 4, 1, 1]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 69], [169, 1], [221, 1], [312, 68], [468, 69], [481, 1], [533, 1], [624, 68]]
# total multiplicity of roots:  278
# ------------------------------------------------------------------------
# n:  177  n.digits(prime):  [2, 0, 2, 1]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 71], [169, 1], [221, 1], [312, 70], [468, 71], [481, 1], [533, 1], [624, 70]]
# total multiplicity of roots:  286
# ------------------------------------------------------------------------
# n:  182  n.digits(prime):  [2, 1, 2, 1]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 73], [169, 1], [221, 1], [312, 72], [468, 73], [481, 1], [533, 1], [624, 72]]
# total multiplicity of roots:  294
# ------------------------------------------------------------------------
# n:  187  n.digits(prime):  [2, 2, 2, 1]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 75], [169, 1], [221, 1], [312, 74], [468, 75], [481, 1], [533, 1], [624, 74]]
# total multiplicity of roots:  302
# ------------------------------------------------------------------------
# n:  192  n.digits(prime):  [2, 3, 2, 1]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 77], [169, 1], [221, 1], [312, 76], [468, 77], [481, 1], [533, 1], [624, 76]]
# total multiplicity of roots:  310
# ------------------------------------------------------------------------
# n:  197  n.digits(prime):  [2, 4, 2, 1]  sd:  4  prime:  5  n mod prime:  2
# basic roots:
# [156, 169, 221, 312, 468, 481, 533, 624]
# root-logs and multiplicities:
# [[156, 79], [169, 1], [221, 1], [312, 78], [468, 79], [481, 1], [533, 1], [624, 78]]
# total multiplicity of roots:  318
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
#  bad n:  []
# template:  [156, 169, 221, 312, 468, 481, 533, 624]

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=5
residue=3
sdvalue=6
badn=[]
count=0
flag=1
template=[]
for k in [1..200]:
    n=s[k][0]
    if (n>prime-1)&(mod(n,prime)==residue):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
    
        if (sd==sdvalue)&(flag==1):
            template=basicRoots(polynum,prime,sd)
            flag=0
    
        if (sd==sdvalue):
            count=1+count
            br=basicRoots(polynum,prime,sd)
            if br!=template:badn=badn+[n]
            lm=logsAndMultiplicitiesOverField(polynum,prime,sd)
            tm=totalMultiplicityOverField(polynum,prime,sd)
            print "------------------------------------------------------------------------"
            print "n: ",n," n.digits(prime): ",n.digits(prime)," sd: ",sd," prime: ",prime," n mod prime: ",mod(n,prime)
            print "basic roots:";print br
            print "root-logs and multiplicities:";print sorted(lm)
            print "total multiplicity of roots: ",tm
print "&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&"
if count==0:print "null"
print " bad n: ",badn;print "template: ",template
# Out:
# ------------------------------------------------------------------------
# n:  8  n.digits(prime):  [3, 1]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 3], [6993, 1], [7812, 2], [10773, 1], [11529, 1], [11718, 3], [14805, 1], [15624, 2]]
# total multiplicity of roots:  16
# ------------------------------------------------------------------------
# n:  13  n.digits(prime):  [3, 2]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 5], [6993, 1], [7812, 4], [10773, 1], [11529, 1], [11718, 5], [14805, 1], [15624, 4]]
# total multiplicity of roots:  24
# ------------------------------------------------------------------------
# n:  18  n.digits(prime):  [3, 3]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 7], [6993, 1], [7812, 6], [10773, 1], [11529, 1], [11718, 7], [14805, 1], [15624, 6]]
# total multiplicity of roots:  32
# ------------------------------------------------------------------------
# n:  23  n.digits(prime):  [3, 4]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 9], [6993, 1], [7812, 8], [10773, 1], [11529, 1], [11718, 9], [14805, 1], [15624, 8]]
# total multiplicity of roots:  40
# ------------------------------------------------------------------------
# n:  28  n.digits(prime):  [3, 0, 1]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 11], [6993, 1], [7812, 10], [10773, 1], [11529, 1], [11718, 11], [14805, 1], [15624, 10]]
# total multiplicity of roots:  48
# ------------------------------------------------------------------------
# n:  33  n.digits(prime):  [3, 1, 1]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 13], [6993, 1], [7812, 12], [10773, 1], [11529, 1], [11718, 13], [14805, 1], [15624, 12]]
# total multiplicity of roots:  56
# ------------------------------------------------------------------------
# n:  38  n.digits(prime):  [3, 2, 1]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 15], [6993, 1], [7812, 14], [10773, 1], [11529, 1], [11718, 15], [14805, 1], [15624, 14]]
# total multiplicity of roots:  64
# ------------------------------------------------------------------------
# n:  43  n.digits(prime):  [3, 3, 1]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 17], [6993, 1], [7812, 16], [10773, 1], [11529, 1], [11718, 17], [14805, 1], [15624, 16]]
# total multiplicity of roots:  72
# ------------------------------------------------------------------------
# n:  48  n.digits(prime):  [3, 4, 1]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 19], [6993, 1], [7812, 18], [10773, 1], [11529, 1], [11718, 19], [14805, 1], [15624, 18]]
# total multiplicity of roots:  80
# ------------------------------------------------------------------------
# n:  53  n.digits(prime):  [3, 0, 2]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 21], [6993, 1], [7812, 20], [10773, 1], [11529, 1], [11718, 21], [14805, 1], [15624, 20]]
# total multiplicity of roots:  88
# ------------------------------------------------------------------------
# n:  58  n.digits(prime):  [3, 1, 2]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 23], [6993, 1], [7812, 22], [10773, 1], [11529, 1], [11718, 23], [14805, 1], [15624, 22]]
# total multiplicity of roots:  96
# ------------------------------------------------------------------------
# n:  63  n.digits(prime):  [3, 2, 2]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 25], [6993, 1], [7812, 24], [10773, 1], [11529, 1], [11718, 25], [14805, 1], [15624, 24]]
# total multiplicity of roots:  104
# ------------------------------------------------------------------------
# n:  68  n.digits(prime):  [3, 3, 2]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 27], [6993, 1], [7812, 26], [10773, 1], [11529, 1], [11718, 27], [14805, 1], [15624, 26]]
# total multiplicity of roots:  112
# ------------------------------------------------------------------------
# n:  73  n.digits(prime):  [3, 4, 2]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 29], [6993, 1], [7812, 28], [10773, 1], [11529, 1], [11718, 29], [14805, 1], [15624, 28]]
# total multiplicity of roots:  120
# ------------------------------------------------------------------------
# n:  78  n.digits(prime):  [3, 0, 3]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 31], [6993, 1], [7812, 30], [10773, 1], [11529, 1], [11718, 31], [14805, 1], [15624, 30]]
# total multiplicity of roots:  128
# ------------------------------------------------------------------------
# n:  83  n.digits(prime):  [3, 1, 3]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 33], [6993, 1], [7812, 32], [10773, 1], [11529, 1], [11718, 33], [14805, 1], [15624, 32]]
# total multiplicity of roots:  136
# ------------------------------------------------------------------------
# n:  88  n.digits(prime):  [3, 2, 3]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 35], [6993, 1], [7812, 34], [10773, 1], [11529, 1], [11718, 35], [14805, 1], [15624, 34]]
# total multiplicity of roots:  144
# ------------------------------------------------------------------------
# n:  93  n.digits(prime):  [3, 3, 3]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 37], [6993, 1], [7812, 36], [10773, 1], [11529, 1], [11718, 37], [14805, 1], [15624, 36]]
# total multiplicity of roots:  152
# ------------------------------------------------------------------------
# n:  98  n.digits(prime):  [3, 4, 3]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 39], [6993, 1], [7812, 38], [10773, 1], [11529, 1], [11718, 39], [14805, 1], [15624, 38]]
# total multiplicity of roots:  160
# ------------------------------------------------------------------------
# n:  103  n.digits(prime):  [3, 0, 4]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 41], [6993, 1], [7812, 40], [10773, 1], [11529, 1], [11718, 41], [14805, 1], [15624, 40]]
# total multiplicity of roots:  168
# ------------------------------------------------------------------------
# n:  108  n.digits(prime):  [3, 1, 4]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 43], [6993, 1], [7812, 42], [10773, 1], [11529, 1], [11718, 43], [14805, 1], [15624, 42]]
# total multiplicity of roots:  176
# ------------------------------------------------------------------------
# n:  113  n.digits(prime):  [3, 2, 4]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 45], [6993, 1], [7812, 44], [10773, 1], [11529, 1], [11718, 45], [14805, 1], [15624, 44]]
# total multiplicity of roots:  184
# ------------------------------------------------------------------------
# n:  118  n.digits(prime):  [3, 3, 4]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 47], [6993, 1], [7812, 46], [10773, 1], [11529, 1], [11718, 47], [14805, 1], [15624, 46]]
# total multiplicity of roots:  192
# ------------------------------------------------------------------------
# n:  123  n.digits(prime):  [3, 4, 4]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 49], [6993, 1], [7812, 48], [10773, 1], [11529, 1], [11718, 49], [14805, 1], [15624, 48]]
# total multiplicity of roots:  200
# ------------------------------------------------------------------------
# n:  128  n.digits(prime):  [3, 0, 0, 1]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 51], [6993, 1], [7812, 50], [10773, 1], [11529, 1], [11718, 51], [14805, 1], [15624, 50]]
# total multiplicity of roots:  208
# ------------------------------------------------------------------------
# n:  133  n.digits(prime):  [3, 1, 0, 1]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 53], [6993, 1], [7812, 52], [10773, 1], [11529, 1], [11718, 53], [14805, 1], [15624, 52]]
# total multiplicity of roots:  216
# ------------------------------------------------------------------------
# n:  138  n.digits(prime):  [3, 2, 0, 1]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 55], [6993, 1], [7812, 54], [10773, 1], [11529, 1], [11718, 55], [14805, 1], [15624, 54]]
# total multiplicity of roots:  224
# ------------------------------------------------------------------------
# n:  143  n.digits(prime):  [3, 3, 0, 1]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 57], [6993, 1], [7812, 56], [10773, 1], [11529, 1], [11718, 57], [14805, 1], [15624, 56]]
# total multiplicity of roots:  232
# ------------------------------------------------------------------------
# n:  148  n.digits(prime):  [3, 4, 0, 1]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 59], [6993, 1], [7812, 58], [10773, 1], [11529, 1], [11718, 59], [14805, 1], [15624, 58]]
# total multiplicity of roots:  240
# ------------------------------------------------------------------------
# n:  153  n.digits(prime):  [3, 0, 1, 1]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 61], [6993, 1], [7812, 60], [10773, 1], [11529, 1], [11718, 61], [14805, 1], [15624, 60]]
# total multiplicity of roots:  248
# ------------------------------------------------------------------------
# n:  158  n.digits(prime):  [3, 1, 1, 1]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 63], [6993, 1], [7812, 62], [10773, 1], [11529, 1], [11718, 63], [14805, 1], [15624, 62]]
# total multiplicity of roots:  256
# ------------------------------------------------------------------------
# n:  163  n.digits(prime):  [3, 2, 1, 1]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 65], [6993, 1], [7812, 64], [10773, 1], [11529, 1], [11718, 65], [14805, 1], [15624, 64]]
# total multiplicity of roots:  264
# ------------------------------------------------------------------------
# n:  168  n.digits(prime):  [3, 3, 1, 1]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 67], [6993, 1], [7812, 66], [10773, 1], [11529, 1], [11718, 67], [14805, 1], [15624, 66]]
# total multiplicity of roots:  272
# ------------------------------------------------------------------------
# n:  173  n.digits(prime):  [3, 4, 1, 1]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 69], [6993, 1], [7812, 68], [10773, 1], [11529, 1], [11718, 69], [14805, 1], [15624, 68]]
# total multiplicity of roots:  280
# ------------------------------------------------------------------------
# n:  178  n.digits(prime):  [3, 0, 2, 1]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 71], [6993, 1], [7812, 70], [10773, 1], [11529, 1], [11718, 71], [14805, 1], [15624, 70]]
# total multiplicity of roots:  288
# ------------------------------------------------------------------------
# n:  183  n.digits(prime):  [3, 1, 2, 1]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 73], [6993, 1], [7812, 72], [10773, 1], [11529, 1], [11718, 73], [14805, 1], [15624, 72]]
# total multiplicity of roots:  296
# ------------------------------------------------------------------------
# n:  188  n.digits(prime):  [3, 2, 2, 1]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 75], [6993, 1], [7812, 74], [10773, 1], [11529, 1], [11718, 75], [14805, 1], [15624, 74]]
# total multiplicity of roots:  304
# ------------------------------------------------------------------------
# n:  193  n.digits(prime):  [3, 3, 2, 1]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 77], [6993, 1], [7812, 76], [10773, 1], [11529, 1], [11718, 77], [14805, 1], [15624, 76]]
# total multiplicity of roots:  312
# ------------------------------------------------------------------------
# n:  198  n.digits(prime):  [3, 4, 2, 1]  sd:  6  prime:  5  n mod prime:  3
# basic roots:
# [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]
# root-logs and multiplicities:
# [[2961, 1], [3717, 1], [3906, 79], [6993, 1], [7812, 78], [10773, 1], [11529, 1], [11718, 79], [14805, 1], [15624, 78]]
# total multiplicity of roots:  320
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
#  bad n:  []
# template:  [2961, 3717, 3906, 6993, 7812, 10773, 11529, 11718, 15624]

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=5
residue=4
sdvalue=1
badn=[]
count=0
flag=1
template=[]
for k in [1..200]:
    n=s[k][0]
    if (n>prime-1)&(mod(n,prime)==residue):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
    
        if (sd==sdvalue)&(flag==1):
            template=basicRoots(polynum,prime,sd)
            flag=0
    
        if (sd==sdvalue):
            count=1+count
            br=basicRoots(polynum,prime,sd)
            if br!=template:badn=badn+[n]
            lm=logsAndMultiplicitiesOverField(polynum,prime,sd)
            tm=totalMultiplicityOverField(polynum,prime,sd)
            print "------------------------------------------------------------------------"
            print "n: ",n," n.digits(prime): ",n.digits(prime)," sd: ",sd," prime: ",prime," n mod prime: ",mod(n,prime)
            print "basic roots:";print br
            print "root-logs and multiplicities:";print sorted(lm)
            print "total multiplicity of roots: ",tm
print "&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&"
if count==0:print "null"
print " bad n: ",badn;print "template: ",template
# Out:
# ------------------------------------------------------------------------
# n:  9  n.digits(prime):  [4, 1]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 4], [2, 4], [3, 4], [4, 4]]
# total multiplicity of roots:  16
# ------------------------------------------------------------------------
# n:  14  n.digits(prime):  [4, 2]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 6], [2, 6], [3, 6], [4, 6]]
# total multiplicity of roots:  24
# ------------------------------------------------------------------------
# n:  19  n.digits(prime):  [4, 3]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 8], [2, 8], [3, 8], [4, 8]]
# total multiplicity of roots:  32
# ------------------------------------------------------------------------
# n:  24  n.digits(prime):  [4, 4]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 10], [2, 10], [3, 10], [4, 10]]
# total multiplicity of roots:  40
# ------------------------------------------------------------------------
# n:  29  n.digits(prime):  [4, 0, 1]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 12], [2, 12], [3, 12], [4, 12]]
# total multiplicity of roots:  48
# ------------------------------------------------------------------------
# n:  34  n.digits(prime):  [4, 1, 1]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 14], [2, 14], [3, 14], [4, 14]]
# total multiplicity of roots:  56
# ------------------------------------------------------------------------
# n:  39  n.digits(prime):  [4, 2, 1]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 16], [2, 16], [3, 16], [4, 16]]
# total multiplicity of roots:  64
# ------------------------------------------------------------------------
# n:  44  n.digits(prime):  [4, 3, 1]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 18], [2, 18], [3, 18], [4, 18]]
# total multiplicity of roots:  72
# ------------------------------------------------------------------------
# n:  49  n.digits(prime):  [4, 4, 1]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 20], [2, 20], [3, 20], [4, 20]]
# total multiplicity of roots:  80
# ------------------------------------------------------------------------
# n:  54  n.digits(prime):  [4, 0, 2]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 22], [2, 22], [3, 22], [4, 22]]
# total multiplicity of roots:  88
# ------------------------------------------------------------------------
# n:  59  n.digits(prime):  [4, 1, 2]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 24], [2, 24], [3, 24], [4, 24]]
# total multiplicity of roots:  96
# ------------------------------------------------------------------------
# n:  64  n.digits(prime):  [4, 2, 2]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 26], [2, 26], [3, 26], [4, 26]]
# total multiplicity of roots:  104
# ------------------------------------------------------------------------
# n:  69  n.digits(prime):  [4, 3, 2]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 28], [2, 28], [3, 28], [4, 28]]
# total multiplicity of roots:  112
# ------------------------------------------------------------------------
# n:  74  n.digits(prime):  [4, 4, 2]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 30], [2, 30], [3, 30], [4, 30]]
# total multiplicity of roots:  120
# ------------------------------------------------------------------------
# n:  79  n.digits(prime):  [4, 0, 3]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 32], [2, 32], [3, 32], [4, 32]]
# total multiplicity of roots:  128
# ------------------------------------------------------------------------
# n:  84  n.digits(prime):  [4, 1, 3]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 34], [2, 34], [3, 34], [4, 34]]
# total multiplicity of roots:  136
# ------------------------------------------------------------------------
# n:  89  n.digits(prime):  [4, 2, 3]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 36], [2, 36], [3, 36], [4, 36]]
# total multiplicity of roots:  144
# ------------------------------------------------------------------------
# n:  94  n.digits(prime):  [4, 3, 3]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 38], [2, 38], [3, 38], [4, 38]]
# total multiplicity of roots:  152
# ------------------------------------------------------------------------
# n:  99  n.digits(prime):  [4, 4, 3]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 40], [2, 40], [3, 40], [4, 40]]
# total multiplicity of roots:  160
# ------------------------------------------------------------------------
# n:  104  n.digits(prime):  [4, 0, 4]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 42], [2, 42], [3, 42], [4, 42]]
# total multiplicity of roots:  168
# ------------------------------------------------------------------------
# n:  109  n.digits(prime):  [4, 1, 4]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 44], [2, 44], [3, 44], [4, 44]]
# total multiplicity of roots:  176
# ------------------------------------------------------------------------
# n:  114  n.digits(prime):  [4, 2, 4]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 46], [2, 46], [3, 46], [4, 46]]
# total multiplicity of roots:  184
# ------------------------------------------------------------------------
# n:  119  n.digits(prime):  [4, 3, 4]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 48], [2, 48], [3, 48], [4, 48]]
# total multiplicity of roots:  192
# ------------------------------------------------------------------------
# n:  124  n.digits(prime):  [4, 4, 4]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 50], [2, 50], [3, 50], [4, 50]]
# total multiplicity of roots:  200
# ------------------------------------------------------------------------
# n:  129  n.digits(prime):  [4, 0, 0, 1]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 52], [2, 52], [3, 52], [4, 52]]
# total multiplicity of roots:  208
# ------------------------------------------------------------------------
# n:  134  n.digits(prime):  [4, 1, 0, 1]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 54], [2, 54], [3, 54], [4, 54]]
# total multiplicity of roots:  216
# ------------------------------------------------------------------------
# n:  139  n.digits(prime):  [4, 2, 0, 1]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 56], [2, 56], [3, 56], [4, 56]]
# total multiplicity of roots:  224
# ------------------------------------------------------------------------
# n:  144  n.digits(prime):  [4, 3, 0, 1]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 58], [2, 58], [3, 58], [4, 58]]
# total multiplicity of roots:  232
# ------------------------------------------------------------------------
# n:  149  n.digits(prime):  [4, 4, 0, 1]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 60], [2, 60], [3, 60], [4, 60]]
# total multiplicity of roots:  240
# ------------------------------------------------------------------------
# n:  154  n.digits(prime):  [4, 0, 1, 1]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 62], [2, 62], [3, 62], [4, 62]]
# total multiplicity of roots:  248
# ------------------------------------------------------------------------
# n:  159  n.digits(prime):  [4, 1, 1, 1]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 64], [2, 64], [3, 64], [4, 64]]
# total multiplicity of roots:  256
# ------------------------------------------------------------------------
# n:  164  n.digits(prime):  [4, 2, 1, 1]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 66], [2, 66], [3, 66], [4, 66]]
# total multiplicity of roots:  264
# ------------------------------------------------------------------------
# n:  169  n.digits(prime):  [4, 3, 1, 1]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 68], [2, 68], [3, 68], [4, 68]]
# total multiplicity of roots:  272
# ------------------------------------------------------------------------
# n:  174  n.digits(prime):  [4, 4, 1, 1]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 70], [2, 70], [3, 70], [4, 70]]
# total multiplicity of roots:  280
# ------------------------------------------------------------------------
# n:  179  n.digits(prime):  [4, 0, 2, 1]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 72], [2, 72], [3, 72], [4, 72]]
# total multiplicity of roots:  288
# ------------------------------------------------------------------------
# n:  184  n.digits(prime):  [4, 1, 2, 1]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 74], [2, 74], [3, 74], [4, 74]]
# total multiplicity of roots:  296
# ------------------------------------------------------------------------
# n:  189  n.digits(prime):  [4, 2, 2, 1]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 76], [2, 76], [3, 76], [4, 76]]
# total multiplicity of roots:  304
# ------------------------------------------------------------------------
# n:  194  n.digits(prime):  [4, 3, 2, 1]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 78], [2, 78], [3, 78], [4, 78]]
# total multiplicity of roots:  312
# ------------------------------------------------------------------------
# n:  199  n.digits(prime):  [4, 4, 2, 1]  sd:  1  prime:  5  n mod prime:  4
# basic roots:
# [1, 2, 3, 4]
# root-logs and multiplicities:
# [[1, 80], [2, 80], [3, 80], [4, 80]]
# total multiplicity of roots:  320
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
#  bad n:  []
# template:  [1, 2, 3, 4]
