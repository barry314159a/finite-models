# %%
P = Primes()
ZR.<x> = PolynomialRing(ZZ)
D.<x> = PolynomialRing(QQ)
R.<x> = PolynomialRing(QQ)
C.<x> = PolynomialRing(CC)
S = PowerSeriesRing(QQ,'x', default_prec=300)
#S.<x,y>=PowerSeriesRing(QQ,default_prec=300)
# Using "R = PolynomialRing(QQ,'x')" produces an error.
# Yet using S as defined here is fine (see definition of Fraleigh4 below)
# But S = PowerSeriesRing(QQ,'x','y') also produces an error.
def pochhammer(x,n):
    return product ([x+k for k in [0..n-1]])
def cRaleigh2(alpha,beta,nu):
    pchhmrA = pochhammer(alpha,nu)
    pchhmrB = pochhammer(beta,nu)
    fnu=factorial(nu)
    answer = D(pchhmrA*pchhmrB/fnu^2)
    return answer
def term(alpha,beta,p):
    return D(1/(alpha + p) + 1/(beta + p) - 2/(1 + p))
def eRaleigh(alpha, beta, nu):
    return D(sum([term(alpha, beta, p) for p in [0..nu - 1]]))
def FstarRaleigh2(alpha,beta,u,terms):
    fsr = sum([cRaleigh2(alpha, beta, nu)*eRaleigh(alpha,beta,nu)*u^nu for nu in [1..terms]])
    return D(fsr)
def Fraleigh2(alpha,beta,u,terms): 
    return D(sum([cRaleigh2(alpha,beta,nu)*u^nu for nu in [0..terms]]))
def FstarRaleigh3(n,m,x):
    alpha = (1/2-1/m)/2
    beta = (1/2+1/m)/2
    fsr2 = FstarRaleigh2(alpha,beta,x,n)
    return D(fsr2)
def Fraleigh4(n,m,x):
    alpha = (1/2-1/m)/2
    beta = (1/2+1/m)/2
    fr2 = Fraleigh2(alpha,beta,x,n)
    return D(fr2)
def exNo3c(n,m):
    a1 = S(x)*exp(S(FstarRaleigh3(n,m,x)/Fraleigh4(n,m,x))).O(2*n)
    # S(x) instead of x in df of a1 to avoid an error message
    # after use of the stripQuotationMarks command below.
    a2 = S(a1).O(n+1)
    return a2 # applying S to argument of exp is key.
def J(n,m):
    exn = exNo3c(n+2,m)
    jnm = 1/exn.reverse()
    return jnm.O(n+1) # Jtest is faster than J, and they agree.
def normalJ(n,m):
    f = J(n,m)
    return f.truncate(n+1)
def Jcoefficient(n,m,x):
    f = J(n+2,m,x)
    f1 = f.truncate(n+1)
    f1=f1.list()
    f1=Set(f1)
    g1 = f.truncate(n)
    g1 = g1.list()
    g1 = set(g1)
    h = f1.difference(g1)
    h = h.list()
    return h[0]
def xjNewStep(n,m,x): 
    f=J(n,m,x)
    fl=f.list()
    return (sum(c*x**i*(m**3*2**6)**i for i,c in enumerate(fl)))
def xjNew(n,m,x):
    return xjNewStep(n-1,m,x)
def xjNewCoefficient(n,m,x):
    if n>0:return (xjNew(n,m,x)-xjNew(n-1,m,x))/x^n
    if n==0:return 1
def xjNewTest(n,m,x):
    return D(xjNewStep(n-1,m,x))
def polynomialCoefficient(n,poly):
    return poly.list()[n]
def factorpairToFactor(factorpair):
    (monomial,exponent)=factorpair
    return monomial^exponent
def numericalfactor(polynomial):
    fp=polynomial.factor()
    lst=[factorpairToFactor(factorpair) for factorpair in fp]
    return polynomial/product(lst)
def lastfactor(polynomial):
    fp=polynomial.factor()
    fp=FiniteEnumeratedSet(fp)
    return factorpairToFactor(fp.last())
def reduced(polynomial):
    return numericalfactor(polynomial)*lastfactor(polynomial)
def stripQuotationMarks(string):
    var('x')
    return sage_eval(string,locals={'x':x})

def prime_n(a):return P.unrank(a-1)

def primeFactors(n):
    answer=[]
    lf=list(n.factor())
    length=len(lf)
    for k in [0..length-1]:
        pair=lf[k]
        (base,exponent)=pair
        answer=answer+[[base]]
    return(flatten(answer))

def primeFactorsInList(lst):
    ld=len(lst)
    primelist=[]
    for k in [0..ld-1]:
        a=ZZ(lst[k])
        primelist=primelist+[primeFactors(a)]
    primelist=flatten(primelist)
    primelist=list(set(primelist))
    return primelist

def den(a):
    if a in QQ:
        if a in ZZ:return 1
        return a.denominator()
def listdens(lst):
    return list(den(a) for a in lst)
def polynomialdenominator(poly):return lcm(listdens(poly))
def polynomialnumerator(poly):
    return expand(poly*polynomialdenominator(poly))
def num(a):return a.numerator()
def prime(n):
    P=Primes()
    return P.unrank(n-1)
def inclusiveListPrimesTo(n):
    if is_prime(n):
        return list(primes(n+1))
    else:
        return list(primes(n))
def chunk(k,list):
    chnk=[]
    for n in [k..len(list)-1]:
        chnk=chnk+[list[n]]
    return chnk
def drop(m,lst): return list(Set(lst).difference({m}))
def sort(list):
    answr=[]
    chnk=list
    for n in [0..len(list)-1]:
        m = min(chnk)
        answr=answr+[m]
        chnk=drop(m,chnk)
    return answr
def ord(p,n):return QQ.valuation(p)(n)
def base_conversion(number, base_from, base_to):  # by Vishnu Namboothiri
# https://ask.sagemath.org/question/9657/how-to-output-decimal-numbers-in-different-radix/
    if(base_from==10):
        return stripQuotationMarks((number.str(base=base_to)))
    else:
        decimal = Integer(str(number), base=base_from)
        return (stripQuotationMarks(decimal.str(base=base_to)))
def lastFactorWithIntegralFactors(polynomial):
    return polynomialnumerator(lastfactor(polynomial))
def numericalFactorWithIntegralFactors(polynomial):
    nf=numericalfactor(polynomial);
    pd=polynomialdenominator(lastfactor(polynomial))
    return nf/pd


def primeDivisors(n):
    pd=[]
    n=n
    fn=factor(n)
    ln=len(fn)
    for k in [0..ln-1]:
        part = fn[k]
        (prime,exponent) = part
        pd = pd + [prime]
    return pd 
def fOverField(f,prime,power):
    answer=[]
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    ppoly = U(f)
    expr=str(ppoly)
    var('x')
    fp=ppoly.factor()
    return ppoly

###################### following two routines disagree ####################
def factorOverField(f,prime,power):
    answer=[]
    T = GF(prime^power,'t')
    G.<t>= GF(prime^power)
    U.<x> = T[]
    ppoly = U(f)
    expr=str(ppoly)
    var('x')
    fp=ppoly.factor()
    return fp

def factorOverField2(poly,prime,power,j):
    sd = leastSplittingDegree(poly,prime,bound)
    T=GF(prime^j)
    G.<t>= GF(prime^sd)
    U.<x> = T[]
    ppoly=U(poly)
    fpp=ppoly.factor()
    return fpp

############################

#######################################################
# splitting tests below fail at  e.g. f = x + 1 
############################################################

def splitsTF(f,prime,power):
    T = GF(prime^power)
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx > 1:return(False)
    return(True)

def leastSplittingDegree(f,prime,bound):
    for power in [1..bound]:
        tf=splitsTF(f,prime,power)
        if tf == True:return power
    return -1

#########################################################

def firstNprimes(n):
    P=Primes()
    first=[]
    for k in [0..n-1]:
        first=first+[P.unrank(k)]
    return first

def slopeExistsTF(pairlist):
    lenth=len(pairlist)
    if lenth<3:return False
    slopes=[]
    for k in [1..lenth-1]:
        pair1=pairlist[k-1]
        abscissa1=pair1[0]
        ordinate1=pair1[1]
        pair2=pairlist[k]
        abscissa2=pair2[0]
        ordinate2=pair2[1]
        dx=abscissa2-abscissa1
        if dx == 0:return False
        dy=ordinate2-ordinate1
        slope=dy/dx
        slopes=slopes+[slope]
    slopes=Set(slopes)
    if len(slopes) == 1:
        return [True,slopes[0]]
    if len(slopes) > 1:
        return False 
    
def zeroOfLinearMonomial(monomial,x):return x-monomial

def totalDegreeOverField(f,prime,power):
    T = GF(prime^power,'t')
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    td=0
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        td=td+exponent
    return td

def logsAndMultiplicitiesOverField(f,prime,power):
    T = GF(prime^power,'t')
    b=T.multiplicative_generator()
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    data=[]
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx == 1:
            xm=x-monomial
            if xm==0:data=data+[[-1,exponent]]
            if xm != 0:
                for i in [1..prime^power-1]:
                    if b^i==xm:data=data+[[i,exponent]]
    return data

def generatingZeroLogsOverField(f,prime,power):
    T = GF(prime^power,'t')
    b=T.multiplicative_generator()
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    data=[]
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx == 1:
            xm=x-monomial
            if xm==0:data=data+[[-1,exponent]]
            if xm != 0:
                for i in [1..prime^power-1]:
                    if b^i==xm:
                        if mod(i,prime)>0:
                            data=data+[i]
    data=data.sort()
    return data



def generatingZeroLogsAndMultiplicitiesOverField(f,prime,power):
    T = GF(prime^power,'t')
    b=T.multiplicative_generator()
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    data=[]
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx == 1:
            xm=x-monomial
            if xm==0:data=data+[[-1,exponent]]
            if xm != 0:
                for i in [1..prime^power-1]:
                    if b^i==xm:
                        if mod(i,prime)>0:
                            data=data+[[i,exponent]]
    return data




def logsAndMultiplicitiesOverFieldTest(f,prime,power):
    T = GF(prime^power,'t')
    b=T.multiplicative_generator()
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    print gf
    lnf = len(gf)-1
    data=[]
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx == 1:
            xm=x-monomial
            if xm==0:data=data+[[-1,exponent]]
            if xm != 0:
                for i in [1..prime^power-1]:
                    if b^i==xm:data=data+[[i,exponent]]
    return data

def logsAndMultiplicitiesOverFieldTest(f,prime,power):
    T = GF(prime^power,'t')
    b=T.multiplicative_generator()
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    print gf
    lnf = len(gf)-1
    data=[]
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx == 1:
            xm=x-monomial
            if xm==0:data=data+[[-1,exponent]]
            if xm != 0:
                for i in [1..prime^power-1]:
                    if b^i==xm:data=data+[[i,exponent]]
    return data



def dropzeros(list):
    data=[]
    el=len(list)
    for j  in [0..el-1]:
        lj=list[j]
        if lj != 0:data=data+[lj]
    return data

def padListOnRightToLengthK(listo,k):
    length=len(listo)
    padded=listo
   
    if length<k:
        for j in [length..k-1]:
            padded=padded+[0]
           
        return padded
    return listo

def testCandidateZeroLogOverField(f,prime,power,candidate):
    tf=False
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    poly = U(f)
    expr=str(poly)
    var('x')
    a=t^candidate
    expr3=sage_eval(expr,locals={'x':a})
    if expr3 == 0:tf=True
    return tf

def digitsToInteger(digitlist,prime):
    lenth=len(digitlist)
    sum=0
    for k in [0..lenth-1]:
        sum=sum+prime^k*digitlist[k]
    return sum

def minimumIntegerRepresentedInList(lstlst,prime):
    answer=Infinity
    ln=len(lstlst)
    for k in [0..ln-1]:
        lst=lstlst[k]
        n=digitsToInteger(lst,prime)
        if n < answer:answer=n
    return answer

def lastElement(lst):
    ln=len(lst)
    return lst[ln-1]

def push(lst):
    if len(lst)<2:return lst
    answer=[lastElement(lst)]
    for k in [0..len(lst)-2]:
        answer=flatten([answer]+[lst[k]])
    return answer

def cyclicPermutationEquivalenceClass(lst):
    if lst==[]:return lst
    answer=[lst]
    lnth=len(lst)
    for k in [0..lnth-2]:
        ple=push(lastElement(answer))
        answer=answer+[ple]
    return answer

def bestRepresentativeOfCyclicEquivalenceClass(lst,prime):
    cpec=cyclicPermutationEquivalenceClass(lst)
    minm=minimumIntegerRepresentedInList(cpec,prime)
    lcpec=len(lst) # ... = len(cpec)
    for k in [0..lcpec-1]:
        ck=cpec[k]
        dti=digitsToInteger(ck,prime)
        if minm==dti:return ck
    return "error"

def directZeroLogOverField(f,prime,power):
    tf=False
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    poly = U(f)
    expr=str(poly)
    var('x')
    answer=[]
    expr3=sage_eval(expr,locals={'x':0})
    if expr3 == 0:
        answer=[0]
    for i in [1..prime^power-1]:
        a=t^i
        expr3=sage_eval(expr,locals={'x':a})
        if expr3 == 0:
            answer=answer+[i]
    return answer

def reduce(f,prime):
    poly=polynomialnumerator(D(f))
    
    ls=list(poly)
    
    def modulo(n):
        return ZZ(mod(n,prime))
    def listmod(list):
        return map(modulo,list)
    lmls = listmod(ls)
    sm=0
    for j in [0..len(lmls)-1]:
        sm=sm+lmls[j]*x^j
    return sm


mt=[ #McKay-Thompson series w. a(0) = 24.
[-1, 1],
[0, 24],
[1, 276],
[2, 2048],
[3, 11202],
[4, 49152],
[5, 184024],
[6, 614400],
[7, 1881471],
[8, 5373952],
[9, 14478180],
[10, 37122048],
[11, 91231550],
[12, 216072192],
[13, 495248952],
[14, 1102430208],
[15, 2390434947],
[16, 5061476352],
[17, 10487167336],
[18, 21301241856],
[19, 42481784514],
[20, 83300614144],
[21, 160791890304],
[22, 305854488576],
[23, 573872089212],
[24, 1063005978624],
[25,1945403602764],
[26, 3519965179904],
[27, 6300794030460],
[28, 11164248047616],
[29, 19591528119288],
[30, 34065932304384],
[31, 58718797964805],
[32, 100372723007488],
[33, 170215559855424],
[34, 286470013685760],
[35, 478625723149576],
[36, 794110053826560],
[37, 1308745319975256],
[38, 2143055278039040],
[39, 3487563372381816],
[40, 5641848336678912],
[41, 9074553043554568],
[42, 14515166263443456],
[43, 23093778743102262],
[44, 36552977852071936],
[45, 57567784186189368],
[46, 90226777113575424],
[47, 140752796480416011],
[48, 218578429975461888],
[49, 337945040343588276],
[50, 520271697765971968],
[51, 797652526220573580],
[52, 1218002527825723392],
[53, 1852604006634050072],
[54, 2807138079496716288],
[55, 4237760460302936433],
[56, 6374456847628238848],
[57, 9554873766107770560],
[58, 14273181657059143680],
[59, 21250450411204068910],
[60, 31535729115847852032],
[61, 46650835290143061624],
[62, 68797209365301886976],
[63, 101150679669913197462],
[64, 148280443106626633728],
[65, 216743142763626253712],
[66, 315923191441199824896],
[67, 459218611940943755226],
[68, 665710603285072019456],
[69, 962508846974918603904],
[70, 1388038765923851599872],
[71, 1996639069403279491427],
[72, 2864978197116521938944],
[73, 4100990608911708903432],
[74, 5856297079648098807808],
[75, 8343432715970391209502],
[76, 11859696700297921757184],
[77, 16820105145987654631552],
[78, 23802835313046730063872],
[79, 33611779636250175278886],
[80, 47362494062244172660736],
[81, 66600077798590855556532],
[82, 93460562353103053049856],
[83, 130891485964083426534122],
[84, 182952844329494181838848],
[85, 255227018229957765044016],
[86, 355376219286719031156736],
[87, 493899311443420857952845],
[88, 685157678128482627354624],
[89, 948763597225844233250504],
[90, 1311456320500974276980736],
[91, 1809633323386495729057992],
[92, 2492760414984152205361152],
[93, 3427959082742197097793024],
[94, 4706168520874397834575872],
[95, 6450411048962389429976770],
[96, 8826863296640622526464000],
[97, 12059665023346371597383976],
[98, 16450700321708764061517824],
[99, 22405985191605778318221966],
[100, 30470821082605141257437184]]

def sumOfRoots(f,prime,power):
    answer=0
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    #U.<x> = T[] -- this line gave an error
    poly = U(f)
    expr=str(poly)
    var('x')
    for i in [1..prime^power-1]:
        a=t^i
        expr3=sage_eval(expr,locals={'x':a})
        if expr3 == 0:
            answer=answer+a
    return answer

def productOfNonzeroRoots(f,prime,power):
    answer=1
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    #U.<x> = T[] -- this line gave an error
    poly = U(f)
    expr=str(poly)
    var('x')
    for i in [1..prime^power-1]:
        a=t^i
        expr3=sage_eval(expr,locals={'x':a})
        if expr3 == 0:
            answer=answer*a
    return answer

def roots(f,prime,power):
    answer=[]
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    #U.<x> = T[] -- this line gave an error
    poly = U(f)
    expr=str(poly)
    var('x')
    expr3=sage_eval(expr,locals={'x':0})
    if expr3==0:answer=answer+[0]
    for i in [1..prime^power-1]:
        a=t^i
        expr3=sage_eval(expr,locals={'x':a})
        if expr3 == 0:
            answer=answer+[a]
    return answer

def numericalTermOverFieldNoPrint(f,prime,power):
    T = GF(prime^power,'t')
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    xproduct=1
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        xproduct=xproduct*monomial^exponent
    return g/xproduct

def polynomialDegree(poly):
    return len(poly.list())-1

def leadingCoefficient(poly):
    dp=D(poly)
    deg=polynomialDegree(dp)
    return dp.list()[deg]

def testRootLogTimesPrimeCn(f,prime,power):
    tf=True
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    poly = U(f)
    expr=str(poly)
    var('x')
    fp=poly.factor()
    lnf = len(fp) - 1
    flag = 1
    for i in [1..prime^power-1]:
        a=t^i
        expr3=sage_eval(expr,locals={'x':a})
        if expr3 == 0:
            j=i*prime
            b=t^j
            expr4=sage_eval(expr,locals={'x':b})
            if expr4!=0:
                tf=False
                print (i,j)
                
    return tf

def basicRoots(f,prime,power):
    answer=[]
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    poly = U(f)
    expr=str(poly)
    var('x')
    fp=poly.factor()
    lnf = len(fp) - 1
    flag = 1
    for i in [1..prime^power-1]:
        if mod(i,prime)!=0:
            a=t^i
            expr3=sage_eval(expr,locals={'x':a})
            if expr3 == 0:answer=answer+[i]
    return answer

def basicRootsDigits(f,prime,power):
    answer=[]
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    poly = U(f)
    expr=str(poly)
    var('x')
    fp=poly.factor()
    lnf = len(fp) - 1
    flag = 1
    for i in [1..prime^power-1]:
        if mod(i,prime)!=0:
            a=t^i
            expr3=sage_eval(expr,locals={'x':a})
            if expr3 == 0:answer=answer+[padListOnRightToLengthK(i.digits(prime),power)]
    return answer

def basicLogsAndMultiplicitiesOverField(f,prime,power):
    T = GF(prime^power,'t')
    b=T.multiplicative_generator()
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    data=[]
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx == 1:
            xm=x-monomial
            if xm==0:data=data+[[-1,exponent]]
            if xm != 0:
                for i in [1..prime^power-1]:
                    if mod(i,prime)!=0:
                        if b^i==xm:data=data+[[i,exponent]]
    return data.sort()

def totalMultiplicityOverField(f,prime,power):
    tm=0
    T = GF(prime^power,'t')
    b=T.multiplicative_generator()
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    data=[]
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx == 1:tm=tm+exponent
    return tm

def testRootLogTimesPrimeCn(f,prime,power):
    tf=True
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    poly = U(f)
    expr=str(poly)
    var('x')
    fp=poly.factor()
    lnf = len(fp) - 1
    flag = 1
    for i in [1..prime^power-1]:
        a=t^i
        expr3=sage_eval(expr,locals={'x':a})
        if expr3 == 0:
            j=i*prime
            b=t^j
            expr4=sage_eval(expr,locals={'x':b})
            if expr4!=0:
                tf=False
                print (i,j)
                
    return tf

def roots(f,prime,power):
    answer=[]
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    expr=str(f)
    var('x')
    expr3=sage_eval(expr,locals={'x':0})
    if expr3 == 0:
        answer=answer+[0]
    for i in [1..prime^power]:
        a=t^i
        expr3=sage_eval(expr,locals={'x':a})
        if expr3 == 0:
            answer=answer+[a]
    return Set(answer)

# %%
## printed output has been snipped

import pickle
wfile=open('/Users/barrybrent/run1jun21no1.txt','a')
data=[]
for m in [3..500]:
    print m
    data=data+[[m,normalJ(200,m)]]
s=pickle.dumps(str(data))
wfile.write(s)
wfile.close()
#########################
import pickle
rfile = open('/Users/barrybrent/run1jun21no1.txt','r')
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)

polydata=[]

wfile = open('/Users/barrybrent/run14jun21no14.txt','a') # xJ polynomials
for n in [0..200]:
    data=[]
    for k in [0..2*n+1]:
        print (n,k)
        m = s[k][0]
        poly=x*s[k][1] 
        cf=polynomialCoefficient(n,poly)
        data=data+[[m,cf*m^(2*n)]]
    rl=R.lagrange_polynomial(data)
    polydata=polydata+[[n-1,rl]] 

    
t = pickle.dumps(str(polydata))
wfile.write(t)
wfile.close() # print-output snippeds
for n in [0..200]:
    data=[]
    for k in [0..2*n+1]:
        print (n,k)
        m = s[k][0]
        poly=x*s[k][1] 
        cf=polynomialCoefficient(n,poly)
        data=data+[[m,cf*m^(2*n)]]
    rl=R.lagrange_polynomial(data)
    polydata=polydata+[[n-1,rl]] 

    
t = pickle.dumps(str(polydata))
wfile.write(t)
wfile.close() # print-output snipped

# %% [markdown]
# sum

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') #Jfn
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
len(s)
# Out:
# 201

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=7
pairs=[]
for k in [1..200]:
    n=s[k][0]
    if (1==1)&(n>prime):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
        pair=(mod(n,prime),sd)
        pairs=pairs+[pair]
print sort(union(pairs))
# Out:
# [(0, 4), (1, 4), (2, 2), (3, 2), (4, 6), (5, 5), (6, 1)]

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=7
residue=0
sdvalue=4
size=prime^sdvalue
badn=[]
count=0
template=Set([1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 
3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 
6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t])
for k in [1..200]:
    n=s[k][0]
    if (1==1):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
        
        if (sd==sdvalue)&(mod(n,prime)==residue):
            count=1+count
            T = GF(size,'t')
            t=T.multiplicative_generator()
            U.<x> = T[]
            g=U(polynum)
            fg=g.factor()
            roots=[]
            expr=str(g)
            var('x')
            expr3=sage_eval(expr,locals={'x':0})
            if expr3==0:
                roots=roots+[0]
            for i in [1..size]:
                a=t^i
                expr3=sage_eval(expr,locals={'x':a})
                if expr3==0:
                    roots=roots+[t^i]
            roots=Set(roots)
            if roots!=template:
                badn=badn+[n]
            print "------------------------------------------------------------------------"
            print "n: ",n," n.digits(prime): ",n.digits(prime)," sd: ",sd," prime: ",prime
            print "factored model:";print fg;print
            print "template: ",template
            print "roots:",roots
print "&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&"
if count==0:print "null"
print " bad n: ",badn
# Out:
# ------------------------------------------------------------------------
# n:  7  n.digits(prime):  [0, 1]  sd:  4  prime:  7
# factored model:
# (3) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 2)^2 * (x + 5)^2 * (x + 3)^3 * (x + 4)^3
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {2, 3, 4, 5, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  14  n.digits(prime):  [0, 2]  sd:  4  prime:  7
# factored model:
# (4) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^2 * (x + 6)^2 * (x + 2)^4 * (x + 5)^4 * (x + 3)^5 * (x + 4)^5
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  21  n.digits(prime):  [0, 3]  sd:  4  prime:  7
# factored model:
# (4) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^4 * (x + 6)^4 * (x + 2)^6 * (x + 5)^6 * (x + 3)^7 * (x + 4)^7
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  28  n.digits(prime):  [0, 4]  sd:  4  prime:  7
# factored model:
# (4) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^6 * (x + 6)^6 * (x + 2)^8 * (x + 5)^8 * (x + 3)^9 * (x + 4)^9
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  35  n.digits(prime):  [0, 5]  sd:  4  prime:  7
# factored model:
# (3) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^8 * (x + 6)^8 * (x + 2)^10 * (x + 5)^10 * (x + 3)^11 * (x + 4)^11
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  42  n.digits(prime):  [0, 6]  sd:  4  prime:  7
# factored model:
# (2) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^10 * (x + 6)^10 * (x + 2)^12 * (x + 5)^12 * (x + 3)^13 * (x + 4)^13
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  49  n.digits(prime):  [0, 0, 1]  sd:  4  prime:  7
# factored model:
# (2) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^12 * (x + 6)^12 * (x + 2)^14 * (x + 5)^14 * (x + 3)^15 * (x + 4)^15
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  56  n.digits(prime):  [0, 1, 1]  sd:  4  prime:  7
# factored model:
# (2) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^14 * (x + 6)^14 * (x + 2)^16 * (x + 5)^16 * (x + 3)^17 * (x + 4)^17
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  63  n.digits(prime):  [0, 2, 1]  sd:  4  prime:  7
# factored model:
# (2) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^16 * (x + 6)^16 * (x + 2)^18 * (x + 5)^18 * (x + 3)^19 * (x + 4)^19
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  70  n.digits(prime):  [0, 3, 1]  sd:  4  prime:  7
# factored model:
# (5) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^18 * (x + 6)^18 * (x + 2)^20 * (x + 5)^20 * (x + 3)^21 * (x + 4)^21
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  77  n.digits(prime):  [0, 4, 1]  sd:  4  prime:  7
# factored model:
# (6) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^20 * (x + 6)^20 * (x + 2)^22 * (x + 5)^22 * (x + 3)^23 * (x + 4)^23
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  84  n.digits(prime):  [0, 5, 1]  sd:  4  prime:  7
# factored model:
# (5) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^22 * (x + 6)^22 * (x + 2)^24 * (x + 5)^24 * (x + 3)^25 * (x + 4)^25
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  91  n.digits(prime):  [0, 6, 1]  sd:  4  prime:  7
# factored model:
# (4) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^24 * (x + 6)^24 * (x + 2)^26 * (x + 5)^26 * (x + 3)^27 * (x + 4)^27
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  98  n.digits(prime):  [0, 0, 2]  sd:  4  prime:  7
# factored model:
# (6) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^26 * (x + 6)^26 * (x + 2)^28 * (x + 5)^28 * (x + 3)^29 * (x + 4)^29
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  105  n.digits(prime):  [0, 1, 2]  sd:  4  prime:  7
# factored model:
# (3) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^28 * (x + 6)^28 * (x + 2)^30 * (x + 5)^30 * (x + 3)^31 * (x + 4)^31
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  112  n.digits(prime):  [0, 2, 2]  sd:  4  prime:  7
# factored model:
# (4) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^30 * (x + 6)^30 * (x + 2)^32 * (x + 5)^32 * (x + 3)^33 * (x + 4)^33
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  119  n.digits(prime):  [0, 3, 2]  sd:  4  prime:  7
# factored model:
# (4) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^32 * (x + 6)^32 * (x + 2)^34 * (x + 5)^34 * (x + 3)^35 * (x + 4)^35
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  126  n.digits(prime):  [0, 4, 2]  sd:  4  prime:  7
# factored model:
# (5) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^34 * (x + 6)^34 * (x + 2)^36 * (x + 5)^36 * (x + 3)^37 * (x + 4)^37
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  133  n.digits(prime):  [0, 5, 2]  sd:  4  prime:  7
# factored model:
# (3) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^36 * (x + 6)^36 * (x + 2)^38 * (x + 5)^38 * (x + 3)^39 * (x + 4)^39
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  140  n.digits(prime):  [0, 6, 2]  sd:  4  prime:  7
# factored model:
# (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^38 * (x + 6)^38 * (x + 2)^40 * (x + 5)^40 * (x + 3)^41 * (x + 4)^41
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  147  n.digits(prime):  [0, 0, 3]  sd:  4  prime:  7
# factored model:
# (6) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^40 * (x + 6)^40 * (x + 2)^42 * (x + 5)^42 * (x + 3)^43 * (x + 4)^43
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  154  n.digits(prime):  [0, 1, 3]  sd:  4  prime:  7
# factored model:
# (2) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^42 * (x + 6)^42 * (x + 2)^44 * (x + 5)^44 * (x + 3)^45 * (x + 4)^45
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  161  n.digits(prime):  [0, 2, 3]  sd:  4  prime:  7
# factored model:
# (4) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^44 * (x + 6)^44 * (x + 2)^46 * (x + 5)^46 * (x + 3)^47 * (x + 4)^47
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  168  n.digits(prime):  [0, 3, 3]  sd:  4  prime:  7
# factored model:
# (6) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^46 * (x + 6)^46 * (x + 2)^48 * (x + 5)^48 * (x + 3)^49 * (x + 4)^49
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  175  n.digits(prime):  [0, 4, 3]  sd:  4  prime:  7
# factored model:
# (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^48 * (x + 6)^48 * (x + 2)^50 * (x + 5)^50 * (x + 3)^51 * (x + 4)^51
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  182  n.digits(prime):  [0, 5, 3]  sd:  4  prime:  7
# factored model:
# (6) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^50 * (x + 6)^50 * (x + 2)^52 * (x + 5)^52 * (x + 3)^53 * (x + 4)^53
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  189  n.digits(prime):  [0, 6, 3]  sd:  4  prime:  7
# factored model:
# (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^52 * (x + 6)^52 * (x + 2)^54 * (x + 5)^54 * (x + 3)^55 * (x + 4)^55
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# ------------------------------------------------------------------------
# n:  196  n.digits(prime):  [0, 0, 4]  sd:  4  prime:  7
# factored model:
# (4) * (x + t^3 + 3*t^2 + 6*t) * (x + 3*t^3 + 2*t^2 + 3*t) * (x + 3*t^3 + 6*t^2 + 3) * (x + 4*t^3 + t^2 + 4) * (x + 4*t^3 + 5*t^2 + 4*t) * (x + 6*t^3 + 4*t^2 + t) * (x + 1)^54 * (x + 6)^54 * (x + 2)^56 * (x + 5)^56 * (x + 3)^57 * (x + 4)^57
#
# template:  {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# roots: {1, 2, 3, 4, 5, 6, 4*t^3 + 5*t^2 + 4*t, 3*t^3 + 6*t^2 + 3, 4*t^3 + t^2 + 4, t^3 + 3*t^2 + 6*t, 6*t^3 + 4*t^2 + t, 3*t^3 + 2*t^2 + 3*t}
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
#  bad n:  [7]

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=7
residue=1
sdvalue=4
size=prime^sdvalue
badn=[]
count=0
template=Set([1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, 
t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5])
for k in [1..200]:
    n=s[k][0]
    if (1==1):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
        
        if (sd==sdvalue)&(mod(n,prime)==residue):
            count=1+count
            T = GF(size,'t')
            t=T.multiplicative_generator()
            U.<x> = T[]
            g=U(polynum)
            fg=g.factor()
            roots=[]
            expr=str(g)
            var('x')
            expr3=sage_eval(expr,locals={'x':0})
            if expr3==0:
                roots=roots+[0]
            for i in [1..size]:
                a=t^i
                expr3=sage_eval(expr,locals={'x':a})
                if expr3==0:
                    roots=roots+[t^i]
            roots=Set(roots)
            if roots!=template:
                badn=badn+[n]
            print "------------------------------------------------------------------------"
            print "n: ",n," n.digits(prime): ",n.digits(prime)," sd: ",sd," prime: ",prime
            print "factored model:";print fg;print
            print "template: ",template
            print "roots:",roots
print "&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&"
if count==0:print "null"
print " bad n: ",badn
# Out:
# ------------------------------------------------------------------------
# n:  1  n.digits(prime):  [1]  sd:  4  prime:  7
# factored model:
# (6) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5)
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {t^3 + t^2 + t + 2, 6*t^3 + t^2 + 4*t + 3, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  8  n.digits(prime):  [1, 1]  sd:  4  prime:  7
# factored model:
# (6) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^2 * (x + 2)^2 * (x + 3)^2 * (x + 4)^2 * (x + 5)^2 * (x + 6)^2
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  15  n.digits(prime):  [1, 2]  sd:  4  prime:  7
# factored model:
# (5) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^4 * (x + 2)^4 * (x + 3)^4 * (x + 4)^4 * (x + 5)^4 * (x + 6)^4
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  22  n.digits(prime):  [1, 3]  sd:  4  prime:  7
# factored model:
# (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^6 * (x + 2)^6 * (x + 3)^6 * (x + 4)^6 * (x + 5)^6 * (x + 6)^6
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  29  n.digits(prime):  [1, 4]  sd:  4  prime:  7
# factored model:
# (6) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^8 * (x + 2)^8 * (x + 3)^8 * (x + 4)^8 * (x + 5)^8 * (x + 6)^8
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  36  n.digits(prime):  [1, 5]  sd:  4  prime:  7
# factored model:
# (5) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^10 * (x + 2)^10 * (x + 3)^10 * (x + 4)^10 * (x + 5)^10 * (x + 6)^10
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  43  n.digits(prime):  [1, 6]  sd:  4  prime:  7
# factored model:
# (4) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^12 * (x + 2)^12 * (x + 3)^12 * (x + 4)^12 * (x + 5)^12 * (x + 6)^12
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  50  n.digits(prime):  [1, 0, 1]  sd:  4  prime:  7
# factored model:
# (4) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^14 * (x + 2)^14 * (x + 3)^14 * (x + 4)^14 * (x + 5)^14 * (x + 6)^14
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  57  n.digits(prime):  [1, 1, 1]  sd:  4  prime:  7
# factored model:
# (4) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^16 * (x + 2)^16 * (x + 3)^16 * (x + 4)^16 * (x + 5)^16 * (x + 6)^16
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  64  n.digits(prime):  [1, 2, 1]  sd:  4  prime:  7
# factored model:
# (2) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^18 * (x + 2)^18 * (x + 3)^18 * (x + 4)^18 * (x + 5)^18 * (x + 6)^18
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  71  n.digits(prime):  [1, 3, 1]  sd:  4  prime:  7
# factored model:
# (6) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^20 * (x + 2)^20 * (x + 3)^20 * (x + 4)^20 * (x + 5)^20 * (x + 6)^20
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  78  n.digits(prime):  [1, 4, 1]  sd:  4  prime:  7
# factored model:
# (6) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^22 * (x + 2)^22 * (x + 3)^22 * (x + 4)^22 * (x + 5)^22 * (x + 6)^22
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  85  n.digits(prime):  [1, 5, 1]  sd:  4  prime:  7
# factored model:
# (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^24 * (x + 2)^24 * (x + 3)^24 * (x + 4)^24 * (x + 5)^24 * (x + 6)^24
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  92  n.digits(prime):  [1, 6, 1]  sd:  4  prime:  7
# factored model:
# (3) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^26 * (x + 2)^26 * (x + 3)^26 * (x + 4)^26 * (x + 5)^26 * (x + 6)^26
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  99  n.digits(prime):  [1, 0, 2]  sd:  4  prime:  7
# factored model:
# (2) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^28 * (x + 2)^28 * (x + 3)^28 * (x + 4)^28 * (x + 5)^28 * (x + 6)^28
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  106  n.digits(prime):  [1, 1, 2]  sd:  4  prime:  7
# factored model:
# (6) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^30 * (x + 2)^30 * (x + 3)^30 * (x + 4)^30 * (x + 5)^30 * (x + 6)^30
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  113  n.digits(prime):  [1, 2, 2]  sd:  4  prime:  7
# factored model:
# (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^32 * (x + 2)^32 * (x + 3)^32 * (x + 4)^32 * (x + 5)^32 * (x + 6)^32
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  120  n.digits(prime):  [1, 3, 2]  sd:  4  prime:  7
# factored model:
# (4) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^34 * (x + 2)^34 * (x + 3)^34 * (x + 4)^34 * (x + 5)^34 * (x + 6)^34
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  127  n.digits(prime):  [1, 4, 2]  sd:  4  prime:  7
# factored model:
# (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^36 * (x + 2)^36 * (x + 3)^36 * (x + 4)^36 * (x + 5)^36 * (x + 6)^36
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  134  n.digits(prime):  [1, 5, 2]  sd:  4  prime:  7
# factored model:
# (4) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^38 * (x + 2)^38 * (x + 3)^38 * (x + 4)^38 * (x + 5)^38 * (x + 6)^38
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  141  n.digits(prime):  [1, 6, 2]  sd:  4  prime:  7
# factored model:
# (5) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^40 * (x + 2)^40 * (x + 3)^40 * (x + 4)^40 * (x + 5)^40 * (x + 6)^40
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  148  n.digits(prime):  [1, 0, 3]  sd:  4  prime:  7
# factored model:
# (5) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^42 * (x + 2)^42 * (x + 3)^42 * (x + 4)^42 * (x + 5)^42 * (x + 6)^42
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  155  n.digits(prime):  [1, 1, 3]  sd:  4  prime:  7
# factored model:
# (2) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^44 * (x + 2)^44 * (x + 3)^44 * (x + 4)^44 * (x + 5)^44 * (x + 6)^44
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  162  n.digits(prime):  [1, 2, 3]  sd:  4  prime:  7
# factored model:
# (5) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^46 * (x + 2)^46 * (x + 3)^46 * (x + 4)^46 * (x + 5)^46 * (x + 6)^46
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  169  n.digits(prime):  [1, 3, 3]  sd:  4  prime:  7
# factored model:
# (2) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^48 * (x + 2)^48 * (x + 3)^48 * (x + 4)^48 * (x + 5)^48 * (x + 6)^48
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  176  n.digits(prime):  [1, 4, 3]  sd:  4  prime:  7
# factored model:
# (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^50 * (x + 2)^50 * (x + 3)^50 * (x + 4)^50 * (x + 5)^50 * (x + 6)^50
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  183  n.digits(prime):  [1, 5, 3]  sd:  4  prime:  7
# factored model:
# (3) * (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^52 * (x + 2)^52 * (x + 3)^52 * (x + 4)^52 * (x + 5)^52 * (x + 6)^52
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  190  n.digits(prime):  [1, 6, 3]  sd:  4  prime:  7
# factored model:
# (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^54 * (x + 2)^54 * (x + 3)^54 * (x + 4)^54 * (x + 5)^54 * (x + 6)^54
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# ------------------------------------------------------------------------
# n:  197  n.digits(prime):  [1, 0, 4]  sd:  4  prime:  7
# factored model:
# (x + t^3 + t^2 + t + 2) * (x + t^3 + 6*t^2 + 3*t + 4) * (x + 6*t^3 + t^2 + 4*t + 3) * (x + 6*t^3 + 6*t^2 + 6*t + 5) * (x + 1)^56 * (x + 2)^56 * (x + 3)^56 * (x + 4)^56 * (x + 5)^56 * (x + 6)^56
#
# template:  {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# roots: {1, 2, 3, 4, 5, 6, t^3 + t^2 + t + 2, t^3 + 6*t^2 + 3*t + 4, 6*t^3 + t^2 + 4*t + 3, 6*t^3 + 6*t^2 + 6*t + 5}
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
#  bad n:  [1]

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=7
residue=2
sdvalue=2
size=prime^sdvalue
badn=[]
count=0
template=Set([1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4])
for k in [1..200]:
    n=s[k][0]
    if (1==1):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
        
        if (sd==sdvalue)&(mod(n,prime)==residue):
            count=1+count
            T = GF(size,'t')
            t=T.multiplicative_generator()
            U.<x> = T[]
            g=U(polynum)
            fg=g.factor()
            roots=[]
            expr=str(g)
            var('x')
            expr3=sage_eval(expr,locals={'x':0})
            if expr3==0:
                roots=roots+[0]
            for i in [1..size]:
                a=t^i
                expr3=sage_eval(expr,locals={'x':a})
                if expr3==0:
                    roots=roots+[t^i]
            roots=Set(roots)
            if roots!=template:
                badn=badn+[n]
            print "------------------------------------------------------------------------"
            print "n: ",n," n.digits(prime): ",n.digits(prime)," sd: ",sd," prime: ",prime
            print "factored model:";print fg;print
            print "template: ",template
            print "roots:",roots
print "&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&"
if count==0:print "null"
print " bad n: ",badn
# Out:
# ------------------------------------------------------------------------
# n:  2  n.digits(prime):  [2]  sd:  2  prime:  7
# factored model:
# (6) * (x + 2) * (x + 5) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {2*t + 6, 2, 5*t + 1, 5}
# ------------------------------------------------------------------------
# n:  9  n.digits(prime):  [2, 1]  sd:  2  prime:  7
# factored model:
# (3) * (x + 1)^2 * (x + 3)^2 * (x + 4)^2 * (x + 6)^2 * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 2)^3 * (x + 5)^3
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  16  n.digits(prime):  [2, 2]  sd:  2  prime:  7
# factored model:
# (4) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^4 * (x + 3)^4 * (x + 4)^4 * (x + 6)^4 * (x + 2)^5 * (x + 5)^5
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  23  n.digits(prime):  [2, 3]  sd:  2  prime:  7
# factored model:
# (2) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^6 * (x + 3)^6 * (x + 4)^6 * (x + 6)^6 * (x + 2)^7 * (x + 5)^7
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  30  n.digits(prime):  [2, 4]  sd:  2  prime:  7
# factored model:
# (2) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^8 * (x + 3)^8 * (x + 4)^8 * (x + 6)^8 * (x + 2)^9 * (x + 5)^9
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  37  n.digits(prime):  [2, 5]  sd:  2  prime:  7
# factored model:
# (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^10 * (x + 3)^10 * (x + 4)^10 * (x + 6)^10 * (x + 2)^11 * (x + 5)^11
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  44  n.digits(prime):  [2, 6]  sd:  2  prime:  7
# factored model:
# (3) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^12 * (x + 3)^12 * (x + 4)^12 * (x + 6)^12 * (x + 2)^13 * (x + 5)^13
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  51  n.digits(prime):  [2, 0, 1]  sd:  2  prime:  7
# factored model:
# (6) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^14 * (x + 3)^14 * (x + 4)^14 * (x + 6)^14 * (x + 2)^15 * (x + 5)^15
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  58  n.digits(prime):  [2, 1, 1]  sd:  2  prime:  7
# factored model:
# (4) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^16 * (x + 3)^16 * (x + 4)^16 * (x + 6)^16 * (x + 2)^17 * (x + 5)^17
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  65  n.digits(prime):  [2, 2, 1]  sd:  2  prime:  7
# factored model:
# (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^18 * (x + 3)^18 * (x + 4)^18 * (x + 6)^18 * (x + 2)^19 * (x + 5)^19
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  72  n.digits(prime):  [2, 3, 1]  sd:  2  prime:  7
# factored model:
# (3) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^20 * (x + 3)^20 * (x + 4)^20 * (x + 6)^20 * (x + 2)^21 * (x + 5)^21
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  79  n.digits(prime):  [2, 4, 1]  sd:  2  prime:  7
# factored model:
# (3) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^22 * (x + 3)^22 * (x + 4)^22 * (x + 6)^22 * (x + 2)^23 * (x + 5)^23
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  86  n.digits(prime):  [2, 5, 1]  sd:  2  prime:  7
# factored model:
# (3) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^24 * (x + 3)^24 * (x + 4)^24 * (x + 6)^24 * (x + 2)^25 * (x + 5)^25
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  93  n.digits(prime):  [2, 6, 1]  sd:  2  prime:  7
# factored model:
# (5) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^26 * (x + 3)^26 * (x + 4)^26 * (x + 6)^26 * (x + 2)^27 * (x + 5)^27
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  100  n.digits(prime):  [2, 0, 2]  sd:  2  prime:  7
# factored model:
# (2) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^28 * (x + 3)^28 * (x + 4)^28 * (x + 6)^28 * (x + 2)^29 * (x + 5)^29
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  107  n.digits(prime):  [2, 1, 2]  sd:  2  prime:  7
# factored model:
# (2) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^30 * (x + 3)^30 * (x + 4)^30 * (x + 6)^30 * (x + 2)^31 * (x + 5)^31
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  114  n.digits(prime):  [2, 2, 2]  sd:  2  prime:  7
# factored model:
# (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^32 * (x + 3)^32 * (x + 4)^32 * (x + 6)^32 * (x + 2)^33 * (x + 5)^33
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  121  n.digits(prime):  [2, 3, 2]  sd:  2  prime:  7
# factored model:
# (5) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^34 * (x + 3)^34 * (x + 4)^34 * (x + 6)^34 * (x + 2)^35 * (x + 5)^35
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  128  n.digits(prime):  [2, 4, 2]  sd:  2  prime:  7
# factored model:
# (4) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^36 * (x + 3)^36 * (x + 4)^36 * (x + 6)^36 * (x + 2)^37 * (x + 5)^37
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  135  n.digits(prime):  [2, 5, 2]  sd:  2  prime:  7
# factored model:
# (6) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^38 * (x + 3)^38 * (x + 4)^38 * (x + 6)^38 * (x + 2)^39 * (x + 5)^39
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  142  n.digits(prime):  [2, 6, 2]  sd:  2  prime:  7
# factored model:
# (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^40 * (x + 3)^40 * (x + 4)^40 * (x + 6)^40 * (x + 2)^41 * (x + 5)^41
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  149  n.digits(prime):  [2, 0, 3]  sd:  2  prime:  7
# factored model:
# (3) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^42 * (x + 3)^42 * (x + 4)^42 * (x + 6)^42 * (x + 2)^43 * (x + 5)^43
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  156  n.digits(prime):  [2, 1, 3]  sd:  2  prime:  7
# factored model:
# (6) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^44 * (x + 3)^44 * (x + 4)^44 * (x + 6)^44 * (x + 2)^45 * (x + 5)^45
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  163  n.digits(prime):  [2, 2, 3]  sd:  2  prime:  7
# factored model:
# (6) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^46 * (x + 3)^46 * (x + 4)^46 * (x + 6)^46 * (x + 2)^47 * (x + 5)^47
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  170  n.digits(prime):  [2, 3, 3]  sd:  2  prime:  7
# factored model:
# (3) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^48 * (x + 3)^48 * (x + 4)^48 * (x + 6)^48 * (x + 2)^49 * (x + 5)^49
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  177  n.digits(prime):  [2, 4, 3]  sd:  2  prime:  7
# factored model:
# (5) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^50 * (x + 3)^50 * (x + 4)^50 * (x + 6)^50 * (x + 2)^51 * (x + 5)^51
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  184  n.digits(prime):  [2, 5, 3]  sd:  2  prime:  7
# factored model:
# (2) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^52 * (x + 3)^52 * (x + 4)^52 * (x + 6)^52 * (x + 2)^53 * (x + 5)^53
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  191  n.digits(prime):  [2, 6, 3]  sd:  2  prime:  7
# factored model:
# (4) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^54 * (x + 3)^54 * (x + 4)^54 * (x + 6)^54 * (x + 2)^55 * (x + 5)^55
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# ------------------------------------------------------------------------
# n:  198  n.digits(prime):  [2, 0, 4]  sd:  2  prime:  7
# factored model:
# (5) * (x + 2*t + 6)^2 * (x + 5*t + 1)^2 * (x + 1)^56 * (x + 3)^56 * (x + 4)^56 * (x + 6)^56 * (x + 2)^57 * (x + 5)^57
#
# template:  {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# roots: {1, 2, 3, 5*t + 1, 5, 6, 2*t + 6, 4}
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
#  bad n:  [2]

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=7
residue=3
sdvalue=2
size=prime^sdvalue
badn=[]
count=0
template=Set([1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3])
for k in [1..200]:
    n=s[k][0]
    if (1==1):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
        
        if (sd==sdvalue)&(mod(n,prime)==residue):
            count=1+count
            T = GF(size,'t')
            t=T.multiplicative_generator()
            U.<x> = T[]
            g=U(polynum)
            fg=g.factor()
            roots=[]
            expr=str(g)
            var('x')
            expr3=sage_eval(expr,locals={'x':0})
            if expr3==0:
                roots=roots+[0]
            for i in [1..size]:
                a=t^i
                expr3=sage_eval(expr,locals={'x':a})
                if expr3==0:
                    roots=roots+[t^i]
            roots=Set(roots)
            if roots!=template:
                badn=badn+[n]
            print "------------------------------------------------------------------------"
            print "n: ",n," n.digits(prime): ",n.digits(prime)," sd: ",sd," prime: ",prime
            print "factored model:";print fg;print
            print "template: ",template
            print "roots:",roots
print "&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&"
if count==0:print "null"
print " bad n: ",badn
# Out:
# ------------------------------------------------------------------------
# n:  3  n.digits(prime):  [3]  sd:  2  prime:  7
# factored model:
# (x + 2) * (x + 5) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4)
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {2, 5, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  10  n.digits(prime):  [3, 1]  sd:  2  prime:  7
# factored model:
# (4) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^2 * (x + 3)^2 * (x + 4)^2 * (x + 6)^2 * (x + 2)^3 * (x + 5)^3
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  17  n.digits(prime):  [3, 2]  sd:  2  prime:  7
# factored model:
# (2) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^4 * (x + 3)^4 * (x + 4)^4 * (x + 6)^4 * (x + 2)^5 * (x + 5)^5
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  24  n.digits(prime):  [3, 3]  sd:  2  prime:  7
# factored model:
# (4) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^6 * (x + 3)^6 * (x + 4)^6 * (x + 6)^6 * (x + 2)^7 * (x + 5)^7
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  31  n.digits(prime):  [3, 4]  sd:  2  prime:  7
# factored model:
# (2) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^8 * (x + 3)^8 * (x + 4)^8 * (x + 6)^8 * (x + 2)^9 * (x + 5)^9
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  38  n.digits(prime):  [3, 5]  sd:  2  prime:  7
# factored model:
# (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^10 * (x + 3)^10 * (x + 4)^10 * (x + 6)^10 * (x + 2)^11 * (x + 5)^11
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  45  n.digits(prime):  [3, 6]  sd:  2  prime:  7
# factored model:
# (4) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^12 * (x + 3)^12 * (x + 4)^12 * (x + 6)^12 * (x + 2)^13 * (x + 5)^13
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  52  n.digits(prime):  [3, 0, 1]  sd:  2  prime:  7
# factored model:
# (2) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^14 * (x + 3)^14 * (x + 4)^14 * (x + 6)^14 * (x + 2)^15 * (x + 5)^15
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  59  n.digits(prime):  [3, 1, 1]  sd:  2  prime:  7
# factored model:
# (2) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^16 * (x + 3)^16 * (x + 4)^16 * (x + 6)^16 * (x + 2)^17 * (x + 5)^17
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  66  n.digits(prime):  [3, 2, 1]  sd:  2  prime:  7
# factored model:
# (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^18 * (x + 3)^18 * (x + 4)^18 * (x + 6)^18 * (x + 2)^19 * (x + 5)^19
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  73  n.digits(prime):  [3, 3, 1]  sd:  2  prime:  7
# factored model:
# (2) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^20 * (x + 3)^20 * (x + 4)^20 * (x + 6)^20 * (x + 2)^21 * (x + 5)^21
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  80  n.digits(prime):  [3, 4, 1]  sd:  2  prime:  7
# factored model:
# (4) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^22 * (x + 3)^22 * (x + 4)^22 * (x + 6)^22 * (x + 2)^23 * (x + 5)^23
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  87  n.digits(prime):  [3, 5, 1]  sd:  2  prime:  7
# factored model:
# (4) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^24 * (x + 3)^24 * (x + 4)^24 * (x + 6)^24 * (x + 2)^25 * (x + 5)^25
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  94  n.digits(prime):  [3, 6, 1]  sd:  2  prime:  7
# factored model:
# (3) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^26 * (x + 3)^26 * (x + 4)^26 * (x + 6)^26 * (x + 2)^27 * (x + 5)^27
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  101  n.digits(prime):  [3, 0, 2]  sd:  2  prime:  7
# factored model:
# (2) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^28 * (x + 3)^28 * (x + 4)^28 * (x + 6)^28 * (x + 2)^29 * (x + 5)^29
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  108  n.digits(prime):  [3, 1, 2]  sd:  2  prime:  7
# factored model:
# (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^30 * (x + 3)^30 * (x + 4)^30 * (x + 6)^30 * (x + 2)^31 * (x + 5)^31
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  115  n.digits(prime):  [3, 2, 2]  sd:  2  prime:  7
# factored model:
# (4) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^32 * (x + 3)^32 * (x + 4)^32 * (x + 6)^32 * (x + 2)^33 * (x + 5)^33
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  122  n.digits(prime):  [3, 3, 2]  sd:  2  prime:  7
# factored model:
# (2) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^34 * (x + 3)^34 * (x + 4)^34 * (x + 6)^34 * (x + 2)^35 * (x + 5)^35
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  129  n.digits(prime):  [3, 4, 2]  sd:  2  prime:  7
# factored model:
# (6) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^36 * (x + 3)^36 * (x + 4)^36 * (x + 6)^36 * (x + 2)^37 * (x + 5)^37
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  136  n.digits(prime):  [3, 5, 2]  sd:  2  prime:  7
# factored model:
# (6) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^38 * (x + 3)^38 * (x + 4)^38 * (x + 6)^38 * (x + 2)^39 * (x + 5)^39
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  143  n.digits(prime):  [3, 6, 2]  sd:  2  prime:  7
# factored model:
# (4) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^40 * (x + 3)^40 * (x + 4)^40 * (x + 6)^40 * (x + 2)^41 * (x + 5)^41
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  150  n.digits(prime):  [3, 0, 3]  sd:  2  prime:  7
# factored model:
# (4) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^42 * (x + 3)^42 * (x + 4)^42 * (x + 6)^42 * (x + 2)^43 * (x + 5)^43
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  157  n.digits(prime):  [3, 1, 3]  sd:  2  prime:  7
# factored model:
# (3) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^44 * (x + 3)^44 * (x + 4)^44 * (x + 6)^44 * (x + 2)^45 * (x + 5)^45
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  164  n.digits(prime):  [3, 2, 3]  sd:  2  prime:  7
# factored model:
# (4) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^46 * (x + 3)^46 * (x + 4)^46 * (x + 6)^46 * (x + 2)^47 * (x + 5)^47
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  171  n.digits(prime):  [3, 3, 3]  sd:  2  prime:  7
# factored model:
# (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^48 * (x + 3)^48 * (x + 4)^48 * (x + 6)^48 * (x + 2)^49 * (x + 5)^49
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  178  n.digits(prime):  [3, 4, 3]  sd:  2  prime:  7
# factored model:
# (3) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^50 * (x + 3)^50 * (x + 4)^50 * (x + 6)^50 * (x + 2)^51 * (x + 5)^51
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  185  n.digits(prime):  [3, 5, 3]  sd:  2  prime:  7
# factored model:
# (2) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^52 * (x + 3)^52 * (x + 4)^52 * (x + 6)^52 * (x + 2)^53 * (x + 5)^53
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  192  n.digits(prime):  [3, 6, 3]  sd:  2  prime:  7
# factored model:
# (5) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^54 * (x + 3)^54 * (x + 4)^54 * (x + 6)^54 * (x + 2)^55 * (x + 5)^55
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# ------------------------------------------------------------------------
# n:  199  n.digits(prime):  [3, 0, 4]  sd:  2  prime:  7
# factored model:
# (6) * (x + t) * (x + t + 3) * (x + t + 6) * (x + 6*t) * (x + 6*t + 1) * (x + 6*t + 4) * (x + 1)^56 * (x + 3)^56 * (x + 4)^56 * (x + 6)^56 * (x + 2)^57 * (x + 5)^57
#
# template:  {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# roots: {1, 2, 3, 4, 5, 6, t, 6*t, 6*t + 1, t + 6, 6*t + 4, t + 3}
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
#  bad n:  [3]

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=7
residue=4
sdvalue=6
size=prime^sdvalue
badn=[]
count=0
template=Set([4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 
3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 
4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 
4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 
5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 
3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5])
for k in [1..200]:
    n=s[k][0]
    if (1==1):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
        
        if (sd==sdvalue)&(mod(n,prime)==residue):
            count=1+count
            T = GF(size,'t')
            t=T.multiplicative_generator()
            U.<x> = T[]
            g=U(polynum)
            fg=g.factor()
            roots=[]
            expr=str(g)
            var('x')
            expr3=sage_eval(expr,locals={'x':0})
            if expr3==0:
                roots=roots+[0]
            for i in [1..size]:
                a=t^i
                expr3=sage_eval(expr,locals={'x':a})
                if expr3==0:
                    roots=roots+[t^i]
            roots=Set(roots)
            if roots!=template:
                badn=badn+[n]
            print "------------------------------------------------------------------------"
            print "n: ",n," n.digits(prime): ",n.digits(prime)," sd: ",sd," prime: ",prime
            print "factored model:";print fg;print
            print "template: ",template
            print "roots:",roots
print "&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&"
if count==0:print "null"
print " bad n: ",badn
# Out:
# ------------------------------------------------------------------------
# n:  4  n.digits(prime):  [4]  sd:  6  prime:  7
# factored model:
# (3) * (x + 2) * (x + 5) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5)
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 5, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  11  n.digits(prime):  [4, 1]  sd:  6  prime:  7
# factored model:
# (3) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^2 * (x + 3)^2 * (x + 4)^2 * (x + 6)^2 * (x + 2)^3 * (x + 5)^3
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  18  n.digits(prime):  [4, 2]  sd:  6  prime:  7
# factored model:
# (6) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^4 * (x + 3)^4 * (x + 4)^4 * (x + 6)^4 * (x + 2)^5 * (x + 5)^5
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  25  n.digits(prime):  [4, 3]  sd:  6  prime:  7
# factored model:
# (5) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^6 * (x + 3)^6 * (x + 4)^6 * (x + 6)^6 * (x + 2)^7 * (x + 5)^7
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  32  n.digits(prime):  [4, 4]  sd:  6  prime:  7
# factored model:
# (3) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^8 * (x + 3)^8 * (x + 4)^8 * (x + 6)^8 * (x + 2)^9 * (x + 5)^9
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  39  n.digits(prime):  [4, 5]  sd:  6  prime:  7
# factored model:
# (2) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^10 * (x + 3)^10 * (x + 4)^10 * (x + 6)^10 * (x + 2)^11 * (x + 5)^11
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  46  n.digits(prime):  [4, 6]  sd:  6  prime:  7
# factored model:
# (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^12 * (x + 3)^12 * (x + 4)^12 * (x + 6)^12 * (x + 2)^13 * (x + 5)^13
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  53  n.digits(prime):  [4, 0, 1]  sd:  6  prime:  7
# factored model:
# (5) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^14 * (x + 3)^14 * (x + 4)^14 * (x + 6)^14 * (x + 2)^15 * (x + 5)^15
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  60  n.digits(prime):  [4, 1, 1]  sd:  6  prime:  7
# factored model:
# (6) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^16 * (x + 3)^16 * (x + 4)^16 * (x + 6)^16 * (x + 2)^17 * (x + 5)^17
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  67  n.digits(prime):  [4, 2, 1]  sd:  6  prime:  7
# factored model:
# (2) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^18 * (x + 3)^18 * (x + 4)^18 * (x + 6)^18 * (x + 2)^19 * (x + 5)^19
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  74  n.digits(prime):  [4, 3, 1]  sd:  6  prime:  7
# factored model:
# (5) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^20 * (x + 3)^20 * (x + 4)^20 * (x + 6)^20 * (x + 2)^21 * (x + 5)^21
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  81  n.digits(prime):  [4, 4, 1]  sd:  6  prime:  7
# factored model:
# (3) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^22 * (x + 3)^22 * (x + 4)^22 * (x + 6)^22 * (x + 2)^23 * (x + 5)^23
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  88  n.digits(prime):  [4, 5, 1]  sd:  6  prime:  7
# factored model:
# (3) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^24 * (x + 3)^24 * (x + 4)^24 * (x + 6)^24 * (x + 2)^25 * (x + 5)^25
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  95  n.digits(prime):  [4, 6, 1]  sd:  6  prime:  7
# factored model:
# (2) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^26 * (x + 3)^26 * (x + 4)^26 * (x + 6)^26 * (x + 2)^27 * (x + 5)^27
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  102  n.digits(prime):  [4, 0, 2]  sd:  6  prime:  7
# factored model:
# (5) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^28 * (x + 3)^28 * (x + 4)^28 * (x + 6)^28 * (x + 2)^29 * (x + 5)^29
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  109  n.digits(prime):  [4, 1, 2]  sd:  6  prime:  7
# factored model:
# (2) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^30 * (x + 3)^30 * (x + 4)^30 * (x + 6)^30 * (x + 2)^31 * (x + 5)^31
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  116  n.digits(prime):  [4, 2, 2]  sd:  6  prime:  7
# factored model:
# (4) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^32 * (x + 3)^32 * (x + 4)^32 * (x + 6)^32 * (x + 2)^33 * (x + 5)^33
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  123  n.digits(prime):  [4, 3, 2]  sd:  6  prime:  7
# factored model:
# (2) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^34 * (x + 3)^34 * (x + 4)^34 * (x + 6)^34 * (x + 2)^35 * (x + 5)^35
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  130  n.digits(prime):  [4, 4, 2]  sd:  6  prime:  7
# factored model:
# (6) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^36 * (x + 3)^36 * (x + 4)^36 * (x + 6)^36 * (x + 2)^37 * (x + 5)^37
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  137  n.digits(prime):  [4, 5, 2]  sd:  6  prime:  7
# factored model:
# (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^38 * (x + 3)^38 * (x + 4)^38 * (x + 6)^38 * (x + 2)^39 * (x + 5)^39
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  144  n.digits(prime):  [4, 6, 2]  sd:  6  prime:  7
# factored model:
# (2) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^40 * (x + 3)^40 * (x + 4)^40 * (x + 6)^40 * (x + 2)^41 * (x + 5)^41
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  151  n.digits(prime):  [4, 0, 3]  sd:  6  prime:  7
# factored model:
# (6) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^42 * (x + 3)^42 * (x + 4)^42 * (x + 6)^42 * (x + 2)^43 * (x + 5)^43
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  158  n.digits(prime):  [4, 1, 3]  sd:  6  prime:  7
# factored model:
# (2) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^44 * (x + 3)^44 * (x + 4)^44 * (x + 6)^44 * (x + 2)^45 * (x + 5)^45
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  165  n.digits(prime):  [4, 2, 3]  sd:  6  prime:  7
# factored model:
# (5) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^46 * (x + 3)^46 * (x + 4)^46 * (x + 6)^46 * (x + 2)^47 * (x + 5)^47
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  172  n.digits(prime):  [4, 3, 3]  sd:  6  prime:  7
# factored model:
# (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^48 * (x + 3)^48 * (x + 4)^48 * (x + 6)^48 * (x + 2)^49 * (x + 5)^49
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  179  n.digits(prime):  [4, 4, 3]  sd:  6  prime:  7
# factored model:
# (2) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^50 * (x + 3)^50 * (x + 4)^50 * (x + 6)^50 * (x + 2)^51 * (x + 5)^51
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  186  n.digits(prime):  [4, 5, 3]  sd:  6  prime:  7
# factored model:
# (5) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^52 * (x + 3)^52 * (x + 4)^52 * (x + 6)^52 * (x + 2)^53 * (x + 5)^53
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# ------------------------------------------------------------------------
# n:  193  n.digits(prime):  [4, 6, 3]  sd:  6  prime:  7
# factored model:
# (3) * (x + 5*t^4 + t^3 + 5*t^2 + 4*t + 1) * (x + 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6) * (x + 4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2) * (x + 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2) * (x + 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3) * (x + 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4) * (x + 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5) * (x + 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5) * (x + 1)^54 * (x + 3)^54 * (x + 4)^54 * (x + 6)^54 * (x + 2)^55 * (x + 5)^55
#
# template:  {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# roots: {4*t^5 + 6*t^4 + 3*t^3 + 4*t^2 + 2, 2, 3, 4, 5, 6, 3*t^5 + 3*t^4 + 5*t^3 + 2*t^2 + 6*t + 4, 4*t^5 + 4*t^4 + 2*t^3 + 5*t^2 + t + 3, 4*t^5 + 4*t^4 + 4*t^3 + 2*t^2 + 4*t + 2, 5*t^4 + t^3 + 5*t^2 + 4*t + 1, 1, 2*t^4 + 6*t^3 + 2*t^2 + 3*t + 6, 3*t^5 + t^4 + 4*t^3 + 3*t^2 + 5, 3*t^5 + 3*t^4 + 3*t^3 + 5*t^2 + 3*t + 5}
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
#  bad n:  [4]

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=7
residue=5
sdvalue=5
size=prime^sdvalue
badn=[]
count=0
template=Set([1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 
2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 
2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 
5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 
2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2])
for k in [1..200]:
    n=s[k][0]
    if (1==1):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
        
        if (sd==sdvalue)&(mod(n,prime)==residue):
            count=1+count
            T = GF(size,'t')
            t=T.multiplicative_generator()
            U.<x> = T[]
            g=U(polynum)
            fg=g.factor()
            roots=[]
            expr=str(g)
            var('x')
            expr3=sage_eval(expr,locals={'x':0})
            if expr3==0:
                roots=roots+[0]
            for i in [1..size]:
                a=t^i
                expr3=sage_eval(expr,locals={'x':a})
                if expr3==0:
                    roots=roots+[t^i]
            roots=Set(roots)
            if roots!=template:
                badn=badn+[n]
            print "------------------------------------------------------------------------"
            print "n: ",n," n.digits(prime): ",n.digits(prime)," sd: ",sd," prime: ",prime
            print "factored model:";print fg;print
            print "template: ",template
            print "roots:",roots
print "&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&"
if count==0:print "null"
print " bad n: ",badn
# Out:
# ------------------------------------------------------------------------
# n:  5  n.digits(prime):  [5]  sd:  5  prime:  7
# factored model:
# (x + 2) * (x + 5) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t)
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {5*t^4 + 2*t^3 + 6*t^2 + t + 2, 2*t^4 + t^3 + t^2 + 3*t + 5, 5, 3*t^3 + 3*t^2 + 6*t + 5, 4*t^3 + 4*t^2 + t + 2, 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 5*t^4 + t^2 + 6*t + 2, 2*t^4 + 6*t^2 + t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t}
# ------------------------------------------------------------------------
# n:  12  n.digits(prime):  [5, 1]  sd:  5  prime:  7
# factored model:
# (4) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^2 * (x + 3)^2 * (x + 4)^2 * (x + 6)^2 * (x + 2)^3 * (x + 5)^3
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  19  n.digits(prime):  [5, 2]  sd:  5  prime:  7
# factored model:
# (2) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^4 * (x + 3)^4 * (x + 4)^4 * (x + 6)^4 * (x + 2)^5 * (x + 5)^5
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  26  n.digits(prime):  [5, 3]  sd:  5  prime:  7
# factored model:
# (2) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^6 * (x + 3)^6 * (x + 4)^6 * (x + 6)^6 * (x + 2)^7 * (x + 5)^7
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  33  n.digits(prime):  [5, 4]  sd:  5  prime:  7
# factored model:
# (3) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^8 * (x + 3)^8 * (x + 4)^8 * (x + 6)^8 * (x + 2)^9 * (x + 5)^9
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  40  n.digits(prime):  [5, 5]  sd:  5  prime:  7
# factored model:
# (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^10 * (x + 3)^10 * (x + 4)^10 * (x + 6)^10 * (x + 2)^11 * (x + 5)^11
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  47  n.digits(prime):  [5, 6]  sd:  5  prime:  7
# factored model:
# (2) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^12 * (x + 3)^12 * (x + 4)^12 * (x + 6)^12 * (x + 2)^13 * (x + 5)^13
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  54  n.digits(prime):  [5, 0, 1]  sd:  5  prime:  7
# factored model:
# (4) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^14 * (x + 3)^14 * (x + 4)^14 * (x + 6)^14 * (x + 2)^15 * (x + 5)^15
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  61  n.digits(prime):  [5, 1, 1]  sd:  5  prime:  7
# factored model:
# (4) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^16 * (x + 3)^16 * (x + 4)^16 * (x + 6)^16 * (x + 2)^17 * (x + 5)^17
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  68  n.digits(prime):  [5, 2, 1]  sd:  5  prime:  7
# factored model:
# (5) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^18 * (x + 3)^18 * (x + 4)^18 * (x + 6)^18 * (x + 2)^19 * (x + 5)^19
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  75  n.digits(prime):  [5, 3, 1]  sd:  5  prime:  7
# factored model:
# (2) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^20 * (x + 3)^20 * (x + 4)^20 * (x + 6)^20 * (x + 2)^21 * (x + 5)^21
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  82  n.digits(prime):  [5, 4, 1]  sd:  5  prime:  7
# factored model:
# (4) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^22 * (x + 3)^22 * (x + 4)^22 * (x + 6)^22 * (x + 2)^23 * (x + 5)^23
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  89  n.digits(prime):  [5, 5, 1]  sd:  5  prime:  7
# factored model:
# (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^24 * (x + 3)^24 * (x + 4)^24 * (x + 6)^24 * (x + 2)^25 * (x + 5)^25
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  96  n.digits(prime):  [5, 6, 1]  sd:  5  prime:  7
# factored model:
# (5) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^26 * (x + 3)^26 * (x + 4)^26 * (x + 6)^26 * (x + 2)^27 * (x + 5)^27
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  103  n.digits(prime):  [5, 0, 2]  sd:  5  prime:  7
# factored model:
# (6) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^28 * (x + 3)^28 * (x + 4)^28 * (x + 6)^28 * (x + 2)^29 * (x + 5)^29
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  110  n.digits(prime):  [5, 1, 2]  sd:  5  prime:  7
# factored model:
# (6) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^30 * (x + 3)^30 * (x + 4)^30 * (x + 6)^30 * (x + 2)^31 * (x + 5)^31
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  117  n.digits(prime):  [5, 2, 2]  sd:  5  prime:  7
# factored model:
# (5) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^32 * (x + 3)^32 * (x + 4)^32 * (x + 6)^32 * (x + 2)^33 * (x + 5)^33
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  124  n.digits(prime):  [5, 3, 2]  sd:  5  prime:  7
# factored model:
# (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^34 * (x + 3)^34 * (x + 4)^34 * (x + 6)^34 * (x + 2)^35 * (x + 5)^35
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  131  n.digits(prime):  [5, 4, 2]  sd:  5  prime:  7
# factored model:
# (5) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^36 * (x + 3)^36 * (x + 4)^36 * (x + 6)^36 * (x + 2)^37 * (x + 5)^37
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  138  n.digits(prime):  [5, 5, 2]  sd:  5  prime:  7
# factored model:
# (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^38 * (x + 3)^38 * (x + 4)^38 * (x + 6)^38 * (x + 2)^39 * (x + 5)^39
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  145  n.digits(prime):  [5, 6, 2]  sd:  5  prime:  7
# factored model:
# (5) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^40 * (x + 3)^40 * (x + 4)^40 * (x + 6)^40 * (x + 2)^41 * (x + 5)^41
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  152  n.digits(prime):  [5, 0, 3]  sd:  5  prime:  7
# factored model:
# (5) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^42 * (x + 3)^42 * (x + 4)^42 * (x + 6)^42 * (x + 2)^43 * (x + 5)^43
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  159  n.digits(prime):  [5, 1, 3]  sd:  5  prime:  7
# factored model:
# (4) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^44 * (x + 3)^44 * (x + 4)^44 * (x + 6)^44 * (x + 2)^45 * (x + 5)^45
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  166  n.digits(prime):  [5, 2, 3]  sd:  5  prime:  7
# factored model:
# (3) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^46 * (x + 3)^46 * (x + 4)^46 * (x + 6)^46 * (x + 2)^47 * (x + 5)^47
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  173  n.digits(prime):  [5, 3, 3]  sd:  5  prime:  7
# factored model:
# (2) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^48 * (x + 3)^48 * (x + 4)^48 * (x + 6)^48 * (x + 2)^49 * (x + 5)^49
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  180  n.digits(prime):  [5, 4, 3]  sd:  5  prime:  7
# factored model:
# (4) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^50 * (x + 3)^50 * (x + 4)^50 * (x + 6)^50 * (x + 2)^51 * (x + 5)^51
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  187  n.digits(prime):  [5, 5, 3]  sd:  5  prime:  7
# factored model:
# (2) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^52 * (x + 3)^52 * (x + 4)^52 * (x + 6)^52 * (x + 2)^53 * (x + 5)^53
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# ------------------------------------------------------------------------
# n:  194  n.digits(prime):  [5, 6, 3]  sd:  5  prime:  7
# factored model:
# (3) * (x + 3*t^3 + 3*t^2 + 6*t + 5) * (x + 4*t^3 + 4*t^2 + t + 2) * (x + t^4 + 4*t^3 + 2*t^2 + 3*t) * (x + 2*t^4 + 6*t^2 + t + 5) * (x + 2*t^4 + t^3 + t^2 + 3*t + 5) * (x + 2*t^4 + 5*t^3 + t^2 + 6*t + 5) * (x + 5*t^4 + t^2 + 6*t + 2) * (x + 5*t^4 + 2*t^3 + 6*t^2 + t + 2) * (x + 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2) * (x + 6*t^4 + 3*t^3 + 5*t^2 + 4*t) * (x + 1)^54 * (x + 3)^54 * (x + 4)^54 * (x + 6)^54 * (x + 2)^55 * (x + 5)^55
#
# template:  {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# roots: {1, 5*t^4 + 2*t^3 + 6*t^2 + t + 2, 3, 4, 5, 6, 3*t^3 + 3*t^2 + 6*t + 5, 2, 2*t^4 + 5*t^3 + t^2 + 6*t + 5, 6*t^4 + 3*t^3 + 5*t^2 + 4*t, 2*t^4 + t^3 + t^2 + 3*t + 5, 4*t^3 + 4*t^2 + t + 2, 5*t^4 + 6*t^3 + 6*t^2 + 4*t + 2, t^4 + 4*t^3 + 2*t^2 + 3*t, 2*t^4 + 6*t^2 + t + 5, 5*t^4 + t^2 + 6*t + 2}
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
#  bad n:  [5]

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=7
residue=6
sdvalue=1
size=prime^sdvalue
badn=[]
count=0
template=Set([1, 2, 3, 4, 5, 6])
for k in [1..200]:
    n=s[k][0]
    if (1==1):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
        
        if (sd==sdvalue)&(mod(n,prime)==residue):
            count=1+count
            T = GF(size,'t')
            t=T.multiplicative_generator()
            U.<x> = T[]
            g=U(polynum)
            fg=g.factor()
            roots=[]
            expr=str(g)
            var('x')
            expr3=sage_eval(expr,locals={'x':0})
            if expr3==0:
                roots=roots+[0]
            for i in [1..size]:
                a=t^i
                expr3=sage_eval(expr,locals={'x':a})
                if expr3==0:
                    roots=roots+[t^i]
            roots=Set(roots)
            if roots!=template:
                badn=badn+[n]
            print "------------------------------------------------------------------------"
            print "n: ",n," n.digits(prime): ",n.digits(prime)," sd: ",sd," prime: ",prime
            print "factored model:";print fg;print
            print "template: ",template
            print "roots:",roots
print "&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&"
if count==0:print "null"
print " bad n: ",badn
# Out:
# ------------------------------------------------------------------------
# n:  6  n.digits(prime):  [6]  sd:  1  prime:  7
# factored model:
# (3) * (x + 1)^2 * (x + 2)^2 * (x + 3)^2 * (x + 4)^2 * (x + 5)^2 * (x + 6)^2
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  13  n.digits(prime):  [6, 1]  sd:  1  prime:  7
# factored model:
# (x + 1)^4 * (x + 2)^4 * (x + 3)^4 * (x + 4)^4 * (x + 5)^4 * (x + 6)^4
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  20  n.digits(prime):  [6, 2]  sd:  1  prime:  7
# factored model:
# (6) * (x + 1)^6 * (x + 2)^6 * (x + 3)^6 * (x + 4)^6 * (x + 5)^6 * (x + 6)^6
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  27  n.digits(prime):  [6, 3]  sd:  1  prime:  7
# factored model:
# (6) * (x + 1)^8 * (x + 2)^8 * (x + 3)^8 * (x + 4)^8 * (x + 5)^8 * (x + 6)^8
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  34  n.digits(prime):  [6, 4]  sd:  1  prime:  7
# factored model:
# (3) * (x + 1)^10 * (x + 2)^10 * (x + 3)^10 * (x + 4)^10 * (x + 5)^10 * (x + 6)^10
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  41  n.digits(prime):  [6, 5]  sd:  1  prime:  7
# factored model:
# (2) * (x + 1)^12 * (x + 2)^12 * (x + 3)^12 * (x + 4)^12 * (x + 5)^12 * (x + 6)^12
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  48  n.digits(prime):  [6, 6]  sd:  1  prime:  7
# factored model:
# (4) * (x + 1)^14 * (x + 2)^14 * (x + 3)^14 * (x + 4)^14 * (x + 5)^14 * (x + 6)^14
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  55  n.digits(prime):  [6, 0, 1]  sd:  1  prime:  7
# factored model:
# (4) * (x + 1)^16 * (x + 2)^16 * (x + 3)^16 * (x + 4)^16 * (x + 5)^16 * (x + 6)^16
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  62  n.digits(prime):  [6, 1, 1]  sd:  1  prime:  7
# factored model:
# (2) * (x + 1)^18 * (x + 2)^18 * (x + 3)^18 * (x + 4)^18 * (x + 5)^18 * (x + 6)^18
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  69  n.digits(prime):  [6, 2, 1]  sd:  1  prime:  7
# factored model:
# (3) * (x + 1)^20 * (x + 2)^20 * (x + 3)^20 * (x + 4)^20 * (x + 5)^20 * (x + 6)^20
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  76  n.digits(prime):  [6, 3, 1]  sd:  1  prime:  7
# factored model:
# (5) * (x + 1)^22 * (x + 2)^22 * (x + 3)^22 * (x + 4)^22 * (x + 5)^22 * (x + 6)^22
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  83  n.digits(prime):  [6, 4, 1]  sd:  1  prime:  7
# factored model:
# (6) * (x + 1)^24 * (x + 2)^24 * (x + 3)^24 * (x + 4)^24 * (x + 5)^24 * (x + 6)^24
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  90  n.digits(prime):  [6, 5, 1]  sd:  1  prime:  7
# factored model:
# (2) * (x + 1)^26 * (x + 2)^26 * (x + 3)^26 * (x + 4)^26 * (x + 5)^26 * (x + 6)^26
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  97  n.digits(prime):  [6, 6, 1]  sd:  1  prime:  7
# factored model:
# (6) * (x + 1)^28 * (x + 2)^28 * (x + 3)^28 * (x + 4)^28 * (x + 5)^28 * (x + 6)^28
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  104  n.digits(prime):  [6, 0, 2]  sd:  1  prime:  7
# factored model:
# (5) * (x + 1)^30 * (x + 2)^30 * (x + 3)^30 * (x + 4)^30 * (x + 5)^30 * (x + 6)^30
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  111  n.digits(prime):  [6, 1, 2]  sd:  1  prime:  7
# factored model:
# (4) * (x + 1)^32 * (x + 2)^32 * (x + 3)^32 * (x + 4)^32 * (x + 5)^32 * (x + 6)^32
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  118  n.digits(prime):  [6, 2, 2]  sd:  1  prime:  7
# factored model:
# (4) * (x + 1)^34 * (x + 2)^34 * (x + 3)^34 * (x + 4)^34 * (x + 5)^34 * (x + 6)^34
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  125  n.digits(prime):  [6, 3, 2]  sd:  1  prime:  7
# factored model:
# (5) * (x + 1)^36 * (x + 2)^36 * (x + 3)^36 * (x + 4)^36 * (x + 5)^36 * (x + 6)^36
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  132  n.digits(prime):  [6, 4, 2]  sd:  1  prime:  7
# factored model:
# (2) * (x + 1)^38 * (x + 2)^38 * (x + 3)^38 * (x + 4)^38 * (x + 5)^38 * (x + 6)^38
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  139  n.digits(prime):  [6, 5, 2]  sd:  1  prime:  7
# factored model:
# (2) * (x + 1)^40 * (x + 2)^40 * (x + 3)^40 * (x + 4)^40 * (x + 5)^40 * (x + 6)^40
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  146  n.digits(prime):  [6, 6, 2]  sd:  1  prime:  7
# factored model:
# (6) * (x + 1)^42 * (x + 2)^42 * (x + 3)^42 * (x + 4)^42 * (x + 5)^42 * (x + 6)^42
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  153  n.digits(prime):  [6, 0, 3]  sd:  1  prime:  7
# factored model:
# (3) * (x + 1)^44 * (x + 2)^44 * (x + 3)^44 * (x + 4)^44 * (x + 5)^44 * (x + 6)^44
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  160  n.digits(prime):  [6, 1, 3]  sd:  1  prime:  7
# factored model:
# (2) * (x + 1)^46 * (x + 2)^46 * (x + 3)^46 * (x + 4)^46 * (x + 5)^46 * (x + 6)^46
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  167  n.digits(prime):  [6, 2, 3]  sd:  1  prime:  7
# factored model:
# (3) * (x + 1)^48 * (x + 2)^48 * (x + 3)^48 * (x + 4)^48 * (x + 5)^48 * (x + 6)^48
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  174  n.digits(prime):  [6, 3, 3]  sd:  1  prime:  7
# factored model:
# (5) * (x + 1)^50 * (x + 2)^50 * (x + 3)^50 * (x + 4)^50 * (x + 5)^50 * (x + 6)^50
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  181  n.digits(prime):  [6, 4, 3]  sd:  1  prime:  7
# factored model:
# (3) * (x + 1)^52 * (x + 2)^52 * (x + 3)^52 * (x + 4)^52 * (x + 5)^52 * (x + 6)^52
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  188  n.digits(prime):  [6, 5, 3]  sd:  1  prime:  7
# factored model:
# (5) * (x + 1)^54 * (x + 2)^54 * (x + 3)^54 * (x + 4)^54 * (x + 5)^54 * (x + 6)^54
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# ------------------------------------------------------------------------
# n:  195  n.digits(prime):  [6, 6, 3]  sd:  1  prime:  7
# factored model:
# (4) * (x + 1)^56 * (x + 2)^56 * (x + 3)^56 * (x + 4)^56 * (x + 5)^56 * (x + 6)^56
#
# template:  {1, 2, 3, 4, 5, 6}
# roots: {1, 2, 3, 4, 5, 6}
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
#  bad n:  []
