# %%
P = Primes()
ZR.<x> = PolynomialRing(ZZ)
D.<x> = PolynomialRing(QQ)
R.<x> = PolynomialRing(QQ)
C.<x> = PolynomialRing(CC)
S = PowerSeriesRing(QQ,'x', default_prec=300)
#S.<x,y>=PowerSeriesRing(QQ,default_prec=300)
# Using "R = PolynomialRing(QQ,'x')" produces an error.
# Yet using S as defined here is fine (see definition of Fraleigh4 below)
# But S = PowerSeriesRing(QQ,'x','y') also produces an error.
def pochhammer(x,n):
    return product ([x+k for k in [0..n-1]])
def cRaleigh2(alpha,beta,nu):
    pchhmrA = pochhammer(alpha,nu)
    pchhmrB = pochhammer(beta,nu)
    fnu=factorial(nu)
    answer = D(pchhmrA*pchhmrB/fnu^2)
    return answer
def term(alpha,beta,p):
    return D(1/(alpha + p) + 1/(beta + p) - 2/(1 + p))
def eRaleigh(alpha, beta, nu):
    return D(sum([term(alpha, beta, p) for p in [0..nu - 1]]))
def FstarRaleigh2(alpha,beta,u,terms):
    fsr = sum([cRaleigh2(alpha, beta, nu)*eRaleigh(alpha,beta,nu)*u^nu for nu in [1..terms]])
    return D(fsr)
def Fraleigh2(alpha,beta,u,terms): 
    return D(sum([cRaleigh2(alpha,beta,nu)*u^nu for nu in [0..terms]]))
def FstarRaleigh3(n,m,x):
    alpha = (1/2-1/m)/2
    beta = (1/2+1/m)/2
    fsr2 = FstarRaleigh2(alpha,beta,x,n)
    return D(fsr2)
def Fraleigh4(n,m,x):
    alpha = (1/2-1/m)/2
    beta = (1/2+1/m)/2
    fr2 = Fraleigh2(alpha,beta,x,n)
    return D(fr2)
def exNo3c(n,m):
    a1 = S(x)*exp(S(FstarRaleigh3(n,m,x)/Fraleigh4(n,m,x))).O(2*n)
    # S(x) instead of x in df of a1 to avoid an error message
    # after use of the stripQuotationMarks command below.
    a2 = S(a1).O(n+1)
    return a2 # applying S to argument of exp is key.
def J(n,m):
    exn = exNo3c(n+2,m)
    jnm = 1/exn.reverse()
    return jnm.O(n+1) # Jtest is faster than J, and they agree.
def normalJ(n,m):
    f = J(n,m)
    return f.truncate(n+1)
def Jcoefficient(n,m,x):
    f = J(n+2,m,x)
    f1 = f.truncate(n+1)
    f1=f1.list()
    f1=Set(f1)
    g1 = f.truncate(n)
    g1 = g1.list()
    g1 = set(g1)
    h = f1.difference(g1)
    h = h.list()
    return h[0]
def xjNewStep(n,m,x): 
    f=J(n,m,x)
    fl=f.list()
    return (sum(c*x**i*(m**3*2**6)**i for i,c in enumerate(fl)))
def xjNew(n,m,x):
    return xjNewStep(n-1,m,x)
def xjNewCoefficient(n,m,x):
    if n>0:return (xjNew(n,m,x)-xjNew(n-1,m,x))/x^n
    if n==0:return 1
def xjNewTest(n,m,x):
    return D(xjNewStep(n-1,m,x))
def polynomialCoefficient(n,poly):
    return poly.list()[n]
def factorpairToFactor(factorpair):
    (monomial,exponent)=factorpair
    return monomial^exponent
def numericalfactor(polynomial):
    fp=polynomial.factor()
    lst=[factorpairToFactor(factorpair) for factorpair in fp]
    return polynomial/product(lst)
def lastfactor(polynomial):
    fp=polynomial.factor()
    fp=FiniteEnumeratedSet(fp)
    return factorpairToFactor(fp.last())
def reduced(polynomial):
    return numericalfactor(polynomial)*lastfactor(polynomial)
def stripQuotationMarks(string):
    var('x')
    return sage_eval(string,locals={'x':x})

def prime_n(a):return P.unrank(a-1)

def primeFactors(n):
    answer=[]
    lf=list(n.factor())
    length=len(lf)
    for k in [0..length-1]:
        pair=lf[k]
        (base,exponent)=pair
        answer=answer+[[base]]
    return(flatten(answer))

def primeFactorsInList(lst):
    ld=len(lst)
    primelist=[]
    for k in [0..ld-1]:
        a=ZZ(lst[k])
        primelist=primelist+[primeFactors(a)]
    primelist=flatten(primelist)
    primelist=list(set(primelist))
    return primelist

def den(a):
    if a in QQ:
        if a in ZZ:return 1
        return a.denominator()
def listdens(lst):
    return list(den(a) for a in lst)
def polynomialdenominator(poly):return lcm(listdens(poly))
def polynomialnumerator(poly):
    return expand(poly*polynomialdenominator(poly))
def num(a):return a.numerator()
def prime(n):
    P=Primes()
    return P.unrank(n-1)
def inclusiveListPrimesTo(n):
    if is_prime(n):
        return list(primes(n+1))
    else:
        return list(primes(n))
def chunk(k,list):
    chnk=[]
    for n in [k..len(list)-1]:
        chnk=chnk+[list[n]]
    return chnk
def drop(m,lst): return list(Set(lst).difference({m}))
def sort(list):
    answr=[]
    chnk=list
    for n in [0..len(list)-1]:
        m = min(chnk)
        answr=answr+[m]
        chnk=drop(m,chnk)
    return answr
def ord(p,n):return QQ.valuation(p)(n)
def base_conversion(number, base_from, base_to):  # by Vishnu Namboothiri
# https://ask.sagemath.org/question/9657/how-to-output-decimal-numbers-in-different-radix/
    if(base_from==10):
        return stripQuotationMarks((number.str(base=base_to)))
    else:
        decimal = Integer(str(number), base=base_from)
        return (stripQuotationMarks(decimal.str(base=base_to)))
def lastFactorWithIntegralFactors(polynomial):
    return polynomialnumerator(lastfactor(polynomial))
def numericalFactorWithIntegralFactors(polynomial):
    nf=numericalfactor(polynomial);
    pd=polynomialdenominator(lastfactor(polynomial))
    return nf/pd


def primeDivisors(n):
    pd=[]
    n=n
    fn=factor(n)
    ln=len(fn)
    for k in [0..ln-1]:
        part = fn[k]
        (prime,exponent) = part
        pd = pd + [prime]
    return pd 
def fOverField(f,prime,power):
    answer=[]
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    ppoly = U(f)
    expr=str(ppoly)
    var('x')
    fp=ppoly.factor()
    return ppoly

###################### following two routines disagree ####################
def factorOverField(f,prime,power):
    answer=[]
    T = GF(prime^power,'t')
    G.<t>= GF(prime^power)
    U.<x> = T[]
    ppoly = U(f)
    expr=str(ppoly)
    var('x')
    fp=ppoly.factor()
    return fp

def factorOverField2(poly,prime,power,j):
    sd = leastSplittingDegree(poly,prime,bound)
    T=GF(prime^j)
    G.<t>= GF(prime^sd)
    U.<x> = T[]
    ppoly=U(poly)
    fpp=ppoly.factor()
    return fpp

############################

#######################################################
# splitting tests below fail at  e.g. f = x + 1 
############################################################

def splitsTF(f,prime,power):
    T = GF(prime^power)
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx > 1:return(False)
    return(True)

def leastSplittingDegree(f,prime,bound):
    for power in [1..bound]:
        tf=splitsTF(f,prime,power)
        if tf == True:return power
    return -1

#########################################################

def firstNprimes(n):
    P=Primes()
    first=[]
    for k in [0..n-1]:
        first=first+[P.unrank(k)]
    return first

def slopeExistsTF(pairlist):
    lenth=len(pairlist)
    if lenth<3:return False
    slopes=[]
    for k in [1..lenth-1]:
        pair1=pairlist[k-1]
        abscissa1=pair1[0]
        ordinate1=pair1[1]
        pair2=pairlist[k]
        abscissa2=pair2[0]
        ordinate2=pair2[1]
        dx=abscissa2-abscissa1
        if dx == 0:return False
        dy=ordinate2-ordinate1
        slope=dy/dx
        slopes=slopes+[slope]
    slopes=Set(slopes)
    if len(slopes) == 1:
        return [True,slopes[0]]
    if len(slopes) > 1:
        return False 
    
def zeroOfLinearMonomial(monomial,x):return x-monomial

def totalDegreeOverField(f,prime,power):
    T = GF(prime^power,'t')
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    td=0
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        td=td+exponent
    return td

def logsAndMultiplicitiesOverField(f,prime,power):
    T = GF(prime^power,'t')
    b=T.multiplicative_generator()
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    data=[]
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx == 1:
            xm=x-monomial
            if xm==0:data=data+[[-1,exponent]]
            if xm != 0:
                for i in [1..prime^power-1]:
                    if b^i==xm:data=data+[[i,exponent]]
    return data

def generatingZeroLogsOverField(f,prime,power):
    T = GF(prime^power,'t')
    b=T.multiplicative_generator()
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    data=[]
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx == 1:
            xm=x-monomial
            if xm==0:data=data+[[-1,exponent]]
            if xm != 0:
                for i in [1..prime^power-1]:
                    if b^i==xm:
                        if mod(i,prime)>0:
                            data=data+[i]
    data=data.sort()
    return data



def generatingZeroLogsAndMultiplicitiesOverField(f,prime,power):
    T = GF(prime^power,'t')
    b=T.multiplicative_generator()
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    data=[]
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx == 1:
            xm=x-monomial
            if xm==0:data=data+[[-1,exponent]]
            if xm != 0:
                for i in [1..prime^power-1]:
                    if b^i==xm:
                        if mod(i,prime)>0:
                            data=data+[[i,exponent]]
    return data




def logsAndMultiplicitiesOverFieldTest(f,prime,power):
    T = GF(prime^power,'t')
    b=T.multiplicative_generator()
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    print gf
    lnf = len(gf)-1
    data=[]
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx == 1:
            xm=x-monomial
            if xm==0:data=data+[[-1,exponent]]
            if xm != 0:
                for i in [1..prime^power-1]:
                    if b^i==xm:data=data+[[i,exponent]]
    return data

def logsAndMultiplicitiesOverFieldTest(f,prime,power):
    T = GF(prime^power,'t')
    b=T.multiplicative_generator()
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    print gf
    lnf = len(gf)-1
    data=[]
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx == 1:
            xm=x-monomial
            if xm==0:data=data+[[-1,exponent]]
            if xm != 0:
                for i in [1..prime^power-1]:
                    if b^i==xm:data=data+[[i,exponent]]
    return data



def dropzeros(list):
    data=[]
    el=len(list)
    for j  in [0..el-1]:
        lj=list[j]
        if lj != 0:data=data+[lj]
    return data

def padListOnRightToLengthK(listo,k):
    length=len(listo)
    padded=listo
   
    if length<k:
        for j in [length..k-1]:
            padded=padded+[0]
           
        return padded
    return listo

def testCandidateZeroLogOverField(f,prime,power,candidate):
    tf=False
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    poly = U(f)
    expr=str(poly)
    var('x')
    a=t^candidate
    expr3=sage_eval(expr,locals={'x':a})
    if expr3 == 0:tf=True
    return tf

def digitsToInteger(digitlist,prime):
    lenth=len(digitlist)
    sum=0
    for k in [0..lenth-1]:
        sum=sum+prime^k*digitlist[k]
    return sum

def minimumIntegerRepresentedInList(lstlst,prime):
    answer=Infinity
    ln=len(lstlst)
    for k in [0..ln-1]:
        lst=lstlst[k]
        n=digitsToInteger(lst,prime)
        if n < answer:answer=n
    return answer

def lastElement(lst):
    ln=len(lst)
    return lst[ln-1]

def push(lst):
    if len(lst)<2:return lst
    answer=[lastElement(lst)]
    for k in [0..len(lst)-2]:
        answer=flatten([answer]+[lst[k]])
    return answer

def cyclicPermutationEquivalenceClass(lst):
    if lst==[]:return lst
    answer=[lst]
    lnth=len(lst)
    for k in [0..lnth-2]:
        ple=push(lastElement(answer))
        answer=answer+[ple]
    return answer

def bestRepresentativeOfCyclicEquivalenceClass(lst,prime):
    cpec=cyclicPermutationEquivalenceClass(lst)
    minm=minimumIntegerRepresentedInList(cpec,prime)
    lcpec=len(lst) # ... = len(cpec)
    for k in [0..lcpec-1]:
        ck=cpec[k]
        dti=digitsToInteger(ck,prime)
        if minm==dti:return ck
    return "error"

def directZeroLogOverField(f,prime,power):
    tf=False
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    poly = U(f)
    expr=str(poly)
    var('x')
    answer=[]
    expr3=sage_eval(expr,locals={'x':0})
    if expr3 == 0:
        answer=[0]
    for i in [1..prime^power-1]:
        a=t^i
        expr3=sage_eval(expr,locals={'x':a})
        if expr3 == 0:
            answer=answer+[i]
    return answer

def reduce(f,prime):
    poly=polynomialnumerator(D(f))
    
    ls=list(poly)
    
    def modulo(n):
        return ZZ(mod(n,prime))
    def listmod(list):
        return map(modulo,list)
    lmls = listmod(ls)
    sm=0
    for j in [0..len(lmls)-1]:
        sm=sm+lmls[j]*x^j
    return sm


mt=[ #McKay-Thompson series w. a(0) = 24.
[-1, 1],
[0, 24],
[1, 276],
[2, 2048],
[3, 11202],
[4, 49152],
[5, 184024],
[6, 614400],
[7, 1881471],
[8, 5373952],
[9, 14478180],
[10, 37122048],
[11, 91231550],
[12, 216072192],
[13, 495248952],
[14, 1102430208],
[15, 2390434947],
[16, 5061476352],
[17, 10487167336],
[18, 21301241856],
[19, 42481784514],
[20, 83300614144],
[21, 160791890304],
[22, 305854488576],
[23, 573872089212],
[24, 1063005978624],
[25,1945403602764],
[26, 3519965179904],
[27, 6300794030460],
[28, 11164248047616],
[29, 19591528119288],
[30, 34065932304384],
[31, 58718797964805],
[32, 100372723007488],
[33, 170215559855424],
[34, 286470013685760],
[35, 478625723149576],
[36, 794110053826560],
[37, 1308745319975256],
[38, 2143055278039040],
[39, 3487563372381816],
[40, 5641848336678912],
[41, 9074553043554568],
[42, 14515166263443456],
[43, 23093778743102262],
[44, 36552977852071936],
[45, 57567784186189368],
[46, 90226777113575424],
[47, 140752796480416011],
[48, 218578429975461888],
[49, 337945040343588276],
[50, 520271697765971968],
[51, 797652526220573580],
[52, 1218002527825723392],
[53, 1852604006634050072],
[54, 2807138079496716288],
[55, 4237760460302936433],
[56, 6374456847628238848],
[57, 9554873766107770560],
[58, 14273181657059143680],
[59, 21250450411204068910],
[60, 31535729115847852032],
[61, 46650835290143061624],
[62, 68797209365301886976],
[63, 101150679669913197462],
[64, 148280443106626633728],
[65, 216743142763626253712],
[66, 315923191441199824896],
[67, 459218611940943755226],
[68, 665710603285072019456],
[69, 962508846974918603904],
[70, 1388038765923851599872],
[71, 1996639069403279491427],
[72, 2864978197116521938944],
[73, 4100990608911708903432],
[74, 5856297079648098807808],
[75, 8343432715970391209502],
[76, 11859696700297921757184],
[77, 16820105145987654631552],
[78, 23802835313046730063872],
[79, 33611779636250175278886],
[80, 47362494062244172660736],
[81, 66600077798590855556532],
[82, 93460562353103053049856],
[83, 130891485964083426534122],
[84, 182952844329494181838848],
[85, 255227018229957765044016],
[86, 355376219286719031156736],
[87, 493899311443420857952845],
[88, 685157678128482627354624],
[89, 948763597225844233250504],
[90, 1311456320500974276980736],
[91, 1809633323386495729057992],
[92, 2492760414984152205361152],
[93, 3427959082742197097793024],
[94, 4706168520874397834575872],
[95, 6450411048962389429976770],
[96, 8826863296640622526464000],
[97, 12059665023346371597383976],
[98, 16450700321708764061517824],
[99, 22405985191605778318221966],
[100, 30470821082605141257437184]]

def sumOfRoots(f,prime,power):
    answer=0
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    #U.<x> = T[] -- this line gave an error
    poly = U(f)
    expr=str(poly)
    var('x')
    for i in [1..prime^power-1]:
        a=t^i
        expr3=sage_eval(expr,locals={'x':a})
        if expr3 == 0:
            answer=answer+a
    return answer

def productOfNonzeroRoots(f,prime,power):
    answer=1
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    #U.<x> = T[] -- this line gave an error
    poly = U(f)
    expr=str(poly)
    var('x')
    for i in [1..prime^power-1]:
        a=t^i
        expr3=sage_eval(expr,locals={'x':a})
        if expr3 == 0:
            answer=answer*a
    return answer

def roots(f,prime,power):
    answer=[]
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    #U.<x> = T[] -- this line gave an error
    poly = U(f)
    expr=str(poly)
    var('x')
    expr3=sage_eval(expr,locals={'x':0})
    if expr3==0:answer=answer+[0]
    for i in [1..prime^power-1]:
        a=t^i
        expr3=sage_eval(expr,locals={'x':a})
        if expr3 == 0:
            answer=answer+[a]
    return answer

def numericalTermOverFieldNoPrint(f,prime,power):
    T = GF(prime^power,'t')
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    xproduct=1
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        xproduct=xproduct*monomial^exponent
    return g/xproduct

def polynomialDegree(poly):
    return len(poly.list())-1

def leadingCoefficient(poly):
    dp=D(poly)
    deg=polynomialDegree(dp)
    return dp.list()[deg]

def testRootLogTimesPrimeCn(f,prime,power):
    tf=True
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    poly = U(f)
    expr=str(poly)
    var('x')
    fp=poly.factor()
    lnf = len(fp) - 1
    flag = 1
    for i in [1..prime^power-1]:
        a=t^i
        expr3=sage_eval(expr,locals={'x':a})
        if expr3 == 0:
            j=i*prime
            b=t^j
            expr4=sage_eval(expr,locals={'x':b})
            if expr4!=0:
                tf=False
                print (i,j)
                
    return tf

def basicRoots(f,prime,power):
    answer=[]
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    poly = U(f)
    expr=str(poly)
    var('x')
    fp=poly.factor()
    lnf = len(fp) - 1
    flag = 1
    for i in [1..prime^power-1]:
        if mod(i,prime)!=0:
            a=t^i
            expr3=sage_eval(expr,locals={'x':a})
            if expr3 == 0:answer=answer+[i]
    return answer

def basicRootsDigits(f,prime,power):
    answer=[]
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    poly = U(f)
    expr=str(poly)
    var('x')
    fp=poly.factor()
    lnf = len(fp) - 1
    flag = 1
    for i in [1..prime^power-1]:
        if mod(i,prime)!=0:
            a=t^i
            expr3=sage_eval(expr,locals={'x':a})
            if expr3 == 0:answer=answer+[padListOnRightToLengthK(i.digits(prime),power)]
    return answer

def basicLogsAndMultiplicitiesOverField(f,prime,power):
    T = GF(prime^power,'t')
    b=T.multiplicative_generator()
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    data=[]
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx == 1:
            xm=x-monomial
            if xm==0:data=data+[[-1,exponent]]
            if xm != 0:
                for i in [1..prime^power-1]:
                    if mod(i,prime)!=0:
                        if b^i==xm:data=data+[[i,exponent]]
    return data.sort()

def totalMultiplicityOverField(f,prime,power):
    tm=0
    T = GF(prime^power,'t')
    b=T.multiplicative_generator()
    U.<x> = T[]
    g=U(f)
    gf=g.factor()
    lnf = len(gf)-1
    data=[]
    for nn in [0..lnf]:
        part = gf[nn]
        (monomial,exponent) = part
        mdx = monomial.degree()
        if mdx == 1:tm=tm+exponent
    return tm

def testRootLogTimesPrimeCn(f,prime,power):
    tf=True
    T = GF(prime^power)
    G.<t>= GF(prime^power)
    U.<x> = T[]
    poly = U(f)
    expr=str(poly)
    var('x')
    fp=poly.factor()
    lnf = len(fp) - 1
    flag = 1
    for i in [1..prime^power-1]:
        a=t^i
        expr3=sage_eval(expr,locals={'x':a})
        if expr3 == 0:
            j=i*prime
            b=t^j
            expr4=sage_eval(expr,locals={'x':b})
            if expr4!=0:
                tf=False
                print (i,j)
                
    return tf

# %%
## printed output has been snipped

import pickle
wfile=open('/Users/barrybrent/run1jun21no1.txt','a')
data=[]
for m in [3..500]:
    print m
    data=data+[[m,normalJ(200,m)]]
s=pickle.dumps(str(data))
wfile.write(s)
wfile.close()
#########################
import pickle
rfile = open('/Users/barrybrent/run1jun21no1.txt','r')
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)

polydata=[]

wfile = open('/Users/barrybrent/run14jun21no14.txt','a') # xJ polynomials
for n in [0..200]:
    data=[]
    for k in [0..2*n+1]:
        print (n,k)
        m = s[k][0]
        poly=x*s[k][1] 
        cf=polynomialCoefficient(n,poly)
        data=data+[[m,cf*m^(2*n)]]
    rl=R.lagrange_polynomial(data)
    polydata=polydata+[[n-1,rl]] 

    
t = pickle.dumps(str(polydata))
wfile.write(t)
wfile.close() # print-output snippeds
for n in [0..200]:
    data=[]
    for k in [0..2*n+1]:
        print (n,k)
        m = s[k][0]
        poly=x*s[k][1] 
        cf=polynomialCoefficient(n,poly)
        data=data+[[m,cf*m^(2*n)]]
    rl=R.lagrange_polynomial(data)
    polydata=polydata+[[n-1,rl]] 

    
t = pickle.dumps(str(polydata))
wfile.write(t)
wfile.close() # print-output snipped

# %% [markdown]
# sum

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') #Jfn
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
len(s)
# Out:
# 201

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=3
pairs=[]
for k in [1..200]:
    n=s[k][0]
    if (1==1)&(n>prime):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
        pair=(mod(n,prime),sd)
        pairs=pairs+[pair]
print sort(union(pairs))
# Out:
# [(0, 1), (1, 1), (1, 2), (1, 3), (2, 1), (2, 2), (2, 3), (2, 4)]

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=3
residue=0
sdvalue=1
badn=[]
count=0
flag=1
template=[]
for k in [1..200]:
    n=s[k][0]
    if (n>prime-1)&(mod(n,prime)==residue):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
    
        if (sd==sdvalue)&(flag==1):
            template=basicRoots(polynum,prime,sd)
            flag=0
    
        if (sd==sdvalue):
            count=1+count
            br=basicRoots(polynum,prime,sd)
            if br!=template:badn=badn+[n]
            lm=logsAndMultiplicitiesOverField(polynum,prime,sd)
            tm=totalMultiplicityOverField(polynum,prime,sd)
            print "------------------------------------------------------------------------"
            print "n: ",n," n.digits(prime): ",n.digits(prime)," sd: ",sd," prime: ",prime," n mod prime: ",mod(n,prime)
            print "basic roots:";print br
            print "root-logs and multiplicities:";print sorted(lm)
            print "total multiplicity of roots: ",tm
print "&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&"
if count==0:print "null"
print " bad n: ",badn;print "template: ",template
# Out:
# ------------------------------------------------------------------------
# n:  3  n.digits(prime):  [0, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 2], [2, 2]]
# total multiplicity of roots:  6
# ------------------------------------------------------------------------
# n:  6  n.digits(prime):  [0, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 4], [2, 4]]
# total multiplicity of roots:  10
# ------------------------------------------------------------------------
# n:  9  n.digits(prime):  [0, 0, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 6], [2, 6]]
# total multiplicity of roots:  14
# ------------------------------------------------------------------------
# n:  12  n.digits(prime):  [0, 1, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 8], [2, 8]]
# total multiplicity of roots:  18
# ------------------------------------------------------------------------
# n:  15  n.digits(prime):  [0, 2, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 10], [2, 10]]
# total multiplicity of roots:  22
# ------------------------------------------------------------------------
# n:  18  n.digits(prime):  [0, 0, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 12], [2, 12]]
# total multiplicity of roots:  26
# ------------------------------------------------------------------------
# n:  21  n.digits(prime):  [0, 1, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 14], [2, 14]]
# total multiplicity of roots:  30
# ------------------------------------------------------------------------
# n:  24  n.digits(prime):  [0, 2, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 16], [2, 16]]
# total multiplicity of roots:  34
# ------------------------------------------------------------------------
# n:  27  n.digits(prime):  [0, 0, 0, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 18], [2, 18]]
# total multiplicity of roots:  38
# ------------------------------------------------------------------------
# n:  30  n.digits(prime):  [0, 1, 0, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 20], [2, 20]]
# total multiplicity of roots:  42
# ------------------------------------------------------------------------
# n:  33  n.digits(prime):  [0, 2, 0, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 22], [2, 22]]
# total multiplicity of roots:  46
# ------------------------------------------------------------------------
# n:  36  n.digits(prime):  [0, 0, 1, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 24], [2, 24]]
# total multiplicity of roots:  50
# ------------------------------------------------------------------------
# n:  39  n.digits(prime):  [0, 1, 1, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 26], [2, 26]]
# total multiplicity of roots:  54
# ------------------------------------------------------------------------
# n:  42  n.digits(prime):  [0, 2, 1, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 28], [2, 28]]
# total multiplicity of roots:  58
# ------------------------------------------------------------------------
# n:  45  n.digits(prime):  [0, 0, 2, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 30], [2, 30]]
# total multiplicity of roots:  62
# ------------------------------------------------------------------------
# n:  48  n.digits(prime):  [0, 1, 2, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 32], [2, 32]]
# total multiplicity of roots:  66
# ------------------------------------------------------------------------
# n:  51  n.digits(prime):  [0, 2, 2, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 34], [2, 34]]
# total multiplicity of roots:  70
# ------------------------------------------------------------------------
# n:  54  n.digits(prime):  [0, 0, 0, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 36], [2, 36]]
# total multiplicity of roots:  74
# ------------------------------------------------------------------------
# n:  57  n.digits(prime):  [0, 1, 0, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 38], [2, 38]]
# total multiplicity of roots:  78
# ------------------------------------------------------------------------
# n:  60  n.digits(prime):  [0, 2, 0, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 40], [2, 40]]
# total multiplicity of roots:  82
# ------------------------------------------------------------------------
# n:  63  n.digits(prime):  [0, 0, 1, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 42], [2, 42]]
# total multiplicity of roots:  86
# ------------------------------------------------------------------------
# n:  66  n.digits(prime):  [0, 1, 1, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 44], [2, 44]]
# total multiplicity of roots:  90
# ------------------------------------------------------------------------
# n:  69  n.digits(prime):  [0, 2, 1, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 46], [2, 46]]
# total multiplicity of roots:  94
# ------------------------------------------------------------------------
# n:  72  n.digits(prime):  [0, 0, 2, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 48], [2, 48]]
# total multiplicity of roots:  98
# ------------------------------------------------------------------------
# n:  75  n.digits(prime):  [0, 1, 2, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 50], [2, 50]]
# total multiplicity of roots:  102
# ------------------------------------------------------------------------
# n:  78  n.digits(prime):  [0, 2, 2, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 52], [2, 52]]
# total multiplicity of roots:  106
# ------------------------------------------------------------------------
# n:  81  n.digits(prime):  [0, 0, 0, 0, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 54], [2, 54]]
# total multiplicity of roots:  110
# ------------------------------------------------------------------------
# n:  84  n.digits(prime):  [0, 1, 0, 0, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 56], [2, 56]]
# total multiplicity of roots:  114
# ------------------------------------------------------------------------
# n:  87  n.digits(prime):  [0, 2, 0, 0, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 58], [2, 58]]
# total multiplicity of roots:  118
# ------------------------------------------------------------------------
# n:  90  n.digits(prime):  [0, 0, 1, 0, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 60], [2, 60]]
# total multiplicity of roots:  122
# ------------------------------------------------------------------------
# n:  93  n.digits(prime):  [0, 1, 1, 0, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 62], [2, 62]]
# total multiplicity of roots:  126
# ------------------------------------------------------------------------
# n:  96  n.digits(prime):  [0, 2, 1, 0, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 64], [2, 64]]
# total multiplicity of roots:  130
# ------------------------------------------------------------------------
# n:  99  n.digits(prime):  [0, 0, 2, 0, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 66], [2, 66]]
# total multiplicity of roots:  134
# ------------------------------------------------------------------------
# n:  102  n.digits(prime):  [0, 1, 2, 0, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 68], [2, 68]]
# total multiplicity of roots:  138
# ------------------------------------------------------------------------
# n:  105  n.digits(prime):  [0, 2, 2, 0, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 70], [2, 70]]
# total multiplicity of roots:  142
# ------------------------------------------------------------------------
# n:  108  n.digits(prime):  [0, 0, 0, 1, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 72], [2, 72]]
# total multiplicity of roots:  146
# ------------------------------------------------------------------------
# n:  111  n.digits(prime):  [0, 1, 0, 1, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 74], [2, 74]]
# total multiplicity of roots:  150
# ------------------------------------------------------------------------
# n:  114  n.digits(prime):  [0, 2, 0, 1, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 76], [2, 76]]
# total multiplicity of roots:  154
# ------------------------------------------------------------------------
# n:  117  n.digits(prime):  [0, 0, 1, 1, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 78], [2, 78]]
# total multiplicity of roots:  158
# ------------------------------------------------------------------------
# n:  120  n.digits(prime):  [0, 1, 1, 1, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 80], [2, 80]]
# total multiplicity of roots:  162
# ------------------------------------------------------------------------
# n:  123  n.digits(prime):  [0, 2, 1, 1, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 82], [2, 82]]
# total multiplicity of roots:  166
# ------------------------------------------------------------------------
# n:  126  n.digits(prime):  [0, 0, 2, 1, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 84], [2, 84]]
# total multiplicity of roots:  170
# ------------------------------------------------------------------------
# n:  129  n.digits(prime):  [0, 1, 2, 1, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 86], [2, 86]]
# total multiplicity of roots:  174
# ------------------------------------------------------------------------
# n:  132  n.digits(prime):  [0, 2, 2, 1, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 88], [2, 88]]
# total multiplicity of roots:  178
# ------------------------------------------------------------------------
# n:  135  n.digits(prime):  [0, 0, 0, 2, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 90], [2, 90]]
# total multiplicity of roots:  182
# ------------------------------------------------------------------------
# n:  138  n.digits(prime):  [0, 1, 0, 2, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 92], [2, 92]]
# total multiplicity of roots:  186
# ------------------------------------------------------------------------
# n:  141  n.digits(prime):  [0, 2, 0, 2, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 94], [2, 94]]
# total multiplicity of roots:  190
# ------------------------------------------------------------------------
# n:  144  n.digits(prime):  [0, 0, 1, 2, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 96], [2, 96]]
# total multiplicity of roots:  194
# ------------------------------------------------------------------------
# n:  147  n.digits(prime):  [0, 1, 1, 2, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 98], [2, 98]]
# total multiplicity of roots:  198
# ------------------------------------------------------------------------
# n:  150  n.digits(prime):  [0, 2, 1, 2, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 100], [2, 100]]
# total multiplicity of roots:  202
# ------------------------------------------------------------------------
# n:  153  n.digits(prime):  [0, 0, 2, 2, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 102], [2, 102]]
# total multiplicity of roots:  206
# ------------------------------------------------------------------------
# n:  156  n.digits(prime):  [0, 1, 2, 2, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 104], [2, 104]]
# total multiplicity of roots:  210
# ------------------------------------------------------------------------
# n:  159  n.digits(prime):  [0, 2, 2, 2, 1]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 106], [2, 106]]
# total multiplicity of roots:  214
# ------------------------------------------------------------------------
# n:  162  n.digits(prime):  [0, 0, 0, 0, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 108], [2, 108]]
# total multiplicity of roots:  218
# ------------------------------------------------------------------------
# n:  165  n.digits(prime):  [0, 1, 0, 0, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 110], [2, 110]]
# total multiplicity of roots:  222
# ------------------------------------------------------------------------
# n:  168  n.digits(prime):  [0, 2, 0, 0, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 112], [2, 112]]
# total multiplicity of roots:  226
# ------------------------------------------------------------------------
# n:  171  n.digits(prime):  [0, 0, 1, 0, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 114], [2, 114]]
# total multiplicity of roots:  230
# ------------------------------------------------------------------------
# n:  174  n.digits(prime):  [0, 1, 1, 0, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 116], [2, 116]]
# total multiplicity of roots:  234
# ------------------------------------------------------------------------
# n:  177  n.digits(prime):  [0, 2, 1, 0, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 118], [2, 118]]
# total multiplicity of roots:  238
# ------------------------------------------------------------------------
# n:  180  n.digits(prime):  [0, 0, 2, 0, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 120], [2, 120]]
# total multiplicity of roots:  242
# ------------------------------------------------------------------------
# n:  183  n.digits(prime):  [0, 1, 2, 0, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 122], [2, 122]]
# total multiplicity of roots:  246
# ------------------------------------------------------------------------
# n:  186  n.digits(prime):  [0, 2, 2, 0, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 124], [2, 124]]
# total multiplicity of roots:  250
# ------------------------------------------------------------------------
# n:  189  n.digits(prime):  [0, 0, 0, 1, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 126], [2, 126]]
# total multiplicity of roots:  254
# ------------------------------------------------------------------------
# n:  192  n.digits(prime):  [0, 1, 0, 1, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 128], [2, 128]]
# total multiplicity of roots:  258
# ------------------------------------------------------------------------
# n:  195  n.digits(prime):  [0, 2, 0, 1, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 130], [2, 130]]
# total multiplicity of roots:  262
# ------------------------------------------------------------------------
# n:  198  n.digits(prime):  [0, 0, 1, 1, 2]  sd:  1  prime:  3  n mod prime:  0
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 132], [2, 132]]
# total multiplicity of roots:  266
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
#  bad n:  []
# template:  [1, 2]

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=3
residue=1
sdvalue=1
badn=[]
count=0
flag=1
template=[]
for k in [1..200]:
    n=s[k][0]
    if (n>prime-1)&(mod(n,prime)==residue):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
    
        if (sd==sdvalue)&(flag==1):
            template=basicRoots(polynum,prime,sd)
            flag=0
    
        if (sd==sdvalue):
            count=1+count
            br=basicRoots(polynum,prime,sd)
            if br!=template:badn=badn+[n]
            lm=logsAndMultiplicitiesOverField(polynum,prime,sd)
            tm=totalMultiplicityOverField(polynum,prime,sd)
            print "------------------------------------------------------------------------"
            print "n: ",n," n.digits(prime): ",n.digits(prime)," sd: ",sd," prime: ",prime," n mod prime: ",mod(n,prime)
            print "basic roots:";print br
            print "root-logs and multiplicities:";print sorted(lm)
            print "total multiplicity of roots: ",tm
print "&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&"
if count==0:print "null"
print " bad n: ",badn;print "template: ",template
# Out:
# ------------------------------------------------------------------------
# n:  4  n.digits(prime):  [1, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 2], [2, 2]]
# total multiplicity of roots:  6
# ------------------------------------------------------------------------
# n:  7  n.digits(prime):  [1, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 4], [2, 4]]
# total multiplicity of roots:  10
# ------------------------------------------------------------------------
# n:  10  n.digits(prime):  [1, 0, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 8], [1, 4], [2, 4]]
# total multiplicity of roots:  16
# ------------------------------------------------------------------------
# n:  13  n.digits(prime):  [1, 1, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 8], [2, 8]]
# total multiplicity of roots:  18
# ------------------------------------------------------------------------
# n:  16  n.digits(prime):  [1, 2, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 10], [2, 10]]
# total multiplicity of roots:  22
# ------------------------------------------------------------------------
# n:  19  n.digits(prime):  [1, 0, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 12], [2, 12]]
# total multiplicity of roots:  26
# ------------------------------------------------------------------------
# n:  22  n.digits(prime):  [1, 1, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 8], [1, 12], [2, 12]]
# total multiplicity of roots:  32
# ------------------------------------------------------------------------
# n:  25  n.digits(prime):  [1, 2, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 16], [2, 16]]
# total multiplicity of roots:  34
# ------------------------------------------------------------------------
# n:  28  n.digits(prime):  [1, 0, 0, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 18], [2, 18]]
# total multiplicity of roots:  38
# ------------------------------------------------------------------------
# n:  31  n.digits(prime):  [1, 1, 0, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 20], [2, 20]]
# total multiplicity of roots:  42
# ------------------------------------------------------------------------
# n:  37  n.digits(prime):  [1, 0, 1, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 24], [2, 24]]
# total multiplicity of roots:  50
# ------------------------------------------------------------------------
# n:  40  n.digits(prime):  [1, 1, 1, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 8], [1, 24], [2, 24]]
# total multiplicity of roots:  56
# ------------------------------------------------------------------------
# n:  43  n.digits(prime):  [1, 2, 1, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 28], [2, 28]]
# total multiplicity of roots:  58
# ------------------------------------------------------------------------
# n:  46  n.digits(prime):  [1, 0, 2, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 8], [1, 28], [2, 28]]
# total multiplicity of roots:  64
# ------------------------------------------------------------------------
# n:  52  n.digits(prime):  [1, 2, 2, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 34], [2, 34]]
# total multiplicity of roots:  70
# ------------------------------------------------------------------------
# n:  55  n.digits(prime):  [1, 0, 0, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 8], [1, 34], [2, 34]]
# total multiplicity of roots:  76
# ------------------------------------------------------------------------
# n:  58  n.digits(prime):  [1, 1, 0, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 8], [1, 36], [2, 36]]
# total multiplicity of roots:  80
# ------------------------------------------------------------------------
# n:  61  n.digits(prime):  [1, 2, 0, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 40], [2, 40]]
# total multiplicity of roots:  82
# ------------------------------------------------------------------------
# n:  64  n.digits(prime):  [1, 0, 1, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 42], [2, 42]]
# total multiplicity of roots:  86
# ------------------------------------------------------------------------
# n:  67  n.digits(prime):  [1, 1, 1, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 44], [2, 44]]
# total multiplicity of roots:  90
# ------------------------------------------------------------------------
# n:  70  n.digits(prime):  [1, 2, 1, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 8], [1, 44], [2, 44]]
# total multiplicity of roots:  96
# ------------------------------------------------------------------------
# n:  73  n.digits(prime):  [1, 0, 2, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 48], [2, 48]]
# total multiplicity of roots:  98
# ------------------------------------------------------------------------
# n:  76  n.digits(prime):  [1, 1, 2, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 50], [2, 50]]
# total multiplicity of roots:  102
# ------------------------------------------------------------------------
# n:  79  n.digits(prime):  [1, 2, 2, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 52], [2, 52]]
# total multiplicity of roots:  106
# ------------------------------------------------------------------------
# n:  82  n.digits(prime):  [1, 0, 0, 0, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 8], [1, 52], [2, 52]]
# total multiplicity of roots:  112
# ------------------------------------------------------------------------
# n:  88  n.digits(prime):  [1, 2, 0, 0, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 8], [1, 56], [2, 56]]
# total multiplicity of roots:  120
# ------------------------------------------------------------------------
# n:  91  n.digits(prime):  [1, 0, 1, 0, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 60], [2, 60]]
# total multiplicity of roots:  122
# ------------------------------------------------------------------------
# n:  94  n.digits(prime):  [1, 1, 1, 0, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 8], [1, 60], [2, 60]]
# total multiplicity of roots:  128
# ------------------------------------------------------------------------
# n:  97  n.digits(prime):  [1, 2, 1, 0, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 64], [2, 64]]
# total multiplicity of roots:  130
# ------------------------------------------------------------------------
# n:  100  n.digits(prime):  [1, 0, 2, 0, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 66], [2, 66]]
# total multiplicity of roots:  134
# ------------------------------------------------------------------------
# n:  103  n.digits(prime):  [1, 1, 2, 0, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 68], [2, 68]]
# total multiplicity of roots:  138
# ------------------------------------------------------------------------
# n:  109  n.digits(prime):  [1, 0, 0, 1, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 72], [2, 72]]
# total multiplicity of roots:  146
# ------------------------------------------------------------------------
# n:  112  n.digits(prime):  [1, 1, 0, 1, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 74], [2, 74]]
# total multiplicity of roots:  150
# ------------------------------------------------------------------------
# n:  115  n.digits(prime):  [1, 2, 0, 1, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 8], [1, 74], [2, 74]]
# total multiplicity of roots:  156
# ------------------------------------------------------------------------
# n:  118  n.digits(prime):  [1, 0, 1, 1, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 8], [1, 76], [2, 76]]
# total multiplicity of roots:  160
# ------------------------------------------------------------------------
# n:  121  n.digits(prime):  [1, 1, 1, 1, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 80], [2, 80]]
# total multiplicity of roots:  162
# ------------------------------------------------------------------------
# n:  124  n.digits(prime):  [1, 2, 1, 1, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 82], [2, 82]]
# total multiplicity of roots:  166
# ------------------------------------------------------------------------
# n:  127  n.digits(prime):  [1, 0, 2, 1, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 84], [2, 84]]
# total multiplicity of roots:  170
# ------------------------------------------------------------------------
# n:  130  n.digits(prime):  [1, 1, 2, 1, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 8], [1, 84], [2, 84]]
# total multiplicity of roots:  176
# ------------------------------------------------------------------------
# n:  133  n.digits(prime):  [1, 2, 2, 1, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 88], [2, 88]]
# total multiplicity of roots:  178
# ------------------------------------------------------------------------
# n:  139  n.digits(prime):  [1, 1, 0, 2, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 92], [2, 92]]
# total multiplicity of roots:  186
# ------------------------------------------------------------------------
# n:  145  n.digits(prime):  [1, 0, 1, 2, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 8], [1, 94], [2, 94]]
# total multiplicity of roots:  196
# ------------------------------------------------------------------------
# n:  148  n.digits(prime):  [1, 1, 1, 2, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 98], [2, 98]]
# total multiplicity of roots:  198
# ------------------------------------------------------------------------
# n:  151  n.digits(prime):  [1, 2, 1, 2, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 100], [2, 100]]
# total multiplicity of roots:  202
# ------------------------------------------------------------------------
# n:  154  n.digits(prime):  [1, 0, 2, 2, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 8], [1, 100], [2, 100]]
# total multiplicity of roots:  208
# ------------------------------------------------------------------------
# n:  157  n.digits(prime):  [1, 1, 2, 2, 1]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 104], [2, 104]]
# total multiplicity of roots:  210
# ------------------------------------------------------------------------
# n:  163  n.digits(prime):  [1, 0, 0, 0, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 108], [2, 108]]
# total multiplicity of roots:  218
# ------------------------------------------------------------------------
# n:  166  n.digits(prime):  [1, 1, 0, 0, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 8], [1, 108], [2, 108]]
# total multiplicity of roots:  224
# ------------------------------------------------------------------------
# n:  172  n.digits(prime):  [1, 0, 1, 0, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 114], [2, 114]]
# total multiplicity of roots:  230
# ------------------------------------------------------------------------
# n:  175  n.digits(prime):  [1, 1, 1, 0, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 116], [2, 116]]
# total multiplicity of roots:  234
# ------------------------------------------------------------------------
# n:  181  n.digits(prime):  [1, 0, 2, 0, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 120], [2, 120]]
# total multiplicity of roots:  242
# ------------------------------------------------------------------------
# n:  184  n.digits(prime):  [1, 1, 2, 0, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 8], [1, 120], [2, 120]]
# total multiplicity of roots:  248
# ------------------------------------------------------------------------
# n:  190  n.digits(prime):  [1, 0, 0, 1, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 8], [1, 124], [2, 124]]
# total multiplicity of roots:  256
# ------------------------------------------------------------------------
# n:  193  n.digits(prime):  [1, 1, 0, 1, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 128], [2, 128]]
# total multiplicity of roots:  258
# ------------------------------------------------------------------------
# n:  199  n.digits(prime):  [1, 0, 1, 1, 2]  sd:  1  prime:  3  n mod prime:  1
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 2], [1, 132], [2, 132]]
# total multiplicity of roots:  266
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
#  bad n:  []
# template:  [1, 2]

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=3
residue=1
sdvalue=2
badn=[]
count=0
flag=1
template=[]
for k in [1..200]:
    n=s[k][0]
    if (n>prime-1)&(mod(n,prime)==residue):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
    
        if (sd==sdvalue)&(flag==1):
            template=basicRoots(polynum,prime,sd)
            flag=0
    
        if (sd==sdvalue):
            count=1+count
            br=basicRoots(polynum,prime,sd)
            if br!=template:badn=badn+[n]
            lm=logsAndMultiplicitiesOverField(polynum,prime,sd)
            tm=totalMultiplicityOverField(polynum,prime,sd)
            print "------------------------------------------------------------------------"
            print "n: ",n," n.digits(prime): ",n.digits(prime)," sd: ",sd," prime: ",prime," n mod prime: ",mod(n,prime)
            print "basic roots:";print br
            print "root-logs and multiplicities:";print sorted(lm)
            print "total multiplicity of roots: ",tm
print "&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&"
if count==0:print "null"
print " bad n: ",badn;print "template: ",template
# Out:
# ------------------------------------------------------------------------
# n:  34  n.digits(prime):  [1, 2, 0, 1]  sd:  2  prime:  3  n mod prime:  1
# basic roots:
# [1, 2, 4, 5, 7, 8]
# root-logs and multiplicities:
# [[-1, 8], [1, 2], [2, 2], [3, 2], [4, 16], [5, 2], [6, 2], [7, 2], [8, 16]]
# total multiplicity of roots:  52
# ------------------------------------------------------------------------
# n:  85  n.digits(prime):  [1, 1, 0, 0, 1]  sd:  2  prime:  3  n mod prime:  1
# basic roots:
# [1, 2, 4, 5, 7, 8]
# root-logs and multiplicities:
# [[-1, 8], [1, 2], [2, 2], [3, 2], [4, 50], [5, 2], [6, 2], [7, 2], [8, 50]]
# total multiplicity of roots:  120
# ------------------------------------------------------------------------
# n:  136  n.digits(prime):  [1, 0, 0, 2, 1]  sd:  2  prime:  3  n mod prime:  1
# basic roots:
# [1, 2, 4, 5, 7, 8]
# root-logs and multiplicities:
# [[-1, 8], [1, 2], [2, 2], [3, 2], [4, 84], [5, 2], [6, 2], [7, 2], [8, 84]]
# total multiplicity of roots:  188
# ------------------------------------------------------------------------
# n:  142  n.digits(prime):  [1, 2, 0, 2, 1]  sd:  2  prime:  3  n mod prime:  1
# basic roots:
# [1, 2, 4, 5, 7, 8]
# root-logs and multiplicities:
# [[-1, 8], [1, 2], [2, 2], [3, 2], [4, 88], [5, 2], [6, 2], [7, 2], [8, 88]]
# total multiplicity of roots:  196
# ------------------------------------------------------------------------
# n:  160  n.digits(prime):  [1, 2, 2, 2, 1]  sd:  2  prime:  3  n mod prime:  1
# basic roots:
# [1, 2, 4, 5, 7, 8]
# root-logs and multiplicities:
# [[-1, 8], [1, 2], [2, 2], [3, 2], [4, 100], [5, 2], [6, 2], [7, 2], [8, 100]]
# total multiplicity of roots:  220
# ------------------------------------------------------------------------
# n:  178  n.digits(prime):  [1, 2, 1, 0, 2]  sd:  2  prime:  3  n mod prime:  1
# basic roots:
# [1, 2, 4, 5, 7, 8]
# root-logs and multiplicities:
# [[-1, 8], [1, 2], [2, 2], [3, 2], [4, 112], [5, 2], [6, 2], [7, 2], [8, 112]]
# total multiplicity of roots:  244
# ------------------------------------------------------------------------
# n:  187  n.digits(prime):  [1, 2, 2, 0, 2]  sd:  2  prime:  3  n mod prime:  1
# basic roots:
# [1, 2, 4, 5, 7, 8]
# root-logs and multiplicities:
# [[-1, 8], [1, 2], [2, 2], [3, 2], [4, 118], [5, 2], [6, 2], [7, 2], [8, 118]]
# total multiplicity of roots:  256
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
#  bad n:  []
# template:  [1, 2, 4, 5, 7, 8]

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=3
residue=1
sdvalue=3
badn=[]
count=0
flag=1
template=[]
for k in [1..200]:
    n=s[k][0]
    if (n>prime-1)&(mod(n,prime)==residue):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
    
        if (sd==sdvalue)&(flag==1):
            template=basicRoots(polynum,prime,sd)
            flag=0
    
        if (sd==sdvalue):
            count=1+count
            br=basicRoots(polynum,prime,sd)
            if br!=template:badn=badn+[n]
            lm=logsAndMultiplicitiesOverField(polynum,prime,sd)
            tm=totalMultiplicityOverField(polynum,prime,sd)
            print "------------------------------------------------------------------------"
            print "n: ",n," n.digits(prime): ",n.digits(prime)," sd: ",sd," prime: ",prime," n mod prime: ",mod(n,prime)
            print "basic roots:";print br
            print "root-logs and multiplicities:";print sorted(lm)
            print "total multiplicity of roots: ",tm
print "&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&"
if count==0:print "null"
print " bad n: ",badn;print "template: ",template
# Out:
# ------------------------------------------------------------------------
# n:  49  n.digits(prime):  [1, 1, 2, 1]  sd:  3  prime:  3  n mod prime:  1
# basic roots:
# [4, 10, 13, 17, 23, 25, 26]
# root-logs and multiplicities:
# [[-1, 2], [4, 1], [10, 1], [12, 1], [13, 30], [17, 1], [23, 1], [25, 1], [26, 30]]
# total multiplicity of roots:  68
# ------------------------------------------------------------------------
# n:  106  n.digits(prime):  [1, 2, 2, 0, 1]  sd:  3  prime:  3  n mod prime:  1
# basic roots:
# [1, 2, 5, 7, 8, 11, 13, 14, 16, 19, 20, 22, 26]
# root-logs and multiplicities:
# [[-1, 8], [1, 1], [2, 1], [3, 1], [5, 1], [6, 1], [7, 1], [8, 1], [9, 1], [11, 1], [13, 62], [14, 1], [15, 1], [16, 1], [18, 1], [19, 1], [20, 1], [21, 1], [22, 1], [24, 1], [26, 62]]
# total multiplicity of roots:  150
# ------------------------------------------------------------------------
# n:  169  n.digits(prime):  [1, 2, 0, 0, 2]  sd:  3  prime:  3  n mod prime:  1
# basic roots:
# [4, 10, 13, 17, 23, 25, 26]
# root-logs and multiplicities:
# [[-1, 2], [4, 1], [10, 1], [12, 1], [13, 110], [17, 1], [23, 1], [25, 1], [26, 110]]
# total multiplicity of roots:  228
# ------------------------------------------------------------------------
# n:  196  n.digits(prime):  [1, 2, 0, 1, 2]  sd:  3  prime:  3  n mod prime:  1
# basic roots:
# [4, 10, 13, 17, 23, 25, 26]
# root-logs and multiplicities:
# [[-1, 2], [4, 1], [10, 1], [12, 1], [13, 128], [17, 1], [23, 1], [25, 1], [26, 128]]
# total multiplicity of roots:  264
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
#  bad n:  [106]
# template:  [4, 10, 13, 17, 23, 25, 26]

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=3
residue=2
sdvalue=1
badn=[]
count=0
flag=1
template=[]
for k in [1..200]:
    n=s[k][0]
    if (n>prime-1)&(mod(n,prime)==residue):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
    
        if (sd==sdvalue)&(flag==1):
            template=basicRoots(polynum,prime,sd)
            flag=0
    
        if (sd==sdvalue):
            count=1+count
            br=basicRoots(polynum,prime,sd)
            if br!=template:badn=badn+[n]
            lm=logsAndMultiplicitiesOverField(polynum,prime,sd)
            tm=totalMultiplicityOverField(polynum,prime,sd)
            print "------------------------------------------------------------------------"
            print "n: ",n," n.digits(prime): ",n.digits(prime)," sd: ",sd," prime: ",prime," n mod prime: ",mod(n,prime)
            print "basic roots:";print br
            print "root-logs and multiplicities:";print sorted(lm)
            print "total multiplicity of roots: ",tm
print "&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&"
if count==0:print "null"
print " bad n: ",badn;print "template: ",template
# Out:
# ------------------------------------------------------------------------
# n:  5  n.digits(prime):  [2, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 4], [2, 4]]
# total multiplicity of roots:  8
# ------------------------------------------------------------------------
# n:  14  n.digits(prime):  [2, 1, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 10], [2, 10]]
# total multiplicity of roots:  20
# ------------------------------------------------------------------------
# n:  20  n.digits(prime):  [2, 0, 2]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 14], [2, 14]]
# total multiplicity of roots:  28
# ------------------------------------------------------------------------
# n:  26  n.digits(prime):  [2, 2, 2]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 18], [2, 18]]
# total multiplicity of roots:  36
# ------------------------------------------------------------------------
# n:  29  n.digits(prime):  [2, 0, 0, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 20], [2, 20]]
# total multiplicity of roots:  40
# ------------------------------------------------------------------------
# n:  32  n.digits(prime):  [2, 1, 0, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 22], [2, 22]]
# total multiplicity of roots:  44
# ------------------------------------------------------------------------
# n:  35  n.digits(prime):  [2, 2, 0, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 24], [2, 24]]
# total multiplicity of roots:  48
# ------------------------------------------------------------------------
# n:  41  n.digits(prime):  [2, 1, 1, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 28], [2, 28]]
# total multiplicity of roots:  56
# ------------------------------------------------------------------------
# n:  44  n.digits(prime):  [2, 2, 1, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 30], [2, 30]]
# total multiplicity of roots:  60
# ------------------------------------------------------------------------
# n:  47  n.digits(prime):  [2, 0, 2, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 32], [2, 32]]
# total multiplicity of roots:  64
# ------------------------------------------------------------------------
# n:  53  n.digits(prime):  [2, 2, 2, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 36], [2, 36]]
# total multiplicity of roots:  72
# ------------------------------------------------------------------------
# n:  56  n.digits(prime):  [2, 0, 0, 2]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 38], [2, 38]]
# total multiplicity of roots:  76
# ------------------------------------------------------------------------
# n:  59  n.digits(prime):  [2, 1, 0, 2]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 40], [2, 40]]
# total multiplicity of roots:  80
# ------------------------------------------------------------------------
# n:  62  n.digits(prime):  [2, 2, 0, 2]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 42], [2, 42]]
# total multiplicity of roots:  84
# ------------------------------------------------------------------------
# n:  65  n.digits(prime):  [2, 0, 1, 2]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 44], [2, 44]]
# total multiplicity of roots:  88
# ------------------------------------------------------------------------
# n:  68  n.digits(prime):  [2, 1, 1, 2]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 46], [2, 46]]
# total multiplicity of roots:  92
# ------------------------------------------------------------------------
# n:  71  n.digits(prime):  [2, 2, 1, 2]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 48], [2, 48]]
# total multiplicity of roots:  96
# ------------------------------------------------------------------------
# n:  74  n.digits(prime):  [2, 0, 2, 2]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 50], [2, 50]]
# total multiplicity of roots:  100
# ------------------------------------------------------------------------
# n:  77  n.digits(prime):  [2, 1, 2, 2]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 52], [2, 52]]
# total multiplicity of roots:  104
# ------------------------------------------------------------------------
# n:  86  n.digits(prime):  [2, 1, 0, 0, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 6], [1, 56], [2, 56]]
# total multiplicity of roots:  118
# ------------------------------------------------------------------------
# n:  89  n.digits(prime):  [2, 2, 0, 0, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 60], [2, 60]]
# total multiplicity of roots:  120
# ------------------------------------------------------------------------
# n:  92  n.digits(prime):  [2, 0, 1, 0, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 62], [2, 62]]
# total multiplicity of roots:  124
# ------------------------------------------------------------------------
# n:  95  n.digits(prime):  [2, 1, 1, 0, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 6], [1, 62], [2, 62]]
# total multiplicity of roots:  130
# ------------------------------------------------------------------------
# n:  98  n.digits(prime):  [2, 2, 1, 0, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 66], [2, 66]]
# total multiplicity of roots:  132
# ------------------------------------------------------------------------
# n:  101  n.digits(prime):  [2, 0, 2, 0, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 6], [1, 66], [2, 66]]
# total multiplicity of roots:  138
# ------------------------------------------------------------------------
# n:  107  n.digits(prime):  [2, 2, 2, 0, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 72], [2, 72]]
# total multiplicity of roots:  144
# ------------------------------------------------------------------------
# n:  110  n.digits(prime):  [2, 0, 0, 1, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 74], [2, 74]]
# total multiplicity of roots:  148
# ------------------------------------------------------------------------
# n:  113  n.digits(prime):  [2, 1, 0, 1, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 76], [2, 76]]
# total multiplicity of roots:  152
# ------------------------------------------------------------------------
# n:  119  n.digits(prime):  [2, 0, 1, 1, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 80], [2, 80]]
# total multiplicity of roots:  160
# ------------------------------------------------------------------------
# n:  122  n.digits(prime):  [2, 1, 1, 1, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 82], [2, 82]]
# total multiplicity of roots:  164
# ------------------------------------------------------------------------
# n:  128  n.digits(prime):  [2, 0, 2, 1, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 86], [2, 86]]
# total multiplicity of roots:  172
# ------------------------------------------------------------------------
# n:  131  n.digits(prime):  [2, 1, 2, 1, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 88], [2, 88]]
# total multiplicity of roots:  176
# ------------------------------------------------------------------------
# n:  134  n.digits(prime):  [2, 2, 2, 1, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 90], [2, 90]]
# total multiplicity of roots:  180
# ------------------------------------------------------------------------
# n:  137  n.digits(prime):  [2, 0, 0, 2, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 92], [2, 92]]
# total multiplicity of roots:  184
# ------------------------------------------------------------------------
# n:  140  n.digits(prime):  [2, 1, 0, 2, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 94], [2, 94]]
# total multiplicity of roots:  188
# ------------------------------------------------------------------------
# n:  143  n.digits(prime):  [2, 2, 0, 2, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 96], [2, 96]]
# total multiplicity of roots:  192
# ------------------------------------------------------------------------
# n:  146  n.digits(prime):  [2, 0, 1, 2, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 98], [2, 98]]
# total multiplicity of roots:  196
# ------------------------------------------------------------------------
# n:  149  n.digits(prime):  [2, 1, 1, 2, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 100], [2, 100]]
# total multiplicity of roots:  200
# ------------------------------------------------------------------------
# n:  152  n.digits(prime):  [2, 2, 1, 2, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 102], [2, 102]]
# total multiplicity of roots:  204
# ------------------------------------------------------------------------
# n:  155  n.digits(prime):  [2, 0, 2, 2, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 104], [2, 104]]
# total multiplicity of roots:  208
# ------------------------------------------------------------------------
# n:  158  n.digits(prime):  [2, 1, 2, 2, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 106], [2, 106]]
# total multiplicity of roots:  212
# ------------------------------------------------------------------------
# n:  161  n.digits(prime):  [2, 2, 2, 2, 1]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 108], [2, 108]]
# total multiplicity of roots:  216
# ------------------------------------------------------------------------
# n:  164  n.digits(prime):  [2, 0, 0, 0, 2]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 110], [2, 110]]
# total multiplicity of roots:  220
# ------------------------------------------------------------------------
# n:  167  n.digits(prime):  [2, 1, 0, 0, 2]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 112], [2, 112]]
# total multiplicity of roots:  224
# ------------------------------------------------------------------------
# n:  170  n.digits(prime):  [2, 2, 0, 0, 2]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 114], [2, 114]]
# total multiplicity of roots:  228
# ------------------------------------------------------------------------
# n:  173  n.digits(prime):  [2, 0, 1, 0, 2]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 6], [1, 114], [2, 114]]
# total multiplicity of roots:  234
# ------------------------------------------------------------------------
# n:  176  n.digits(prime):  [2, 1, 1, 0, 2]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 118], [2, 118]]
# total multiplicity of roots:  236
# ------------------------------------------------------------------------
# n:  179  n.digits(prime):  [2, 2, 1, 0, 2]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 120], [2, 120]]
# total multiplicity of roots:  240
# ------------------------------------------------------------------------
# n:  182  n.digits(prime):  [2, 0, 2, 0, 2]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 122], [2, 122]]
# total multiplicity of roots:  244
# ------------------------------------------------------------------------
# n:  185  n.digits(prime):  [2, 1, 2, 0, 2]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 124], [2, 124]]
# total multiplicity of roots:  248
# ------------------------------------------------------------------------
# n:  191  n.digits(prime):  [2, 0, 0, 1, 2]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[-1, 6], [1, 126], [2, 126]]
# total multiplicity of roots:  258
# ------------------------------------------------------------------------
# n:  197  n.digits(prime):  [2, 2, 0, 1, 2]  sd:  1  prime:  3  n mod prime:  2
# basic roots:
# [1, 2]
# root-logs and multiplicities:
# [[1, 132], [2, 132]]
# total multiplicity of roots:  264
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
#  bad n:  []
# template:  [1, 2]

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=3
residue=2
sdvalue=2
badn=[]
count=0
flag=1
template=[]
for k in [1..200]:
    n=s[k][0]
    if (n>prime-1)&(mod(n,prime)==residue):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
    
        if (sd==sdvalue)&(flag==1):
            template=basicRoots(polynum,prime,sd)
            flag=0
    
        if (sd==sdvalue):
            count=1+count
            br=basicRoots(polynum,prime,sd)
            if br!=template:badn=badn+[n]
            lm=logsAndMultiplicitiesOverField(polynum,prime,sd)
            tm=totalMultiplicityOverField(polynum,prime,sd)
            print "------------------------------------------------------------------------"
            print "n: ",n," n.digits(prime): ",n.digits(prime)," sd: ",sd," prime: ",prime," n mod prime: ",mod(n,prime)
            print "basic roots:";print br
            print "root-logs and multiplicities:";print sorted(lm)
            print "total multiplicity of roots: ",tm
print "&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&"
if count==0:print "null"
print " bad n: ",badn;print "template: ",template
# Out:
# ------------------------------------------------------------------------
# n:  80  n.digits(prime):  [2, 2, 2, 2]  sd:  2  prime:  3  n mod prime:  2
# basic roots:
# [1, 2, 4, 5, 7, 8]
# root-logs and multiplicities:
# [[1, 1], [2, 1], [3, 1], [4, 52], [5, 1], [6, 1], [7, 1], [8, 52]]
# total multiplicity of roots:  110
# ------------------------------------------------------------------------
# n:  83  n.digits(prime):  [2, 0, 0, 0, 1]  sd:  2  prime:  3  n mod prime:  2
# basic roots:
# [1, 2, 4, 5, 7, 8]
# root-logs and multiplicities:
# [[1, 1], [2, 1], [3, 1], [4, 54], [5, 1], [6, 1], [7, 1], [8, 54]]
# total multiplicity of roots:  114
# ------------------------------------------------------------------------
# n:  116  n.digits(prime):  [2, 2, 0, 1, 1]  sd:  2  prime:  3  n mod prime:  2
# basic roots:
# [1, 2, 4, 5, 7, 8]
# root-logs and multiplicities:
# [[1, 1], [2, 1], [3, 1], [4, 76], [5, 1], [6, 1], [7, 1], [8, 76]]
# total multiplicity of roots:  158
# ------------------------------------------------------------------------
# n:  125  n.digits(prime):  [2, 2, 1, 1, 1]  sd:  2  prime:  3  n mod prime:  2
# basic roots:
# [1, 2, 4, 5, 7, 8]
# root-logs and multiplicities:
# [[1, 1], [2, 1], [3, 1], [4, 82], [5, 1], [6, 1], [7, 1], [8, 82]]
# total multiplicity of roots:  170
# ------------------------------------------------------------------------
# n:  188  n.digits(prime):  [2, 2, 2, 0, 2]  sd:  2  prime:  3  n mod prime:  2
# basic roots:
# [1, 2, 4, 5, 7, 8]
# root-logs and multiplicities:
# [[1, 1], [2, 1], [3, 1], [4, 124], [5, 1], [6, 1], [7, 1], [8, 124]]
# total multiplicity of roots:  254
# ------------------------------------------------------------------------
# n:  194  n.digits(prime):  [2, 1, 0, 1, 2]  sd:  2  prime:  3  n mod prime:  2
# basic roots:
# [1, 2, 4, 5, 7, 8]
# root-logs and multiplicities:
# [[1, 1], [2, 1], [3, 1], [4, 128], [5, 1], [6, 1], [7, 1], [8, 128]]
# total multiplicity of roots:  262
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
#  bad n:  []
# template:  [1, 2, 4, 5, 7, 8]

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=3
residue=2
sdvalue=3
badn=[]
count=0
flag=1
template=[]
for k in [1..200]:
    n=s[k][0]
    if (n>prime-1)&(mod(n,prime)==residue):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
    
        if (sd==sdvalue)&(flag==1):
            template=basicRoots(polynum,prime,sd)
            flag=0
    
        if (sd==sdvalue):
            count=1+count
            br=basicRoots(polynum,prime,sd)
            if br!=template:badn=badn+[n]
            lm=logsAndMultiplicitiesOverField(polynum,prime,sd)
            tm=totalMultiplicityOverField(polynum,prime,sd)
            print "------------------------------------------------------------------------"
            print "n: ",n," n.digits(prime): ",n.digits(prime)," sd: ",sd," prime: ",prime," n mod prime: ",mod(n,prime)
            print "basic roots:";print br
            print "root-logs and multiplicities:";print sorted(lm)
            print "total multiplicity of roots: ",tm
print "&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&"
if count==0:print "null"
print " bad n: ",badn;print "template: ",template
# Out:
# ------------------------------------------------------------------------
# n:  8  n.digits(prime):  [2, 2]  sd:  3  prime:  3  n mod prime:  2
# basic roots:
# [4, 10, 13, 17, 23, 25, 26]
# root-logs and multiplicities:
# [[4, 1], [10, 1], [12, 1], [13, 4], [17, 1], [23, 1], [25, 1], [26, 4]]
# total multiplicity of roots:  14
# ------------------------------------------------------------------------
# n:  11  n.digits(prime):  [2, 0, 1]  sd:  3  prime:  3  n mod prime:  2
# basic roots:
# [4, 10, 13, 17, 23, 25, 26]
# root-logs and multiplicities:
# [[4, 1], [10, 1], [12, 1], [13, 6], [17, 1], [23, 1], [25, 1], [26, 6]]
# total multiplicity of roots:  18
# ------------------------------------------------------------------------
# n:  23  n.digits(prime):  [2, 1, 2]  sd:  3  prime:  3  n mod prime:  2
# basic roots:
# [4, 10, 13, 17, 23, 25, 26]
# root-logs and multiplicities:
# [[4, 1], [10, 1], [12, 1], [13, 14], [17, 1], [23, 1], [25, 1], [26, 14]]
# total multiplicity of roots:  34
# ------------------------------------------------------------------------
# n:  38  n.digits(prime):  [2, 0, 1, 1]  sd:  3  prime:  3  n mod prime:  2
# basic roots:
# [4, 10, 13, 17, 23, 25, 26]
# root-logs and multiplicities:
# [[4, 1], [10, 1], [12, 1], [13, 24], [17, 1], [23, 1], [25, 1], [26, 24]]
# total multiplicity of roots:  54
# ------------------------------------------------------------------------
# n:  50  n.digits(prime):  [2, 1, 2, 1]  sd:  3  prime:  3  n mod prime:  2
# basic roots:
# [4, 10, 13, 17, 23, 25, 26]
# root-logs and multiplicities:
# [[4, 1], [10, 1], [12, 1], [13, 32], [17, 1], [23, 1], [25, 1], [26, 32]]
# total multiplicity of roots:  70
# ------------------------------------------------------------------------
# n:  104  n.digits(prime):  [2, 1, 2, 0, 1]  sd:  3  prime:  3  n mod prime:  2
# basic roots:
# [4, 10, 13, 17, 23, 25, 26]
# root-logs and multiplicities:
# [[4, 1], [10, 1], [12, 1], [13, 68], [17, 1], [23, 1], [25, 1], [26, 68]]
# total multiplicity of roots:  142
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
#  bad n:  []
# template:  [4, 10, 13, 17, 23, 25, 26]

# %%
import pickle
rfile =open('/Users/barrybrent/run14jun21no14.txt','r') # xJ polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
bound=120
prime=3
residue=2
sdvalue=4
badn=[]
count=0
flag=1
template=[]
for k in [1..200]:
    n=s[k][0]
    if (n>prime-1)&(mod(n,prime)==residue):
        poly=D(s[k][1])
        polynum=ZR(polynomialnumerator(D(poly)))
        sd=leastSplittingDegree(polynum,prime,bound)
    
        if (sd==sdvalue)&(flag==1):
            template=basicRoots(polynum,prime,sd)
            flag=0
    
        if (sd==sdvalue):
            count=1+count
            br=basicRoots(polynum,prime,sd)
            if br!=template:badn=badn+[n]
            lm=logsAndMultiplicitiesOverField(polynum,prime,sd)
            tm=totalMultiplicityOverField(polynum,prime,sd)
            print "------------------------------------------------------------------------"
            print "n: ",n," n.digits(prime): ",n.digits(prime)," sd: ",sd," prime: ",prime," n mod prime: ",mod(n,prime)
            print "basic roots:";print br
            print "root-logs and multiplicities:";print sorted(lm)
            print "total multiplicity of roots: ",tm
print "&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&"
if count==0:print "null"
print " bad n: ",badn;print "template: ",template
# Out:
# ------------------------------------------------------------------------
# n:  17  n.digits(prime):  [2, 2, 1]  sd:  4  prime:  3  n mod prime:  2
# basic roots:
# [5, 22, 26, 34, 38, 40, 55, 62, 74, 80]
# root-logs and multiplicities:
# [[5, 1], [15, 1], [22, 1], [26, 1], [34, 1], [38, 1], [40, 8], [45, 1], [55, 1], [62, 1], [66, 1], [74, 1], [78, 1], [80, 8]]
# total multiplicity of roots:  28
# &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
#  bad n:  []
# template:  [5, 22, 26, 34, 38, 40, 55, 62, 74, 80]
